# %%
# !pip install xpress
# !pip install pandas
# Out:
# Requirement already satisfied: xpress in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (9.4.2)
# Requirement already satisfied: numpy<2.0a0,>=1.26 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from xpress) (1.26.4)
# Requirement already satisfied: xpresslibs==9.4.2 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from xpress) (9.4.2)
# Requirement already satisfied: pandas in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import xpress as xp
import pandas as pd

# %% [markdown]
# **Loading data**

# %%
meal_data_path = 'C:/AOR/meal_data.xlsx'
meal_data = pd.read_excel(meal_data_path)
meal_data.head()
# Out:
#                           item_name course_type subcategories  meal_type  \
# 0          Trick OR Treat Ice Cream        Soup         cream        NaN
# 1                 Sweet Fries Snack        Side         fried        NaN
# 2                  Tomatoes - Salad        Side    red orange        NaN
# 3  Chicken BBQ Caesar Salad EntrÌ©e   Main dish       poultry        NaN
# 4         Corn and Black Bean Salad        Side        legume        NaN
#
#    cost  nf_calories  nf_calories_from_fat  nf_total_fat  nf_saturated_fat  \
# 0  2.08       300.00                 140.0          16.0               9.0
# 1  2.27      1150.00                 690.0          79.0               7.0
# 2  3.45         9.58                   2.4           0.0               0.0
# 3  3.95       203.00                   NaN           NaN               2.1
# 4  3.59       140.00                  10.0           1.0               0.0
#
#    nf_trans_fatty_acid  ...  nf_vitamin_a_dv  nf_vitamin_c_dv  nf_calcium_dv  \
# 0                  0.0  ...              8.0              2.0           15.0
# 1                  0.0  ...              NaN              NaN            NaN
# 2                  0.0  ...              5.0             14.0            0.0
# 3                  NaN  ...              NaN              NaN            NaN
# 4                  0.0  ...              2.0              4.0            2.0
#
#    nf_iron_dv  nf_potassium  nf_servings_per_container  nf_serving_size_qty  \
# 0         4.0           NaN                        NaN                 4.00
# 1         NaN           NaN                        NaN                13.40
# 2         0.0           NaN                        NaN                45.52
# 3         NaN           NaN                        NaN                 2.00
# 4        10.0           NaN                        NaN                 1.00
#
#    nf_serving_size_unit  nf_serving_weight_grams  images_front_full_url
# 0             oz scoops                      NaN                    NaN
# 1                    oz                      NaN                    NaN
# 2                 Grams                    45.52                    NaN
# 3              servings                      NaN                    NaN
# 4                 Salad                      NaN                    NaN
#
# [5 rows x 28 columns]

# %%
score_preference_path = 'C:/AOR/customer_dish_preferences.xlsx'
score_preference = pd.read_excel(score_preference_path)
score_preference.set_index('Unnamed: 0', inplace=True)
score_preference.head()
# Out:
#             Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# Unnamed: 0
# Customer_1                         3                  1                 1
# Customer_2                         1                  3                 3
# Customer_3                         2                  2                 1
# Customer_4                         2                  2                 1
# Customer_5                         3                  3                 3
#
#             Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  \
# Unnamed: 0
# Customer_1                                 3                          1
# Customer_2                                 1                          1
# Customer_3                                 3                          3
# Customer_4                                 2                          3
# Customer_5                                 3                          2
#
#             Mango Cake  Egg  Flavored Fresh Lemonade, Peach  \
# Unnamed: 0
# Customer_1           2    3                               3
# Customer_2           3    3                               1
# Customer_3           3    1                               3
# Customer_4           2    2                               1
# Customer_5           2    2                               3
#
#             Add Pirate Tossed Salad  Blueberry Vinaigrette  ...  \
# Unnamed: 0                                                  ...
# Customer_1                        1                      3  ...
# Customer_2                        3                      3  ...
# Customer_3                        3                      1  ...
# Customer_4                        3                      1  ...
# Customer_5                        3                      3  ...
#
#             Vegetable Stir-Fry  Vegetable Lasagna  Vegetable Paella  \
# Unnamed: 0
# Customer_1                   3                  2                 1
# Customer_2                   2                  3                 2
# Customer_3                   3                  1                 3
# Customer_4                   3                  3                 3
# Customer_5                   2                  3                 2
#
#             Vegetable Quiche  Vegetable Kebabs  Vegetable Chili   \
# Unnamed: 0
# Customer_1                 3                 3                 1
# Customer_2                 3                 3                 3
# Customer_3                 3                 3                 3
# Customer_4                 2                 2                 2
# Customer_5                 3                 3                 3
#
#             Stuffed Bell Peppers  Vegetable Moussaka  Vegetable Biryani  \
# Unnamed: 0
# Customer_1                     3                   3                  3
# Customer_2                     3                   3                  2
# Customer_3                     3                   3                  3
# Customer_4                     2                   1                  3
# Customer_5                     2                   3                  3
#
#             Vegetable Enchiladas
# Unnamed: 0
# Customer_1                     1
# Customer_2                     3
# Customer_3                     3
# Customer_4                     3
# Customer_5                     2
#
# [5 rows x 210 columns]

# %%
nutrition_criteria_path = "C:/AOR/nutrition_criteria.xlsx"
nutrition_criteria = pd.read_excel(nutrition_criteria_path)
nutrition_criteria.head()
# Out:
#    ID        Element     F     M  Average
# 0   1       Calories  1600  2000     1800
# 1   2         Sodium  2300  2300     2300
# 2   3   Carbohydrate   130   130      130
# 3   4  Dietary_fiber    22    28       25
# 4   5        Protein    46    56       51

# %%
table3_path = "C:/AOR/table3.xlsx"
meal_constraints = pd.read_excel(table3_path, sheet_name='meal_constraints', index_col=0)
diet_types = pd.read_excel(table3_path, sheet_name='diet_types', index_col=0)
maximum_servings = pd.read_excel(table3_path, sheet_name='maximum_servings')
day_item = pd.read_excel(table3_path, sheet_name='day_item')
wp = pd.read_excel(table3_path, sheet_name='wp')
wc = pd.read_excel(table3_path, sheet_name='wc')
day_item.head()
# Out:
#    Breakfast  Soup  Salad  Main dish  Side  Appetizer  Dessert
# 0          1     1      1          1   NaN        NaN        1

# %% [markdown]
# **Model parameters and decision variables**

# %%
# model = xp.problem()
num_item = 210
num_day = 7
num_meal = 3
num_patron = 3
num_course = 7

I = list(range(num_item)) # i∈I
M = ['breakfast', 'lunch', 'dinner'] # j∈M
T = list(range(num_day)) # t∈T
P = list(range(num_patron)) # p∈P
L = ['Breakfast', 'Soup', 'Salad', 'Main dish', 'Side', 'Appetizer', 'Dessert'] # l∈L
K = ['calories','cholesterol','sodium','dietary_fiber']
#K = ['calories','cholesterol','dietary_fiber']


l_i = {meal_data.index[i]: meal_data.iloc[i]["course_type"] for i in range(len(meal_data))}
I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
S_l = meal_data.groupby("course_type")["subcategories"].unique().apply(list).to_dict()
I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

w = {
    "calories": {i: meal_data.iloc[i]["nf_calories"] for i in I},
    "cholesterol": {i: meal_data.iloc[i]["nf_cholesterol"] for i in I},
    "sodium": {i: meal_data.iloc[i]["nf_sodium"] for i in I},
    "dietary_fiber": {i: meal_data.iloc[i]["nf_dietary_fiber"] for i in I},
}
# w = {
#     "calories": {i: meal_data.iloc[i]["nf_calories"] for i in I},
#     "cholesterol": {i: meal_data.iloc[i]["nf_cholesterol"] for i in I},
#     "dietary_fiber": {i: meal_data.iloc[i]["nf_dietary_fiber"] for i in I},
# }


ns = meal_constraints.to_dict(orient='index')
np = diet_types.to_dict(orient='index')
np_expanded = {p: {j: {l: np[j][l] for l in L} for j in M} for p in P}
nsOWP = maximum_servings.to_dict(orient='records')[0]
nsd = day_item.to_dict(orient='records')[0]
wp_l = wp.to_dict(orient='records')[0]
wc_l = wc.to_dict(orient='records')[0]
pi_raw = score_preference.to_dict(orient='index')
cost = {i: meal_data.loc[i, 'cost'] for i in I}

x = {
    (i, j, t): xp.var(
        vartype=xp.binary,
        name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
    )
    for i in I for j in M for t in T
}
y = {
    (i, p, j, t): xp.var(
        vartype=xp.binary,
        name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
    )
    for i in I for p in P for j in M for t in T
}
Q = {
    (p, k, t): xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Q_{p}_{k}_{t}'
    )
    for p in P 
    for k in K 
    for t in T
}

alpha_max = {
    p: {
        "calories": 2000,
        "cholesterol": 300,
        "sodium": 2300,
        "dietary_fiber": 1e30 
    }
    for p in P
}
alpha_min = {
    p: {
        "calories": 2000,
        "cholesterol": 0,
        "sodium": 0,
        "dietary_fiber": 28
    }
    for p in P
}
gamma_max = {
    p: {
        "calories": 2000,    
        "cholesterol": 300,
        "sodium": 2300,
        "dietary_fiber": 1e30
    }
    for p in P
}
gamma_min = {
    p: {
        "calories": 2000,    
        "cholesterol": 0,
        "sodium": 0,
        "dietary_fiber": 28
    }
    for p in P
}
# Out:
# C:\Users\18320\AppData\Local\Temp\ipykernel_9112\1217114177.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
# C:\Users\18320\AppData\Local\Temp\ipykernel_9112\1217114177.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

# %% [markdown]
# **PCA and cluster analysis - calculating the proportion of three different dietary groups**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# calculate pi
X = score_preference.copy()
features = list(X.columns)
X = X.values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=5) 
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_pca) 
score_preference['cluster'] = clusters

def p_score(score_preference, p_number):
    score_mean = pd.DataFrame()

    total_samples = len(score_preference)
    p_weight = []
    for cluster_label in range(p_number):
        cluster_size = len(score_preference[score_preference['cluster'] == cluster_label])
        p_weight.append(cluster_size / total_samples)

    for i, p_weight in enumerate(p_weight):
        print(f"p {i+1}: {p_weight:.2f}")

    for cluster_label in range(p_number):
        cluster_data = score_preference[score_preference['cluster'] == cluster_label] 
        cluster_mean = cluster_data.drop('cluster', axis=1).mean() 
        score_mean[cluster_label] = cluster_mean 

    score_mean = score_mean.T
    print("\nAverage values for each p:")
    print(score_mean)

    return p_weight, score_mean

p_score(score_preference, p_number=3)
p_weight, score_mean = p_score(score_preference, p_number=3)
patron_cluster = dict(enumerate(clusters))

item_names = [meal_data.loc[i, "item_name"] for i in range(num_item)]

pi = { p: { i: 0 for i in range(num_item) } for p in range(3) }
for p in range(3):
    for i in range(num_item):
        dish_name = item_names[i]
        try:
            pi[p][i] = score_mean.loc[p, dish_name]
        except KeyError:
            print(f"No clusters found in score_mean {p} corresponding dishes {dish_name} data，the default value is 0")
            pi[p][i] = 0

# check pi
for p in range(3):
    print(f"Clustering {p} Preference score for each dish：", pi[p])
# Out:
# p 1: 0.25
# p 2: 0.43
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  2.000000           1.285714          1.428571
# 1                  1.833333           1.916667          1.833333
# 2                  2.333333           2.111111          2.333333
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          1.285714                   2.000000    1.857143
# 1                          2.083333                   2.083333    1.916667
# 2                          2.666667                   2.222222    2.333333
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.428571                        1.571429                 2.142857
# 1  2.083333                        1.583333                 1.666667
# 2  2.444444                        2.666667                 2.333333
#
#    Blueberry Vinaigrette  ...  Vegetable Stir-Fry  Vegetable Lasagna  \
# 0               2.142857  ...            1.428571           1.571429
# 1               2.083333  ...            2.333333           1.833333
# 2               2.555556  ...            2.555556           2.000000
#
#    Vegetable Paella  Vegetable Quiche  Vegetable Kebabs  Vegetable Chili   \
# 0          1.857143          1.428571          1.714286          1.714286
# 1          2.166667          2.000000          1.833333          2.000000
# 2          2.333333          2.555556          2.555556          2.555556
#
#    Stuffed Bell Peppers  Vegetable Moussaka  Vegetable Biryani  \
# 0              2.000000            2.285714           2.000000
# 1              1.750000            1.833333           2.083333
# 2              2.444444            2.555556           2.333333
#
#    Vegetable Enchiladas
# 0              1.714286
# 1              2.166667
# 2              2.000000
#
# [3 rows x 210 columns]
# p 1: 0.25
# p 2: 0.43
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  2.000000           1.285714          1.428571
# 1                  1.833333           1.916667          1.833333
# 2                  2.333333           2.111111          2.333333
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          1.285714                   2.000000    1.857143
# 1                          2.083333                   2.083333    1.916667
# 2                          2.666667                   2.222222    2.333333
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.428571                        1.571429                 2.142857
# 1  2.083333                        1.583333                 1.666667
# 2  2.444444                        2.666667                 2.333333
#
#    Blueberry Vinaigrette  ...  Vegetable Stir-Fry  Vegetable Lasagna  \
# 0               2.142857  ...            1.428571           1.571429
# 1               2.083333  ...            2.333333           1.833333
# 2               2.555556  ...            2.555556           2.000000
#
#    Vegetable Paella  Vegetable Quiche  Vegetable Kebabs  Vegetable Chili   \
# 0          1.857143          1.428571          1.714286          1.714286
# 1          2.166667          2.000000          1.833333          2.000000
# 2          2.333333          2.555556          2.555556          2.555556
#
#    Stuffed Bell Peppers  Vegetable Moussaka  Vegetable Biryani  \
# 0              2.000000            2.285714           2.000000
# 1              1.750000            1.833333           2.083333
# 2              2.444444            2.555556           2.333333
#
#    Vegetable Enchiladas
# 0              1.714286
# 1              2.166667
# 2              2.000000
#
# [3 rows x 210 columns]
# Clustering 0 Preference score for each dish： {0: 2.0, 1: 1.2857142857142858, 2: 1.4285714285714286, 3: 1.2857142857142858, 4: 2.0, 5: 1.8571428571428572, 6: 1.4285714285714286, 7: 1.5714285714285714, 8: 2.142857142857143, 9: 2.142857142857143, 10: 1.4285714285714286, 11: 1.5714285714285714, 12: 2.0, 13: 2.0, 14: 2.0, 15: 2.142857142857143, 16: 2.142857142857143, 17: 2.4285714285714284, 18: 1.5714285714285714, 19: 1.4285714285714286, 20: 2.0, 21: 1.8571428571428572, 22: 1.7142857142857142, 23: 2.142857142857143, 24: 1.8571428571428572, 25: 1.7142857142857142, 26: 1.7142857142857142, 27: 1.5714285714285714, 28: 2.2857142857142856, 29: 1.7142857142857142, 30: 1.4285714285714286, 31: 2.142857142857143, 32: 1.7142857142857142, 33: 2.0, 34: 1.5714285714285714, 35: 1.2857142857142858, 36: 1.7142857142857142, 37: 1.1428571428571428, 38: 1.5714285714285714, 39: 1.8571428571428572, 40: 1.4285714285714286, 41: 1.7142857142857142, 42: 2.4285714285714284, 43: 1.8571428571428572, 44: 1.1428571428571428, 45: 1.7142857142857142, 46: 1.7142857142857142, 47: 2.142857142857143, 48: 2.0, 49: 1.8571428571428572, 50: 1.8571428571428572, 51: 2.142857142857143, 52: 1.7142857142857142, 53: 1.8571428571428572, 54: 2.0, 55: 1.4285714285714286, 56: 2.0, 57: 2.0, 58: 2.142857142857143, 59: 1.7142857142857142, 60: 2.2857142857142856, 61: 1.5714285714285714, 62: 1.8571428571428572, 63: 2.0, 64: 1.4285714285714286, 65: 1.7142857142857142, 66: 1.8571428571428572, 67: 1.5714285714285714, 68: 2.2857142857142856, 69: 2.142857142857143, 70: 1.7142857142857142, 71: 1.2857142857142858, 72: 2.142857142857143, 73: 2.142857142857143, 74: 1.7142857142857142, 75: 1.5714285714285714, 76: 1.5714285714285714, 77: 1.0, 78: 1.4285714285714286, 79: 2.0, 80: 2.0, 81: 2.0, 82: 2.142857142857143, 83: 1.8571428571428572, 84: 1.5714285714285714, 85: 1.5714285714285714, 86: 2.2857142857142856, 87: 1.5714285714285714, 88: 1.8571428571428572, 89: 1.7142857142857142, 90: 2.2857142857142856, 91: 1.8571428571428572, 92: 1.7142857142857142, 93: 1.5714285714285714, 94: 2.142857142857143, 95: 1.2857142857142858, 96: 1.4285714285714286, 97: 2.142857142857143, 98: 2.0, 99: 1.5714285714285714, 100: 1.4285714285714286, 101: 1.4285714285714286, 102: 1.8571428571428572, 103: 1.7142857142857142, 104: 1.8571428571428572, 105: 1.8571428571428572, 106: 2.0, 107: 1.8571428571428572, 108: 1.8571428571428572, 109: 1.5714285714285714, 110: 2.4285714285714284, 111: 2.142857142857143, 112: 1.4285714285714286, 113: 1.7142857142857142, 114: 1.8571428571428572, 115: 1.8571428571428572, 116: 2.142857142857143, 117: 1.5714285714285714, 118: 2.0, 119: 2.0, 120: 1.8571428571428572, 121: 2.0, 122: 2.0, 123: 2.142857142857143, 124: 1.8571428571428572, 125: 1.5714285714285714, 126: 1.8571428571428572, 127: 1.5714285714285714, 128: 1.8571428571428572, 129: 2.0, 130: 1.4285714285714286, 131: 2.0, 132: 1.8571428571428572, 133: 1.5714285714285714, 134: 1.5714285714285714, 135: 1.8571428571428572, 136: 1.4285714285714286, 137: 1.8571428571428572, 138: 2.142857142857143, 139: 1.8571428571428572, 140: 1.7142857142857142, 141: 1.5714285714285714, 142: 2.0, 143: 2.2857142857142856, 144: 2.2857142857142856, 145: 2.4285714285714284, 146: 2.142857142857143, 147: 1.5714285714285714, 148: 1.4285714285714286, 149: 1.8571428571428572, 150: 2.4285714285714284, 151: 2.2857142857142856, 152: 1.8571428571428572, 153: 2.2857142857142856, 154: 2.142857142857143, 155: 1.7142857142857142, 156: 2.142857142857143, 157: 1.4285714285714286, 158: 1.7142857142857142, 159: 2.2857142857142856, 160: 1.7142857142857142, 161: 1.5714285714285714, 162: 1.8571428571428572, 163: 1.7142857142857142, 164: 1.1428571428571428, 165: 1.5714285714285714, 166: 1.5714285714285714, 167: 2.142857142857143, 168: 1.7142857142857142, 169: 2.142857142857143, 170: 2.0, 171: 1.8571428571428572, 172: 1.8571428571428572, 173: 2.142857142857143, 174: 2.2857142857142856, 175: 2.142857142857143, 176: 2.0, 177: 1.5714285714285714, 178: 1.7142857142857142, 179: 2.1428571428571 ...
# Clustering 1 Preference score for each dish： {0: 1.8333333333333333, 1: 1.9166666666666667, 2: 1.8333333333333333, 3: 2.0833333333333335, 4: 2.0833333333333335, 5: 1.9166666666666667, 6: 2.0833333333333335, 7: 1.5833333333333333, 8: 1.6666666666666667, 9: 2.0833333333333335, 10: 2.0, 11: 2.0833333333333335, 12: 1.8333333333333333, 13: 2.0, 14: 1.9166666666666667, 15: 1.9166666666666667, 16: 2.0833333333333335, 17: 2.0833333333333335, 18: 1.6666666666666667, 19: 1.75, 20: 2.0833333333333335, 21: 2.0, 22: 1.9166666666666667, 23: 1.9166666666666667, 24: 1.9166666666666667, 25: 1.5, 26: 2.25, 27: 1.5, 28: 1.8333333333333333, 29: 1.8333333333333333, 30: 1.5833333333333333, 31: 2.0, 32: 1.9166666666666667, 33: 1.8333333333333333, 34: 2.25, 35: 2.25, 36: 1.9166666666666667, 37: 2.3333333333333335, 38: 2.0, 39: 1.9166666666666667, 40: 2.0, 41: 1.5833333333333333, 42: 1.9166666666666667, 43: 1.6666666666666667, 44: 1.75, 45: 2.3333333333333335, 46: 2.0, 47: 1.9166666666666667, 48: 1.9166666666666667, 49: 1.6666666666666667, 50: 2.1666666666666665, 51: 2.0, 52: 1.75, 53: 2.1666666666666665, 54: 1.8333333333333333, 55: 1.9166666666666667, 56: 1.9166666666666667, 57: 1.9166666666666667, 58: 2.1666666666666665, 59: 1.5, 60: 2.1666666666666665, 61: 2.1666666666666665, 62: 1.75, 63: 2.25, 64: 1.9166666666666667, 65: 2.3333333333333335, 66: 2.0833333333333335, 67: 2.25, 68: 2.0, 69: 2.1666666666666665, 70: 1.9166666666666667, 71: 2.0833333333333335, 72: 1.75, 73: 2.0, 74: 2.0, 75: 1.8333333333333333, 76: 1.8333333333333333, 77: 2.0, 78: 1.8333333333333333, 79: 1.75, 80: 2.3333333333333335, 81: 1.75, 82: 2.1666666666666665, 83: 1.6666666666666667, 84: 1.9166666666666667, 85: 1.8333333333333333, 86: 1.9166666666666667, 87: 2.1666666666666665, 88: 2.0833333333333335, 89: 2.0833333333333335, 90: 1.6666666666666667, 91: 2.25, 92: 2.0, 93: 2.0, 94: 2.0, 95: 1.75, 96: 2.5, 97: 2.0, 98: 1.5, 99: 2.0, 100: 1.9166666666666667, 101: 2.1666666666666665, 102: 1.9166666666666667, 103: 2.4166666666666665, 104: 2.25, 105: 2.0833333333333335, 106: 1.8333333333333333, 107: 2.25, 108: 1.8333333333333333, 109: 2.25, 110: 2.0, 111: 1.75, 112: 2.0833333333333335, 113: 2.0833333333333335, 114: 2.3333333333333335, 115: 1.75, 116: 1.6666666666666667, 117: 1.75, 118: 2.0, 119: 2.4166666666666665, 120: 1.6666666666666667, 121: 1.75, 122: 1.9166666666666667, 123: 2.25, 124: 2.1666666666666665, 125: 2.4166666666666665, 126: 2.1666666666666665, 127: 2.0833333333333335, 128: 2.3333333333333335, 129: 2.0, 130: 1.8333333333333333, 131: 2.0, 132: 2.0833333333333335, 133: 1.9166666666666667, 134: 2.0833333333333335, 135: 2.0833333333333335, 136: 1.6666666666666667, 137: 2.4166666666666665, 138: 1.8333333333333333, 139: 1.75, 140: 2.0, 141: 1.9166666666666667, 142: 1.4166666666666667, 143: 1.8333333333333333, 144: 1.9166666666666667, 145: 2.0833333333333335, 146: 2.3333333333333335, 147: 2.25, 148: 2.3333333333333335, 149: 2.0833333333333335, 150: 2.3333333333333335, 151: 1.75, 152: 2.1666666666666665, 153: 1.75, 154: 2.25, 155: 2.1666666666666665, 156: 2.0833333333333335, 157: 1.9166666666666667, 158: 1.8333333333333333, 159: 1.8333333333333333, 160: 1.6666666666666667, 161: 1.8333333333333333, 162: 2.0, 163: 2.0, 164: 2.0833333333333335, 165: 1.5, 166: 1.8333333333333333, 167: 2.0833333333333335, 168: 2.1666666666666665, 169: 1.9166666666666667, 170: 1.75, 171: 1.75, 172: 2.1666666666666665, 173: 1.5, 174: 1.75, 175: 1.75, 176: 1.6666666666666667, 177: 2.1666666666666665, 178: 2.4166666666666665, 179: 2.0833333333333335, 180: 1.8333333333333333, 181: 1.8333333333333333, 182: 2.25, 183: 2.0, 184: 2.0, 185: 1.75, 186: 2.5, 187: 1.75, 188: 2.3333333333333335, 189: 1.6666666666666667, 190: 1.5833333333333333, 191: 2.0833333333333335, 192: 1.6666666666666667, 193: 2.3333333333333335, 194: 1.75, 195: 1.8333333333333333, 196: 1.9166666666666667, 197: 2.0, 198: 1.6666666666666667, 199: 1.6666666666666667, 200: 2.3333333333333335, 201: 1.8333333333333333, 202: 2.1666666666666665, 203: ...
# Clustering 2 Preference score for each dish： {0: 2.3333333333333335, 1: 2.111111111111111, 2: 2.3333333333333335, 3: 2.6666666666666665, 4: 2.2222222222222223, 5: 2.3333333333333335, 6: 2.4444444444444446, 7: 2.6666666666666665, 8: 2.3333333333333335, 9: 2.5555555555555554, 10: 2.6666666666666665, 11: 2.6666666666666665, 12: 2.5555555555555554, 13: 2.3333333333333335, 14: 2.111111111111111, 15: 2.6666666666666665, 16: 2.2222222222222223, 17: 2.6666666666666665, 18: 2.0, 19: 2.5555555555555554, 20: 2.5555555555555554, 21: 2.3333333333333335, 22: 2.3333333333333335, 23: 2.6666666666666665, 24: 2.0, 25: 2.111111111111111, 26: 2.2222222222222223, 27: 2.3333333333333335, 28: 3.0, 29: 2.111111111111111, 30: 2.0, 31: 2.4444444444444446, 32: 2.2222222222222223, 33: 2.2222222222222223, 34: 2.0, 35: 1.6666666666666667, 36: 2.5555555555555554, 37: 2.3333333333333335, 38: 1.8888888888888888, 39: 2.4444444444444446, 40: 2.0, 41: 2.5555555555555554, 42: 2.3333333333333335, 43: 2.111111111111111, 44: 1.7777777777777777, 45: 2.7777777777777777, 46: 2.0, 47: 2.6666666666666665, 48: 2.888888888888889, 49: 2.0, 50: 2.111111111111111, 51: 1.5555555555555556, 52: 2.4444444444444446, 53: 2.4444444444444446, 54: 2.0, 55: 2.4444444444444446, 56: 2.3333333333333335, 57: 2.111111111111111, 58: 2.3333333333333335, 59: 2.2222222222222223, 60: 1.8888888888888888, 61: 2.111111111111111, 62: 3.0, 63: 2.2222222222222223, 64: 2.3333333333333335, 65: 1.8888888888888888, 66: 2.7777777777777777, 67: 2.2222222222222223, 68: 2.4444444444444446, 69: 2.0, 70: 2.6666666666666665, 71: 1.8888888888888888, 72: 2.5555555555555554, 73: 2.2222222222222223, 74: 2.111111111111111, 75: 2.6666666666666665, 76: 1.6666666666666667, 77: 2.4444444444444446, 78: 1.7777777777777777, 79: 2.5555555555555554, 80: 1.4444444444444444, 81: 2.2222222222222223, 82: 2.5555555555555554, 83: 2.6666666666666665, 84: 1.8888888888888888, 85: 2.111111111111111, 86: 2.5555555555555554, 87: 2.6666666666666665, 88: 2.4444444444444446, 89: 2.4444444444444446, 90: 2.2222222222222223, 91: 1.7777777777777777, 92: 2.7777777777777777, 93: 2.4444444444444446, 94: 2.111111111111111, 95: 2.5555555555555554, 96: 2.4444444444444446, 97: 2.111111111111111, 98: 2.4444444444444446, 99: 2.6666666666666665, 100: 2.5555555555555554, 101: 2.3333333333333335, 102: 1.8888888888888888, 103: 2.2222222222222223, 104: 2.3333333333333335, 105: 2.2222222222222223, 106: 2.3333333333333335, 107: 1.8888888888888888, 108: 2.4444444444444446, 109: 2.5555555555555554, 110: 1.7777777777777777, 111: 2.111111111111111, 112: 2.4444444444444446, 113: 2.3333333333333335, 114: 2.111111111111111, 115: 2.4444444444444446, 116: 2.3333333333333335, 117: 2.4444444444444446, 118: 2.111111111111111, 119: 2.5555555555555554, 120: 2.6666666666666665, 121: 1.8888888888888888, 122: 2.2222222222222223, 123: 2.2222222222222223, 124: 2.111111111111111, 125: 2.3333333333333335, 126: 2.111111111111111, 127: 2.5555555555555554, 128: 2.6666666666666665, 129: 2.3333333333333335, 130: 2.3333333333333335, 131: 2.6666666666666665, 132: 2.2222222222222223, 133: 2.3333333333333335, 134: 2.4444444444444446, 135: 2.2222222222222223, 136: 2.111111111111111, 137: 2.4444444444444446, 138: 2.4444444444444446, 139: 2.111111111111111, 140: 2.2222222222222223, 141: 2.111111111111111, 142: 2.2222222222222223, 143: 2.0, 144: 1.6666666666666667, 145: 2.111111111111111, 146: 2.2222222222222223, 147: 2.7777777777777777, 148: 2.5555555555555554, 149: 2.4444444444444446, 150: 1.8888888888888888, 151: 2.2222222222222223, 152: 2.6666666666666665, 153: 2.3333333333333335, 154: 1.8888888888888888, 155: 2.111111111111111, 156: 2.4444444444444446, 157: 2.4444444444444446, 158: 2.5555555555555554, 159: 2.4444444444444446, 160: 2.4444444444444446, 161: 2.111111111111111, 162: 2.0, 163: 2.2222222222222223, 164: 2.2222222222222223, 165: 2.111111111111111, 166: 2.0, 167: 2.3333333333333335, 168: 2.3333333333333335, 169: 1.8888888888888888, 170: 2.3333333333333335, 171: 2.4444444444444446, ...
# c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# **Model-1**

# %%
xp.init('C:/xpressmp/bin/xpauth.xpr')

# %% [markdown]
# **Model_1 objective function and constrains- cost as constraints, calculating the maximize preference score, solve the MIP model using xpress**

# %%
model = xp.problem()
max_time=1000
model.addVariable(x)
model.addVariable(y)
model.addVariable(Q)

dw = {0: 0.25, 1: 0.43, 2: 0.32}
Total_preference_score = xp.Sum(dw[p] * y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

model.setObjective(Total_preference_score, sense=xp.maximize)

# A.6 item inclusion
for j in M:
    for l in L:
        for t in T:
            model.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7 maximum number of items per subcategory
for t in T:
    for j in M:
        for l in L:
            if l in {"Main dish", "Side", "Soup", "Breakfast"}:    
                for s in S_l:
                    if ns.get((j,l),0) >= 1:
                       model.addConstraint(
                           xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                       )

# A.8 Minimum Number of Items in a Subcategory
s_l_min = {'dark green','red orange','starch'}
for t in T:
    for j in M:
        for l in L:
            if l == "side":
                for s in s_l_min:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) >= 1, name=f'Minimum_Number_of_Items_in_a_Subcategory_{t}_{j}_{l}_{s}')

# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )

# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        model.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            model.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 10
                )
        if l == "Soup":
            for s in S_l[l]:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
        if l == "Dessert":
            if s == "cake":
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
            else:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 0
                )

# A.16 limiting consecutive repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            model.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items
for p in P:
    for j in M:
        for l in L:
            for t in T:
                if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model.addConstraint(
                nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
            )

# A.23
Q_m = {0:0.3, 1:0.3, 2:0.3}
for p in P:
    for k in K:
        for t in T:
            model.addConstraint(Q[(p, k, t)] <= Q_m[p])

# A.24 meal cost
breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
)
non_breakfast_courses = [l for l in L if l != 'Breakfast']
lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
)
dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
)
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
)

print(f"optimal objective:{model.getObjVal()}")
# Out:
# optimal objective:1e+40

# %%
model.setControl('maxtime', max_time )
print(model.getControl('maxtime'))
best_bound = model.getAttrib('bestbound')
mip_gap = 150*((model.getObjVal()-best_bound)/model.getObjVal())

xp.setOutputEnabled(True)
model.solve()
# Out:
# 1000
# FICO Xpress v9.4.2, Hyper, solve started 16:35:39, Mar 26, 2025
# Heap usage: 18MB (peak 18MB, 3032KB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      26863 rows        17724 cols       209181 elements     17640 entities
# Presolved problem has:
#       9846 rows        10493 cols        78680 elements     10493 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 21MB (peak 38MB, 3032KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.04e-01,  1.00e+30] / [ 1.17e-03,  1.53e+00]
#   RHS and bounds [min,max] : [ 3.00e-01,  2.30e+03] / [ 2.10e-01,  1.00e+01]
#   Objective      [min,max] : [ 2.50e-01,  1.07e+00] / [ 2.86e-01,  1.07e+00]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 8994
#  Number of orbits: 4497, largest orbit: 2
#  Row orbits: 4115, row support: 8230
# Will try to keep branch and bound tree memory usage below 173MB
#  *** Solution found:   100.043889   Time:   0.49    Heuristic: h ***
#  *** Solution found:   101.970913   Time:   0.51    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  342.37234   .0000000 |           factorize
#  D  307.11218   .0000000 |  B  267.22803  267.48489
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 5366 simplex iterations, 1.33s
#         Barrier: 18 barrier and 440 simplex iterations, 0.79s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0        267.361897      P      0     0        .000000     1
# Barrier solved problem
#   18 barrier and 440 simplex iterations in 1.37 seconds at time 1
#
# Final objective                       : 2.673618973317979e+02
#   Max primal violation      (abs/rel) : 1.624e-15 / 1.624e-15
#   Max dual violation        (abs/rel) : 5.518e-15 / 5.518e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P          106.095357   267.361897      3                 60.32%       0      2
# P          106.130913   267.361897      4                 60.30%       0      2
# P          106.166468   267.361897      5                 60.29%       0      2
# P          106.202024   267.361897      6                 60.28%       0      2
# R          217.671468   267.288575      7                 18.56%       0      2
# R          220.874325   267.288575      8                 17.36%       0      2
# R          239.616151   267.288575      9                 10.35%       0      3
# R          239.831151   267.288575     10                 10.27%       0      3
# R          240.044563   267.288575     11                 10.19%       0      3
# R          240.257897   267.288575     12                 10.11%       0      3
# R          240.472897   267.288575     13                 10.03%       0      3
# R          240.686706   267.288575     14                  9.95%       0      3
# R          240.903849   267.288575     15                  9.87%       0      3
# R          241.118571   267.288575     16                  9.79%       0      3
# R          241.723016   267.288575     17                  9.56%       0      3
# R          241.830754   267.288575     18                  9.52%       0      4
# R          243.257897   267.288575     19                  8.99%       0      4
# R          243.794484   267.288575     20                  8.79%       0      4
# R          243.794881   267.288575     21                  8.79%       0      4
# R          243.866548   267.288575     22                  8.76%       0      4
# R          243.901825   267.288575     23                  8.75%       0      4
# R          243.974048   267.288575     24                  8.72%       0      4
# R          246.333294   267.288575     25                  7.84%       0      5
# R          246.654206   267.288575     26                  7.72%       0      5
# R          248.084325   267.288575     27                  7.18%       0      5
# R          248.191548   267.288575     28                  7.14%       0      5
#    1  K    248.191548   267.288575     28      7      0    7.14%    1080      6
#    2  K    248.191548   267.288575     28      7      6    7.14%    1098      6
#    3  K    248.191548   267.288575     28      4      6    7.14%    1059      6
#    4  K    248.191548   266.392739     28     14      4    6.83%    1038      7
#    5  K    248.191548   266.392739     28      3     12    6.83%     805      7
#    6  K    248.191548   266.392739     28      0      2    6.83%     833      7
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 5
# Cut elements in the matrix : 9333
# Will try to keep branch and bound tree memory usage below 64MB
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 54MB (peak 100MB, 9002KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1   248.191548   266.392739     28      2      1    6.83%     833     13
#        2   248.191548   266.392739     28      2      3    6.83%     816     14
#        3   248.191548   265.881314     28      3      4    6.65%     755     16
#        4   248.191548   265.881314     28      4      4    6.65%     788     17
# Will try to keep branch and bound tree memory usage below 5.4GB
#        5   248.191548   265.881314     28      5      5    6.65%     776     17
#        6   248.191548   265.881314     28      6      5    6.65%     774     17
#        7   248.191548   265.713490     28      7      5    6.59%     788     18
#        8   248.191548   265.713490     28      7      6    6.59%     776     18
#        9   248.191548   265.713490     28      9      7    6.59%     737     19
#       10   248.191548   265.713490     28     10      3    6.59%     720     19
#       20   248.191548   265.690597     28     19      8    6.59%     835     21
#       30   248.191548   265.690597     28     25     13    6.59%     700     26
#       40   248.191548   265.690597     28     28     16    6.59%     677     29
#       50   248.191548   265.523149     28     34     20    6.53%     728     32
#       60   248.191548   265.523149     28     46     19    6.53%     765     36
#       70   248.191548   265.523149     28     49     23    6.53%     702     38
#       80   248.191548   265.523149     28     53     27    6.53%     741     41
#       90   248.191548   265.523149     28     56     22    6.53%     683     44
#      100   248.191548   265.523149     28     82     26    6.53%     672     49
# Elapsed time (sec): 67, estimated tree completion: 0.00000
# Heap usage: 217MB (peak 217MB, 12MB system)
# B&B tree size: 2.6MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200   248.191548   265.523149     28    129     84    6.53%     573     67
#      300   248.191548   265.523149     28    210     73    6.53%     469     83
#      400   248.191548   265.523149     28    281    181    6.53%     381     93
# d    441   249.895317   265.523149     29    346    206    5.89%       0     96
#      500   249.895317   265.523149     29    376    123    5.89%     304    101
#      600   249.895317   265.523149     29    393    119    5.89%     348    109
#      700   249.895317   265.523149     29    422    160    5.89%     387    119
#      800   249.895317   265.523149     29    606    159    5.89%     601    131
#      900   249.895317   265.523149     29    634    234    5.89%     320    138
#     1000   249.895317   265.523149     29    673    196    5.89%     430    145
#     1100   249.895317   265.523149     29    707    212    5.89%     526    151
#     1200   249.895317   265.523149     29    916    450    5.89%     152    156
#     1300   249.895317   265.523149     29    981     15    5.89%     762    163
#     1400   249.895317   265.523149     29    981    376    5.89%     333    183
#     1500   249.895317   265.523149     29   1417     23    5.89%     698    201
#     1600   249.895317   264.941042     29   1463     43    5.68%     622    232
#     1700   249.895317   264.941042     29   1551     32    5.68%     589    249
#     1801   249.895317   264.941042     29   1598     52    5.68%     503    262
#     1902   249.895317   264.941042     29   1622     51    5.68%     515    279
#     2002   249.895317   264.941042     29   1688     70    5.68%     419    291
# Elapsed time (sec): 303, estimated tree completion: 0.00000
# Heap usage: 406MB (peak 406MB, 16MB system)
# B&B tree size: 25MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2103   249.895317   264.941042     29   1768     80    5.68%     435    303
#     2203   249.895317   264.941042     29   1833     70    5.68%     450    314
#     2303   249.895317   264.941042     29   1833     65    5.68%     489    326
# b   2326   251.147857   264.941042     30   1833     72    5.21%       0    330
# d   2365   253.219960   264.941042     31   1833     75    4.42%       0    336
#     2403   253.219960   264.941042     31   1833     77    4.42%     419    340
#     2744   253.219960   264.941042     31   1621      1    4.42%       2    346
#     2844   253.219960   264.941042     31   1775     89    4.42%     369    355
#     2945   253.219960   264.941042     31   1794    112    4.42%     391    363
#     3045   253.219960   264.941042     31   1794    142    4.42%     387    371
#     3145   253.219960   264.941042     31   1794     96    4.42%     345    380
#     3245   253.219960   264.941042     31   1794    179    4.42%     463    387
#     3345   253.219960   264.941042     31   1794    189    4.42%     366    393
#     3445   253.219960   264.941042     31   1891    164    4.42%     420    400
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:    9843 rows   10485 columns     87828 elements
# Presolve dropped   :       8 rows       8 columns       185 elements
# Will try to keep branch and bound tree memory usage below 5.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve, 406s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  369.46766   .0000000 |           factorize
#  D  322.78849   .0000000 |  B  267.13136  267.13136
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 1653407 simplex iterations, 1.01s
#         Barrier: 16 barrier and 434 simplex iterations, 0.50s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0        267.131363      P      0     0        .000000   407
# Barrier solved problem
#   16 barrier and 434 simplex iterations in 1.02 seconds at time 407
#
# Final objective                       : 2.671313630178961e+02
#   Max primal violation      (abs/rel) : 1.499e-15 / 1.499e-15
#   Max dual violation        (abs/rel) : 6.439e-15 / 6.439e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K    253.219960   264.869391     31     10      1    4.40%     970    411
# P          253.253690   264.869391     32                  4.39%       0    411
# P          253.289524   264.869391     33                  4.37%       0    411
#    2  K    253.289524   264.869391     33     18      7    4.37%     786    412
#    3  K    253.289524   264.629513     33     28     17    4.29%     803    412
# P          254.074603   264.629513     34                  3.99%       0    412
# P          254.181627   264.629513     35                  3.95%       0    412
# P          254.217460   264.629513     36                  3.93%       0    412
# P          254.252302   264.629513     37                  3.92%       0    412
#    4  K    254.252302   264.445171     37     12     27    3.85%     810    413
# P          254.394524   264.445171     38                  3.80%       0    413
# P          254.894524   264.445171     39                  3.61%       0    413
# P          255.001190   264.445171     40                  3.57%       0    413
#    5  K    255.001190   264.014743     40     23     11    3.41%     788    414
# P          255.175833   264.014743     41                  3.35%       0    414
# P          255.783333   264.014743     42                  3.12%       0    414
# P          255.819167   264.014743     43                  3.10%       0    414
# P          256.535833   264.014743     44                  2.83%       0    414
# P          256.536468   264.014743     45                  2.83%       0    414
# P          256.680397   264.014743     46                  2.78%       0    414
# P          256.752937   264.014743     47                  2.75%       0    414
#    6  K    256.752937   264.014743     47     30     26    2.75%     639    414
#    7  K    256.752937   264.014743     47      3     26    2.75%     737    414
#    8  K    256.752937   264.014743     47      0      3    2.75%     717    415
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# P          256.823810   264.014743     48                  2.72%       0    422
# P          256.895238   264.014743     49                  2.70%       0    422
# P          257.003571   264.014743     50                  2.66%       0    422
#
# Cuts in the matrix         : 11
# Cut elements in the matrix : 1037
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 58MB (peak 461MB, 9018KB system)
# Elapsed time (sec): 422, estimated tree completion: 0.00000
# Heap usage: 58MB (peak 461MB, 9018KB system)
# B&B tree size: 96k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     3488   257.003571   264.014743     50      2      1    2.66%     717    422
#     3489   257.003571   264.014743     50      2      3    2.66%     647    423
#     3490   257.003571   264.014743     50      2      4    2.66%     647    424
#     3491   257.003571   264.014743     50      3      3    2.66%     655    425
#     3492   257.003571   264.014743     50      3      5    2.66%     658    425
#     3493   257.003571   263.870151     50      4      4    2.60%     630    426
#     3494   257.003571   263.870151     50      4      6    2.60%     658    426
#     3495   257.003571   263.870151     50      5      4    2.60%     659    426
#     3496   257.003571   263.857684     50      6      7    2.60%     657    427
#     3497   257.003571   263.792095     50      7      5    2.57%     683    428
#     3507   257.003571   263.647503     50     13      7    2.52%     701    433
#     3517   257.003571   263.647503     50     22      8    2.52%     736    437
#     3527   257.003571   263.647503     50     31     10    2.52%     660    441
#     3537   257.003571   263.611632     50     41     10    2.51%     673    445
#     3547   257.003571   263.611632     50     51     11    2.51%     775    448
#     3557   257.003571   263.611632     50     61     13    2.51%     580    451
#     3567   257.003571   263.611632     50     71     14    2.51%     649    454
#     3577   257.003571   263.611632     50     81     16    2.51%     607    456
#     3587   257.003571   263.611632     50     91     15    2.51%     624    460
# Elapsed time (sec): 492, estimated tree completion: 0.00000
# Heap usage: 406MB (peak 461MB, 17MB system)
# B&B tree size: 2.5MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     3687   257.003571   263.611632     50    191     26    2.51%     611    492
#     3787   257.003571   263.611632     50    291     41    2.51%     483    516
#     3887   257.003571   263.611632     50    391     46    2.51%     520    538
#     3987   257.003571   263.611632     50    491     63    2.51%     455    564
#     4087   257.003571   263.611632     50    591     51    2.51%     633    587
#     4187   257.003571   263.611632     50    691     93    2.51%     462    605
#     4287   257.003571   263.611632     50    791    108    2.51%     436    623
#     4387   257.003571   263.611632     50    891    124    2.51%     281    638
#     4487   257.003571   263.611632     50    991    129    2.51%     515    652
#     4587   257.003571   263.611632     50   1091    114    2.51%     377    667
#     4687   257.003571   263.611632     50   1191     99    2.51%     530    680
#     4787   257.003571   263.611632     50   1291    150    2.51%     415    694
#     4887   257.003571   263.611632     50   1391    157    2.51%     378    708
#     4987   257.003571   263.611632     50   1491    175    2.51%     267    720
#     5087   257.003571   263.611632     50   1588    209    2.51%     347    732
#     5187   257.003571   263.611632     50   1683    208    2.51%     245    747
#     5287   257.003571   263.611632     50   1773    185    2.51%     364    761
#     5387   257.003571   263.611632     50   1858    208    2.51%     349    772
#     5487   257.003571   263.611632     50   1941     21    2.51%     537    786
#     5587   257.003571   263.611632     50   2001    224    2.51%     322    809
# Elapsed time (sec): 828, estimated tree completion: 0.00000
# Heap usage: 593MB (peak 593MB, 21MB system)
# B&B tree size: 25MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     5687   257.003571   263.591645     50   2088    255    2.50%     398    828
#     5787   257.003571   263.591645     50   2128     30    2.50%     434    850
#     5887   257.003571   263.591645     50   2155     16    2.50%     581    874
#     5987   257.003571   263.591645     50   2246     21    2.50%     556    898
#     6087   257.003571   263.591645     50   2308     27    2.50%     490    921
#     6187   257.003571   263.591645     50   2340     44    2.50%     461    947
#     6287   257.003571   263.591645     50   2423     32    2.50%     492    968
#     6387   257.003571   263.591645     50   2473     32    2.50%     628    994
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
#  *** Search unfinished ***    Time:  1000.31 Nodes:       6405
# Final MIP objective                   : 2.570035714285717e+02
# Final MIP bound                       : 2.635916450725653e+02
#   Solution time / primaldual integral :   1000.31s/  4.070969%
#   Number of solutions found / nodes   :        50 /      6405
#   Max primal violation      (abs/rel) : 3.244e-14 / 3.244e-14
#   Max integer violation     (abs    ) : 3.244e-14
# (<SolveStatus.STOPPED: 1>, <SolStatus.FEASIBLE: 2>)

# %% [markdown]
# **Calculate cost and nutrition deviation score**

# %%
x_opt = model.getSolution(x)
y_opt = model.getSolution(y)
Q_opt = { (p, k, t): model.getSolution(Q[p, k, t]) for p in P for k in K for t in T }

optimal_total_cost = sum(cost[i] * x_opt[i, j, t] for i in I for j in M for t in T)
optimal_nutrition_deviation = sum(Q_opt.get((p, k, t), 0) for p in P for k in K for t in T)

print(f"Optimal Total Cost: {optimal_total_cost}")
print(f"Optimal Nutrition Deviation Score: {optimal_nutrition_deviation}")
# Out:
# Optimal Total Cost: 427.56000000000023
# Optimal Nutrition Deviation Score: 25.2

# %% [markdown]
# **Save the optimal menu**

# %%
y_solution = {key: model.getSolution(var) for key, var in y.items()}

# show the items that selected
selected_y = {key: value for key, value in y_solution.items() if value > 0.5}

df_y = pd.DataFrame([
    {"Item": key[0], "Guest": key[1], "Meal": key[2], "Time": key[3], "Value": value}
    for key, value in selected_y.items()
])
df_y.to_csv("model1_y_result.csv", index=False)

# preference_scores = {}

# for t in T:
#     score = 0
#     for p in P:
#         for j in M:
#             for i in I:
#                 score += y_solution[(i, p, j, t)] * pi[p][i]
#     preference_scores[t] = score
    
# df = pd.DataFrame(list(preference_scores.items()), columns=['Day', 'Preference Score'])

# df.to_csv('model1_preference_scores.csv', index=False)

# %% [markdown]
# **model 2--- Goal Programming Approach toDiscover Trade-offs Among theNumber of Meal Swipes, Violationsin the HEG Constraints, and Patron Preferences**

# %% [markdown]
# stage 1----Minimize the maximum total weighted deviation of the HEG constraints

# %%
# add variables and parameters
max_time=1000
WN = 3
N = 3 # Maximum daily edible parameters
M_ld = ['lunch','dinner']
nm = {0: 13, 1: 13, 2:13}  # Total number of swipes per customer type---1 week
wp = { # wp[p][k]
    0: {'calories': 0.5,'cholesterol':0.2,'sodium':0.1, 'dietary_fiber': 0.2},  # man - high calories
    1: {'calories': 0.2, 'cholesterol':0.2,'sodium':0.2, 'dietary_fiber': 0.4},  #Female - high dietary_fiber
    2: {'calories': 0.25, 'cholesterol':0.25,'sodium':0.2, 'dietary_fiber': 0.25}  # Blend type, balance nutrition and taste
}
u = {
    (p, j, t): xp.var(
        vartype=xp.binary,
        name=f'u_{p}_{j}_{t}'
    )
    for p in P for j in M_ld for t in T
}
Qmax = {
    p: xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Qmax_{p}'
    )
    for p in P 
}

stage1 = xp.problem()
stage1.addVariable(x)
stage1.addVariable(y)
stage1.addVariable(Qmax)
stage1.addVariable(Q)
stage1.addVariable(u)

Total_variation_1 = xp.Sum(Qmax[p]/2 for p in P)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

stage1.setObjective(Total_variation_1, sense=xp.minimize)

# A.6 item inclusion
for j in M:
    for l in L:
        for t in T:
            stage1.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7 maximum number of items per subcategory
for t in T:
    for j in M:
        for l in L:
            if l in {"Main dish", "Side", "Soup", "Breakfast"}:    
                for s in S_l:
                    if ns.get((j,l),0) >= 1:
                       stage1.addConstraint(
                           xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                       )

# A.8 Minimum Number of Items in a Subcategory
s_l_min = {'dark green','red orange','starch'}
for t in T:
    for j in M:
        for l in L:
            if l == "side":
                for s in s_l_min:
                    stage1.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) >= 1, name=f'Minimum_Number_of_Items_in_a_Subcategory_{t}_{j}_{l}_{s}')

# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    stage1.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    stage1.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    stage1.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            stage1.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            stage1.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )

# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        stage1.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            stage1.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                stage1.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                stage1.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 10
                )
        if l == "Soup":
            for s in S_l[l]:
                stage1.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
        if l == "Dessert":
            if s == "cake":
                stage1.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
            else:
                stage1.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 0
                )

# A.16 limiting consecutive repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            stage1.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            stage1.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                stage1.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items
for p in P:
    for j in M:
        for l in L:
            for t in T:
                if ns.get((j,l),0) >= 1:
                    stage1.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            stage1.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            stage1.addConstraint(
                nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
            )

# A.23
for p in P:
    for k in K:
        for t in T:
            stage1.addConstraint(Q[(p, k, t)] <= Qmax[p])

# A.24 meal cost
breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
stage1.addConstraint(
    xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
)
non_breakfast_courses = [l for l in L if l != 'Breakfast']
lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
stage1.addConstraint(
    xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
)
dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
stage1.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
)
stage1.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
)

# C.1
for p in P:
    for j in M_ld:
            for t in T:
                stage1.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I) <= 3 * u[(p, j, t)]
                    )

# C.2
for p in P:
    stage1.addConstraint(xp.Sum(u[(p,j,t)] for j in M_ld for t in T) == nm[p])

# C.3
def nw(t, T, c):
    return (t + c) % len(T)
for p in P:
    for t in T:
            stage1.addConstraint(
                    xp.Sum(wp[p][k]* Q[(p,k, nw(t, T, c))] for k in K for c in range(1, WN+1)) <= Qmax[p]
                )

# %%
stage1.setControl('maxtime', max_time )
print(stage1.getControl('maxtime'))
best_bound = stage1.getAttrib('bestbound')
mip_gap = 150*((stage1.getObjVal()-best_bound)/stage1.getObjVal())


xp.setOutputEnabled(True)
stage1.solve()
# Out:
# 1000
# FICO Xpress v9.4.2, Hyper, solve started 1:16:10, Mar 28, 2025
# Heap usage: 18MB (peak 18MB, 3035KB system)
# Minimizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = 1
# Original problem has:
#      26929 rows        17769 cols       218442 elements     17682 entities
# Presolved problem has:
#      10227 rows        10853 cols        88571 elements     10766 entities
# Presolve finished in 0 seconds
# Heap usage: 21MB (peak 38MB, 3035KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+30] / [ 5.86e-04,  1.95e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.30e+03] / [ 2.10e-01,  1.69e+02]
#   Objective      [min,max] : [ 5.00e-01,  5.00e-01] / [ 5.00e-01,  5.00e-01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 2, support set: 9244
#  Number of orbits: 4634, largest orbit: 4
#  Row orbits: 4264, row support: 8570
# Will try to keep branch and bound tree memory usage below 132MB
#  *** Solution found:     2.700000   Time:   0.40    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D -1.250E-04   .0000000 |           factorize
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 1623 simplex iterations, 0.45s
#         Barrier: 10 barrier and 0 simplex iterations, 0.47s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1623           .000000      P      0     0        .000000     0
# Dual solved problem
#   1623 simplex iterations in 0.48 seconds at time 0
#
# Final objective                       : 0.000000000000000e+00
#   Max primal violation      (abs/rel) : 1.110e-16 / 5.684e-17
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# q             .432101      .000000      2               0.432101       0      2
# d             .417223      .000000      3               0.417223       0      2
# R             .375000      .000000      4                 0.375        0      2
# R             .361929      .000000      5               0.361929       0      2
#    1  K       .361929      .000000      5     95      0 0.361929     104      2
#    2  K       .361929      .000000      5    173     73 0.361929     139      2
# q             .244194      .000000      6               0.244194       0      3
#    3  K       .244194      .000000      6    200    153 0.244194     191      3
#    4  K       .244194      .000000      6    196    193 0.244194     189      3
#    5  K       .244194      .000000      6    209    208 0.244194     200      3
#    6  K       .244194      .000000      6    187    194 0.244194     208      4
#    7  K       .244194      .000000      6    200    189 0.244194     207      4
#    8  K       .244194      .000000      6    235    188 0.244194     208      5
#    9  K       .244194      .000000      6    203    228 0.244194     225      5
# R             .221766      .000000      7               0.221766       0      6
# R             .184519      .000000      8               0.184519       0      6
# R             .180357      .000000      9               0.180357       0      6
#   10  K       .180357      .000000      9    196    206 0.180357     234      6
#   11  K       .180357      .000000      9    268    202 0.180357     231      6
#   12  K       .180357      .000000      9    184    265 0.180357     221      7
#   13  K       .180357      .000000      9    182    170 0.180357     222      7
#   14  K       .180357      .000000      9    209    185 0.180357     215      7
#   15  K       .180357      .000000      9    158    382 0.180357     225      8
#   16  G       .180357      .000000      9    119      4 0.180357     200      8
#   17  G       .180357      .000000      9    125    234 0.180357     207      8
# Heuristic search 'R' started
# R             .159643      .000000     10               0.159643       0      9
# Heuristic search 'R' stopped
# M             .145332      .000000     11               0.145332       0      9
# M             .128862      .000000     12               0.128862       0      9
# M             .117536      .000000     13               0.117536       0      9
# M             .106232      .000000     14               0.106232       0      9
# M             .094026      .000000     15               0.094026       0      9
# M             .083242      .000000     16               0.083242       0      9
# M             .071250      .000000     17               0.07125        0      9
# M             .060964      .000000     18               0.060964       0      9
# M             .050250      .000000     19               0.05025        0      9
#
# Cuts in the matrix         : 65
# Cut elements in the matrix : 12665
# Will try to keep branch and bound tree memory usage below 5.4GB
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 51MB (peak 96MB, 8978KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1      .050250      .000000     19      2      1 0.05025       88     14
#        2      .050250      .000000     19      2      3 0.05025       92     14
#        3      .050250      .000000     19      3      3 0.05025      118     14
#        4      .050250      .000000     19      4      4 0.05025       92     14
#        5      .050250      .000000     19      5      4 0.05025      119     14
#        6      .050250      .000000     19      6      4 0.05025      109     14
#        7      .050250      .000000     19      7      4 0.05025      101     15
#        8      .050250      .000000     19      8      5 0.05025      117     15
#        9      .050250      .000000     19      9      6 0.05025      106     15
#       10      .050250      .000000     19     10      5 0.05025      122     15
#       20      .050250      .000000     19     18      6 0.05025      151     15
#       30      .050250      .000000     19     26      9 0.05025      100     16
#       40      .050250      .000000     19     33     14 0.05025       88     17
#       50      .050250      .000000     19     41     14 0.05025       97     17
#       60      .050250      .000000     19     50     15 0.05025      109     17
#       70      .050250      .000000     19     58     17 0.05025       94     18
#       80      .050250      .000000     19     64     27 0.05025      111     18
#       90      .050250      .000000     19     71     31 0.05025       89     19
#      100      .050250      .000000     19     78     27 0.05025      100     19
# Elapsed time (sec): 24, estimated tree completion: 0.00000
# Heap usage: 205MB (peak 205MB, 12MB system)
# B&B tree size: 6.9MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200      .050250      .000000     19    155     50 0.05025       63     24
#      300      .050250      .000000     19    220     84 0.05025       76     26
#      400      .050250      .000000     19    298    128 0.05025       84     29
#      500      .050250      .000000     19    372    124 0.05025       60     31
#      603      .050250      .000000     19    560    156 0.05025       42     33
#      703      .050250      .000000     19    614    131 0.05025       67     36
#      803      .050250      .000000     19    656    174 0.05025       19     39
#      904      .050250      .000000     19    662    128 0.05025       72     43
#     1004      .050250      .000000     19    721     44 0.05025       88     46
#     1105      .050250      .000000     19    749    173 0.05025       72     48
#     1207      .050250      .000000     19    879    141 0.05025       56     50
#     1308      .050250      .000000     19   1039    160 0.05025       39     52
#     1409      .050250      .000000     19   1053     84 0.05025       61     53
#     1509      .050250      .000000     19   1204    180 0.05025       29     54
#     1609      .050250      .000000     19   1204     60 0.05025      120     56
# b   1667      .035375      .000000     20   1275    279 0.035375       0     57
# a   1674      .034875      .000000     21   1275    279 0.034875       0     57
# b   1681      .033875      .000000     22   1275    278 0.033875       0     57
#     1865      .033875      .000000     22   1167      1 0.033875       2     57
#     1969      .033875      .000000     22   1230    185 0.033875      87     58
# Elapsed time (sec): 60, estimated tree completion: 0.00000
# Heap usage: 462MB (peak 462MB, 17MB system)
# B&B tree size: 39MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2072      .033875      .000000     22   1309    127 0.033875      27     60
#     2176      .033875      .000000     22   1316    209 0.033875      68     61
# b   2211      .031500      .000000     23   1340    277  0.0315        0     61
# E   2212      .031464      .000000     24   1340    277 0.031464       0     62
#     2276      .031464      .000000     24   1356    137 0.031464      66     62
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:    9966 rows   10526 columns     98028 elements
# Presolve dropped   :     326 rows     327 columns       973 elements
# Symmetric problem: generators: 1, support set: 112
#  Number of orbits: 56, largest orbit: 2
#  Row orbits: 50, row support: 100
# Will try to keep branch and bound tree memory usage below 5.4GB
# Crash basis containing 2576 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
# 391099           .000000      D    220     0        .000000    64
# 394529           .000000      P      0     0        .000000    64
# Optimal solution found
# Dual solved problem
#   394529 simplex iterations in 0.79 seconds at time 64
#
# Final objective                       : 0.000000000000000e+00
#   Max primal violation      (abs/rel) : 4.274e-15 / 2.188e-15
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P             .030500      .000000     25                0.0305        0     66
# P             .030000      .000000     26                  0.03        0     66
# P             .025839      .000000     27               0.025839       0     66
#    1  K       .025839      .000000     27    128     65 0.025839      92     67
#    2  K       .025839      .000000     27    197     92 0.025839     185     68
#    3  K       .025839      .000000     27    209    179 0.025839     222     68
#    4  K       .025839      .000000     27    179    226 0.025839     221     69
#    5  K       .025839      .000000     27    195    160 0.025839     225     70
#    6  K       .025839      .000000     27    191    207 0.025839     215     70
#    7  K       .025839      .000000     27    185    180 0.025839     236     70
#    8  K       .025839      .000000     27    171    185 0.025839     255     71
#    9  K       .025839      .000000     27    164    185 0.025839     238     71
# P             .025217      .000000     28               0.025217       0     71
#   10  K       .025217      .000000     28    171    154 0.025217     243     72
#   11  K       .025217      .000000     28    192    170 0.025217     234     73
# P             .022467      .000000     29               0.022467       0     73
#   12  K       .022467      .000000     29    225    191 0.022467     256     73
#   13  K       .022467      .000000     29    202    221 0.022467     265     74
#   14  K       .022467      .000000     29    183    198 0.022467     257     74
#   15  K       .022467      .000000     29    221    182 0.022467     252     75
#   16  K       .022467      .000000     29    177    228 0.022467     264     75
#   17  K       .022467      .000000     29    205    173 0.022467     248     76
#   18  K       .022467      .000000     29    204    220 0.022467     235     76
#   19  K       .022467      .000000     29    197    186 0.022467     206     77
#   20  K       .022467      .000000     29    202    202 0.022467     236     77
#   21  K       .022467      .000000     29    173    205 0.022467     204     78
#   22  K       .022467      .000000     29    228    172 0.022467     215     78
#   23  K       .022467      .000000     29    205    220 0.022467     238     79
#   24  K       .022467      .000000     29    222    211 0.022467     232     79
#   25  K       .022467      .000000     29    198    221 0.022467     233     80
#   26  K       .022467      .000000     29    168    202 0.022467     233     80
#   27  K       .022467      .000000     29    193    175 0.022467     208     80
#   28  K       .022467      .000000     29    175    181 0.022467     218     81
#   29  K       .022467      .000000     29    168    166 0.022467     237     81
#   30  K       .022467      .000000     29    205    391 0.022467     236     82
#   31  G       .022467      .000000     29     50      4 0.022467     219     83
#   32  G       .022467      .000000     29     57    125 0.022467     210     83
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# M             .012000      .000000     30                 0.012        0     84
#
# Cuts in the matrix         : 28
# Cut elements in the matrix : 2931
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 48MB (peak 487MB, 8996KB system)
# Elapsed time (sec): 88, estimated tree completion: 0.00000
# Heap usage: 48MB (peak 487MB, 8996KB system)
# B&B tree size: 96k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2345      .012000      .000000     30      2      1   0.012      107     88
#     2346      .012000      .000000     30      2      3   0.012      149     88
#     2347      .012000      .000000     30      2      3   0.012      162     88
#     2348      .012000      .000000     30      2      4   0.012      149     88
#     2349      .012000      .000000     30      3      4   0.012      162     89
#     2350      .012000      .000000     30      4      4   0.012      118     89
#     2351      .012000      .000000     30      4      4   0.012      134     89
#     2352      .012000      .000000     30      4      5   0.012      195     89
#     2353      .012000      .000000     30      5      5   0.012      152     89
#     2354      .012000      .000000     30      6      6   0.012      146     90
#     2364      .012000      .000000     30     14      7   0.012      161     92
#     2374      .012000      .000000     30     20      7   0.012      156     93
#     2384      .012000      .000000     30     29      9   0.012      178     94
#     2394      .012000      .000000     30     39      7   0.012      169     96
#     2404      .012000      .000000     30     49     10   0.012      185     98
#     2414      .012000      .000000     30     59      9   0.012      201     99
#     2424      .012000      .000000     30     69     12   0.012      121    100
#     2434      .012000      .000000     30     79     12   0.012      164    101
#     2444      .012000      .000000     30     89     13   0.012      137    102
# Elapsed time (sec): 116, estimated tree completion: 0.00000
# Heap usage: 438MB (peak 487MB, 19MB system)
# B&B tree size: 7.4MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2544      .012000      .000000     30    189     18   0.012      151    116
#     2644      .012000      .000000     30    289     32   0.012      157    124
#     2744      .012000      .000000     30    383     44   0.012      115    131
#     2844      .012000      .000000     30    465     39   0.012      149    136
#     2944      .012000      .000000     30    550     53   0.012      152    142
#     3044      .012000      .000000     30    635     69   0.012      107    147
#     3144      .012000      .000000     30    717     61   0.012      110    152
#     3244      .012000      .000000     30    791     72   0.012      137    156
#     3344      .012000      .000000     30    886     95   0.012       67    161
#     3444      .012000      .000000     30    966    120   0.012       44    166
#     3544      .012000      .000000     30   1014     81   0.012      127    169
#     3644      .012000      .000000     30   1056     87   0.012      126    173
#     3744      .012000      .000000     30   1089     81   0.012      157    177
#     3844      .012000      .000000     30   1186     93   0.012      150    180
#     3946      .012000      .000000     30   1213    186   0.012       36    183
#     4052      .012000      .000000     30   1258    199   0.012       29    185
#     4152      .012000      .000000     30   1355     93   0.012       89    189
#     4252      .012000      .000000     30   1377    119   0.012       47    193
#     4353      .012000      .000000     30   1394    104   0.012       91    198
#     4453      .012000      .000000     30   1412    115   0.012      128    202
# Elapsed time (sec): 205, estimated tree completion: 0.00000
# Heap usage: 680MB (peak 680MB, 24MB system)
# B&B tree size: 58MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4553      .012000      .000000     30   1463    120   0.012      116    205
#     4653      .012000      .000000     30   1477    123   0.012       88    208
#     4753      .012000      .000000     30   1643    106   0.012      141    211
#     4853      .012000      .000000     30   1701    134   0.012       79    215
#     4953      .012000      .000000     30   1779    117   0.012      145    219
#     5053      .012000      .000000     30   1783    157   0.012       59    221
#     5153      .012000      .000000     30   1794    164   0.012       31    223
#     5257      .012000      .000000     30   1819    189   0.012       38    226
#     5357      .012000      .000000     30   2239    108   0.012      121    229
#     5460      .012000      .000000     30   2334    210   0.012       27    231
#     5560      .012000      .000000     30   2340    149   0.012      146    235
#     5661      .012000      .000000     30   2474      1   0.012        2    238
#     5761      .012000      .000000     30   2484    108   0.012      132    242
#     5861      .012000      .000000     30   2486    112   0.012      134    246
#     5961      .012000      .000000     30   2537    132   0.012      108    250
#     6062      .012000      .000000     30   2540    177   0.012       31    254
#     6163      .012000      .000000     30   2564    190   0.012       21    258
#     6267      .012000      .000000     30   2567    121   0.012      102    260
#     6367      .012000      .000000     30   2680    155   0.012       92    263
#     6467      .012000      .000000     30   2679    157   0.012       73    265
# Elapsed time (sec): 268, estimated tree completion: 0.00000
# Heap usage: 709MB (peak 709MB, 24MB system)
# B&B tree size: 84MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6567      .012000      .000000     30   2772    122   0.012      134    268
#     6667      .012000      .000000     30   2901    163   0.012       65    270
#     6767      .012000      .000000     30   2915    102   0.012      101    273
#     6867      .012000      .000000     30   2920    134   0.012      163    276
#     6967      .012000      .000000     30   2920    111   0.012      127    279
#     7067      .012000      .000000     30   2935    126   0.012       88    281
#     7174      .012000      .000000     30   3050    285   0.012       12    284
#     7274      .012000      .000000     30   3113    142   0.012      148    287
#     7379      .012000      .000000     30   3142    306   0.012       10    289
#     7479      .012000      .000000     30   3190    120   0.012      128    291
#     7582      .012000      .000000     30   3251    193   0.012       31    293
#     7683      .012000      .000000     30   3420    146   0.012      131    296
#     7783      .012000      .000000     30   3744    106   0.012      173    300
#     7883      .012000      .000000     30   3822     96   0.012      170    305
#     7983      .012000      .000000     30   3824    142   0.012      131    308
#     8084      .012000      .000000     30   3849    121   0.012       96    311
#     8184      .012000      .000000     30   3909    131   0.012      105    314
#     8284      .012000      .000000     30   3946    160   0.012       89    316
#     8384      .012000      .000000     30   4012    122   0.012      133    318
#     8484      .012000      .000000     30   4066    165   0.012       69    320
# Elapsed time (sec): 323, estimated tree completion: 0.00000
# Heap usage: 744MB (peak 744MB, 24MB system)
# B&B tree size: 108MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     8584      .012000      .000000     30   4138    151   0.012       61    323
#     8684      .012000      .000000     30   4196    181   0.012       74    325
#     8784      .012000      .000000     30   4218    163   0.012       59    326
#     8885      .012000      .000000     30   4227    195   0.012       73    328
#     8985      .012000      .000000     30   4241    210   0.012       61    330
#     9085      .012000      .000000     30   4265    131   0.012      125    332
#     9185      .012000      .000000     30   4265    102   0.012      158    334
#     9285      .012000      .000000     30   4312    170   0.012       50    336
#     9386      .012000      .000000     30   4504    183   0.012       82    337
#     9487      .012000      .000000     30   4536    205   0.012       29    339
#     9589      .012000      .000000     30   4536    236   0.012       29    340
#     9689      .012000      .000000     30   4588    120   0.012      164    341
#     9791      .012000      .000000     30   4750    175   0.012       34    343
#     9891      .012000      .000000     30   4770    116   0.012      146    344
#     9994      .012000      .000000     30   4815    246   0.012       21    345
#    10097      .012000      .000000     30   4892    245   0.012       25    347
#    10200      .012000      .000000     30   4993    161   0.012       60    349
#    10300      .012000      .000000     30   5145    116   0.012      127    352
#    10400      .012000      .000000     30   5316    194   0.012       47    355
#    10500      .012000      .000000     30   5351    122   0.012       92    357
# Elapsed time (sec): 359, estimated tree completion: 0.00000
# Heap usage: 758MB (peak 758MB, 24MB system)
# B&B tree size: 129MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    10600      .012000      .000000     30   5446     95   0.012      149    359
#    10700      .012000      .000000     30   5600    114   0.012      111    361
#    10800      .012000      .000000     30   5645    234   0.012       25    363
#    10903      .012000      .000000     30   5726    242   0.012       21    365
#    11003      .012000      .000000     30   5899    101   0.012      111    367
#    11103      .012000      .000000     30   5917    157   0.012      127    369
#    11206      .012000      .000000     30   5952    179   0.012       62    371
#    11306      .012000      .000000     30   5952    191   0.012       56    373
#    11406      .012000      .000000     30   5952    200   0.012       59    374
#    11506      .012000      .000000     30   6060    130   0.012      153    376
#    11606      .012000      .000000     30   6086    136   0.012      140    379
#    11706      .012000      .000000     30   6143    181   0.012      165    380
#    11810      .012000      .000000     30   6239    206   0.012       58    382
#    11910      .012000      .000000     30   6257    119   0.012      140    385
#    12013      .012000      .000000     30   6458    213   0.012       38    387
#    12113      .012000      .000000     30   6537    173   0.012      109    389
#    12213      .012000      .000000     30   6537    154   0.012      145    391
#    12315      .012000      .000000     30   6537    251   0.012       33    393
#    12415      .012000      .000000     30   6574    152   0.012      114    395
#    13417      .012000      .000000     30   7508    271   0.012       60    416
# Elapsed time (sec): 433, estimated tree completion: 0.00000
# Heap usage: 795MB (peak 795MB, 24MB system)
# B&B tree size: 174MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    14418      .012000      .000000     30   8238    220   0.012       52    433
# R  14517      .011700      .000000     31   8269    185  0.0117        0    435
#    15419      .011700      .000000     31   8407    203  0.0117       70    450
#    16419      .011700      .000000     31   9089    123  0.0117      128    470
#    17419      .011700      .000000     31   9760    143  0.0117      104    488
#    18419      .011700      .000000     31  10495    109  0.0117      152    503
#    19419      .011700      .000000     31  11288    176  0.0117      182    518
#    20419      .011700      .000000     31  12027    119  0.0117      170    536
#    21419      .011700      .000000     31  12709    166  0.0117      141    553
#    22419      .011700      .000000     31  13323    168  0.0117      169    566
#    23419      .011700      .000000     31  14073    178  0.0117      157    579
#    24419      .011700      .000000     31  14712    255  0.0117       48    594
#    25419      .011700      .000000     31  15414    245  0.0117       62    614
#    26419      .011700      .000000     31  16167    201  0.0117       93    626
#    27419      .011700      .000000     31  16907    192  0.0117      112    643
#    28419      .011700      .000000     31  17554    233  0.0117       70    660
#    29423      .011700      .000000     31  18133    318  0.0117       15    674
#    30423      .011700      .000000     31  18804    142  0.0117      122    689
# R  31186      .010750      .000000     32  19385    233 0.01075        0    699
#    32399      .010750      .000000     32  18202      1 0.01075        2    699
# Elapsed time (sec): 713, estimated tree completion: 0.00000
# Heap usage: 1001MB (peak 1001MB, 24MB system)
# B&B tree size: 374MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    33399      .010750      .000000     32  18725    189 0.01075      145    713
#    34399      .010750      .000000     32  19419    246 0.01075      135    728
#    35412      .010750      .000000     32  19949      1 0.01075        2    743
#    36412      .010750      .000000     32  20702    178 0.01075      149    757
#    37412      .010750      .000000     32  21104    242 0.01075      111    769
#    38412      .010750      .000000     32  21898    154 0.01075      139    785
#    39413      .010750      .000000     32  22382    199 0.01075      101    799
#    40413      .010750      .000000     32  23011    245 0.01075       60    812
#    41413      .010750      .000000     32  23751    181 0.01075       66    828
#    42417      .010750      .000000     32  24369    205 0.01075      122    840
#    43417      .010750      .000000     32  24903    182 0.01075      136    857
#    44417      .010750      .000000     32  25279    202 0.01075       95    868
#    45417      .010750      .000000     32  26145    218 0.01075       67    878
#    46417      .010750      .000000     32  26580    187 0.01075      132    891
#    47417      .010750      .000000     32  27326    204 0.01075      101    905
# R  47861      .010575      .000000     33  27551    251 0.010575       0    913
# R  47861      .009500      .000000     34  27551    251  0.0095        0    913
#    50891      .009500      .000000     34  24570      1  0.0095        2    913
#    51891      .009500      .000000     34  25162    211  0.0095       92    925
#    52891      .009500      .000000     34  25766    187  0.0095       96    938
# Elapsed time (sec): 952, estimated tree completion: 0.00000
# Heap usage: 1143MB (peak 1143MB, 24MB system)
# B&B tree size: 0.5GB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    53891      .009500      .000000     34  26192    190  0.0095      143    952
#    54895      .009500      .000000     34  26905    216  0.0095       67    965
#    55897      .009500      .000000     34  27203    228  0.0095       42    981
#    56897      .009500      .000000     34  28040    152  0.0095      100    994
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
#  *** Search unfinished ***    Time:  1000.19 Nodes:      57227
# Numerical issues encountered:
#    Dual failures    :      1 out of    162866 (ratio: 0.0000)
#    Singular bases   :      1 out of     41936 (ratio: 0.0000)
# Final MIP objective                   : 9.500000000000009e-03
# Final MIP bound                       : 0.000000000000000e-01
#   Solution time / primaldual integral :   1000.19s/ 100.000000%
#   Number of solutions found / nodes   :        34 /     57227
#   Max primal violation      (abs/rel) : 1.030e-13 / 5.151e-17
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.STOPPED: 1>, <SolStatus.FEASIBLE: 2>)

# %% [markdown]
# stage 2---Minimize the weighted bias of preference scores---remove cost constrain and breafast constraints about diversity

# %%
max_time=1000
WN = 3
N = 3 # Maximum daily edible parameters
M_ld = ['lunch','dinner']
dw = {0: 0.25, 1: 0.43, 2: 0.32}
nm = {0: 13, 1: 13, 2: 13}  # Total number of swipes per customer type---2 weeks
wp = { # wp[p][k]
    0: {'calories': 0.5,'cholesterol':0.2,'sodium':0.1, 'dietary_fiber': 0.2},  # man - high calories
    1: {'calories': 0.2, 'cholesterol':0.2,'sodium':0.2, 'dietary_fiber': 0.4},  #Female - high dietary_fiber
    2: {'calories': 0.25, 'cholesterol':0.25,'sodium':0.2, 'dietary_fiber': 0.25}  # Blend type, balance nutrition and taste
}
u = {
    (p, j, t): xp.var(
        vartype=xp.binary,
        name=f'u_{p}_{j}_{t}'
    )
    for p in P for j in M_ld for t in T
}
Qmax = {
    p: xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Qmax_{p}'
    )
    for p in P 
}

stage2 = xp.problem()
stage2.addVariable(x)
stage2.addVariable(y)
stage2.addVariable(Qmax)
stage2.addVariable(Q)
stage2.addVariable(u)

F_pi_p = xp.Sum(y[i, p, j, t] * pi[p][i] for i in I for j in M for t in T)
Total_variation_2 = xp.Sum((300-F_pi_p)/300 for p in P)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

stage2.setObjective(Total_variation_2, sense=xp.minimize)

# A.6 item inclusion
for j in M:
    for l in L:
        for t in T:
            stage2.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7 maximum number of items per subcategory
for t in T:
    for j in M:
        for l in L:
            if l in {"Main dish", "Side", "Soup"}:    
                for s in S_l:
                    if ns.get((j,l),0) >= 1:
                       stage2.addConstraint(
                           xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                       )

# A.8 Minimum Number of Items in a Subcategory
s_l_min = {'dark green','red orange','starch'}
for t in T:
    for j in M:
        for l in L:
            if l == "side":
                for s in s_l_min:
                    stage2.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) >= 1, name=f'Minimum_Number_of_Items_in_a_Subcategory_{t}_{j}_{l}_{s}')

# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    stage2.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    stage2.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    stage2.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            stage2.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            stage2.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )

# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        stage2.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            stage2.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                stage2.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                stage2.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 10
                )
        if l == "Soup":
            for s in S_l[l]:
                stage2.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
        if l == "Dessert":
            if s == "cake":
                stage2.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
            else:
                stage2.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 0
                )

# A.16 limiting consecutive repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            stage2.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            stage2.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                stage2.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items
for p in P:
    for j in M:
        for l in L:
            for t in T:
                if ns.get((j,l),0) >= 1:
                    stage2.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            stage2.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            stage2.addConstraint(
                nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
            )

# A.23
for p in P:
    for k in K:
        for t in T:
            stage2.addConstraint(Q[(p, k, t)] <= Qmax[p])

# # A.24 meal cost
# breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
# stage2.addConstraint(
#     xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
# )
# non_breakfast_courses = [l for l in L if l != 'Breakfast']
# lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
# stage2.addConstraint(
#     xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
# )
# dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
# stage2.addConstraint(
#     xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
# )
# stage2.addConstraint(
#     xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
# )

# C.1
for p in P:
    for j in M_ld:
            for t in T:
                stage2.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I) <= 3 * u[(p, j, t)]
                    )

# C.2
for p in P:
    stage2.addConstraint(xp.Sum(u[(p,j,t)] for j in M_ld for t in T) == nm[p])

# C.3
def nw(t, T, c):
    return (t + c) % len(T)
for p in P:
    for t in T:
            stage2.addConstraint(
                    xp.Sum(wp[p][k]* Q[(p,k, nw(t, T, c))] for k in K for c in range(1, WN+1)) <= Qmax[p]
                )

# C.5
slack=0.05
f_Q = 0.0095 + slack
stage2.addConstraint(xp.Sum(Qmax[p]/2 for p in P) <= f_Q)

# %%
stage2.setControl('maxtime', max_time )
print(stage2.getControl('maxtime'))
best_bound = stage2.getAttrib('bestbound')
mip_gap = 150*((stage2.getObjVal()-best_bound)/stage2.getObjVal())

xp.setOutputEnabled(True)
stage2.solve()
# Out:
# 1000
# FICO Xpress v9.4.2, Hyper, solve started 17:09:18, Mar 26, 2025
# Heap usage: 18MB (peak 18MB, 20MB system)
# Minimizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = 1
# Original problem has:
#      26926 rows        17769 cols       200805 elements     17682 entities
# Presolved problem has:
#      10161 rows        10790 cols        77423 elements     10703 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 21MB (peak 38MB, 20MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+30] / [ 5.86e-04,  1.95e+00]
#   RHS and bounds [min,max] : [ 5.09e-01,  2.30e+03] / [ 5.86e-01,  1.30e+01]
#   Objective      [min,max] : [ 1.44e-02,  3.00e-02] / [ 1.56e-02,  3.00e-02]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 8, support set: 10630
#  Number of orbits: 3167, largest orbit: 4
#  Row orbits: 3148, row support: 9602
# Will try to keep branch and bound tree memory usage below 5.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1.5589095   .0000000 |           factorize
#  D  1.5639909   .0000000 |  B  1.5928031  1.4883220
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 4694 simplex iterations, 0.67s
#         Barrier: 21 barrier and 0 simplex iterations, 0.68s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   4694          1.564101      P      0     0        .000000     1
# Dual solved problem
#   4694 simplex iterations in 0.68 seconds at time 1
#
# Final objective                       : 1.564100955694962e+00
#   Max primal violation      (abs/rel) : 3.053e-16 / 1.563e-16
#   Max dual violation        (abs/rel) : 2.047e-16 / 2.047e-16
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                   1.566453      0    147      0              248      2
#    2  K                   1.566453      0    143     82              318      3
#    3  K                   1.566453      0    189    137              347      3
#    4  K                   1.566453      0    130    138              378      3
#    5  K                   1.566453      0    147    153              351      4
#    6  K                   1.566453      0    119    115              350      4
#    7  K                   1.566453      0    138    129              333      4
#    8  K                   1.566453      0    146    133              346      5
#    9  K                   1.566453      0    173    153              358      5
#   10  K                   1.566453      0    167    183              362      8
#   11  K                   1.566484      0    178    161              355      8
#   12  K                   1.566484      0    161    150              357      8
#   13  K                   1.566484      0    192    159              373      9
#   14  K                   1.566484      0    184    217              363      9
#   15  K                   1.566484      0    157    387              372      9
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 74
# Cut elements in the matrix : 16118
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 71MB (peak 71MB, 26MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1                  1.566484      0      2      1              253     12
#        2                  1.566484      0      2      3              274     13
#        3                  1.566484      0      3      4              246     13
#        4                  1.566484      0      4      3              297     13
#        5                  1.567319      0      5      4              251     14
#        6                  1.567351      0      6      4              263     14
#        7                  1.567351      0      7      5              269     15
#        8                  1.567351      0      8      5              274     15
#        9                  1.567351      0      9      5              276     15
#       10                  1.567351      0     10      5              323     16
#       20                  1.567496      0     19      8              231     18
#       30                  1.567496      0     26      6              284     20
#       40                  1.567496      0     31     10              253     22
#       50                  1.567496      0     33     15              264     23
#       60                  1.567496      0     35     16              222     25
#       70                  1.567496      0     38     20              190     27
#       80                  1.567496      0     40     20              200     28
#       90                  1.567496      0     42     23              197     29
#      100                  1.567496      0     45     21              268     30
# Elapsed time (sec): 36, estimated tree completion: 0.00000
# Heap usage: 218MB (peak 218MB, 30MB system)
# B&B tree size: 3.7MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200                  1.567496      0    175     63              191     36
#      300                  1.567496      0    268    100               90     39
#      401                  1.567496      0    329    136               63     41
#      501                  1.567496      0    398    124               98     45
#      602                  1.567496      0    398    140               91     47
#      702                  1.567496      0    523     27              246     49
#      804                  1.567496      0    604    202               68     51
#      905                  1.567496      0    742    234               44     52
#     1005                  1.567496      0    910    267               36     54
#     1106                  1.567496      0   1061     48              184     59
#     1206                  1.567496      0   1086     14              255     68
#     1306                  1.567496      0   1086     26              311     76
#     1406                  1.567496      0   1160    114              170     81
#     1506                  1.567496      0   1339    132              163     85
#     1607                  1.567496      0   1411    154               73     89
#     1707                  1.567496      0   1462     43              233     93
#     1807                  1.567496      0   1506     47              229     95
#     1907                  1.567496      0   1705     64              228     98
#     2007                  1.567496      0   1705     48              191    100
#     2108                  1.567496      0   1866    130              195    102
# Elapsed time (sec): 105, estimated tree completion: 0.00000
# Heap usage: 383MB (peak 383MB, 34MB system)
# B&B tree size: 24MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2208                  1.567496      0   1866     60              188    105
#     2308                  1.567496      0   1945     71              185    107
# R   2399     1.998889     1.567496      1   2210     23   21.58%       0    110
#     2408     1.998889     1.567496      1   2252     65   21.58%     238    111
#     2508     1.998889     1.567496      1   2275     26   21.58%     236    114
#     2608     1.998889     1.567496      1   2381    108   21.58%     147    117
#     2710     1.998889     1.567496      1   2410    123   21.58%     131    121
#     2810     1.998889     1.567496      1   2428     83   21.58%     174    125
#     2912     1.998889     1.567496      1   2501    148   21.58%     128    128
#     3012     1.998889     1.567496      1   2612    121   21.58%     115    130
#     3112     1.998889     1.567496      1   2630     33   21.58%     221    133
#     3212     1.998889     1.567496      1   2630     58   21.58%     107    135
#     3314     1.998889     1.567496      1   2654    206   21.58%      96    137
#     3414     1.998889     1.567496      1   2900    256   21.58%      83    139
#     3515     1.998889     1.567496      1   3233    153   21.58%     110    141
#     3616     1.998889     1.567496      1   3256    172   21.58%     121    143
#     3719     1.998889     1.567496      1   3353     97   21.58%     104    146
#     3820     1.998889     1.567496      1   3490    246   21.58%      84    148
#     3920     1.998889     1.567496      1   3513    150   21.58%     132    151
#     4021     1.998889     1.567496      1   3520    157   21.58%     110    154
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:   10235 rows   10783 columns     93359 elements
# Presolve dropped   :       0 rows       7 columns       167 elements
# Will try to keep branch and bound tree memory usage below 5.4GB
# Crash basis containing 2663 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
# 1045879        -54.061111      D   2722     0        .000000   158
# 1053155          1.564101      P      0     0        .000000   158
# Optimal solution found
# Dual solved problem
#   1053155 simplex iterations in 0.71 seconds at time 158
#
# Final objective                       : 1.564100955694963e+00
#   Max primal violation      (abs/rel) : 2.914e-16 / 1.492e-16
#   Max dual violation        (abs/rel) : 2.179e-17 / 2.179e-17
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P            1.707778     1.567496      2                  8.21%       0    160
# P            1.605556     1.567496      3                  2.37%       0    160
# P            1.582222     1.567496      4                  0.93%       0    160
# P            1.581111     1.567496      5                  0.86%       0    160
# P            1.580000     1.567496      6                  0.79%       0    160
# P            1.577778     1.567496      7                  0.65%       0    160
#    1  K      1.577778     1.567496      7    170     68    0.65%     221    161
# P            1.576667     1.567496      8                  0.58%       0    161
#    2  K      1.576667     1.567496      8    187    104    0.58%     278    162
#    3  K      1.576667     1.567496      8    136    115    0.58%     267    162
# P            1.575556     1.567496      9                  0.51%       0    162
#    4  K      1.575556     1.567496      9    137    140    0.51%     284    163
#    5  K      1.575556     1.567496      9    189    131    0.51%     310    163
#    6  K      1.575556     1.567496      9    178    152    0.51%     325    163
#    7  K      1.575556     1.567496      9    140    169    0.51%     314    164
#    8  K      1.575556     1.567496      9    143    165    0.51%     310    164
#    9  K      1.575556     1.567496      9    118    157    0.51%     314    165
#   10  K      1.575556     1.567496      9    176    130    0.51%     304    167
# P            1.574444     1.567496     10                  0.44%       0    167
#   11  K      1.574444     1.567496     10    181    175    0.44%     324    167
#   12  K      1.574444     1.567496     10    172    151    0.44%     300    168
# P            1.573333     1.567496     11                  0.37%       0    168
#   13  K      1.573333     1.567496     11    184    165    0.37%     301    168
#   14  K      1.573333     1.567496     11    191    170    0.37%     317    168
#   15  K      1.573333     1.567496     11    179    168    0.37%     319    169
#   16  K      1.573333     1.567496     11    177    151    0.37%     320    169
#   17  K      1.573333     1.567496     11    176    178    0.37%     334    170
#   18  K      1.573333     1.567496     11    188    242    0.37%     310    170
#   19  K      1.573333     1.567496     11    187    166    0.37%     328    171
#   20  K      1.573333     1.567496     11    190    179    0.37%     320    172
#   21  K      1.573333     1.567496     11    181    179    0.37%     300    172
#   22  K      1.573333     1.567496     11    234    169    0.37%     290    173
#   23  K      1.573333     1.567496     11    182    225    0.37%     330    173
#   24  K      1.573333     1.567496     11    214    187    0.37%     293    174
#   25  K      1.573333     1.567496     11    203    207    0.37%     344    174
#   26  K      1.573333     1.567496     11    186    238    0.37%     323    174
#   27  K      1.573333     1.567496     11    196    184    0.37%     345    175
#   28  K      1.573333     1.567496     11    172    180    0.37%     317    176
#   29  K      1.573333     1.567496     11    195    202    0.37%     328    176
#   30  K      1.573333     1.567496     11    192    186    0.37%     310    176
#   31  K      1.573333     1.567496     11    185    183    0.37%     313    178
#   32  K      1.573333     1.567496     11    184    181    0.37%     324    178
#   33  K      1.573333     1.567496     11    173    189    0.37%     332    178
#   34  K      1.573333     1.567496     11    183    173    0.37%     336    179
#   35  K      1.573333     1.567496     11    206    194    0.37%     331    179
#   36  K      1.573333     1.567496     11    175    235    0.37%     351    180
#   37  K      1.573333     1.567496     11    192    168    0.37%     350    181
#   38  K      1.573333     1.567496     11    173    182    0.37%     339    181
#   39  K      1.573333     1.567496     11    185    142    0.37%     339    182
#   40  K      1.573333     1.567496     11    185    502    0.37%     325    182
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 87
# Cut elements in the matrix : 15127
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 47MB (peak 573MB, 26MB system)
# Elapsed time (sec): 185, estimated tree completion: 0.00000
# Heap usage: 47MB (peak 573MB, 26MB system)
# B&B tree size: 97k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4117     1.573333     1.567496     11      2      1    0.37%     225    185
#     4118     1.573333     1.567496     11      2      3    0.37%     273    185
#     4119     1.573333     1.567496     11      2      3    0.37%     280    186
#     4120     1.573333     1.567496     11      2      4    0.37%     280    186
#     4121     1.573333     1.567496     11      3      4    0.37%     270    186
#     4122     1.573333     1.567496     11      4      4    0.37%     208    187
#     4123     1.573333     1.567496     11      4      5    0.37%     256    187
#     4124     1.573333     1.567571     11      5      5    0.37%     303    188
#     4125     1.573333     1.567571     11      6      4    0.37%     299    188
#     4126     1.573333     1.567571     11      6      5    0.37%     251    188
#     4136     1.573333     1.567571     11     15      5    0.37%     292    192
#     4146     1.573333     1.567571     11     20      6    0.37%     284    195
#     4156     1.573333     1.567571     11     27      9    0.37%     292    198
#     4166     1.573333     1.567571     11     37      9    0.37%     281    201
#     4176     1.573333     1.567571     11     47      8    0.37%     242    204
#     4186     1.573333     1.567571     11     57     11    0.37%     233    206
#     4196     1.573333     1.567571     11     67     12    0.37%     256    208
#     4206     1.573333     1.567571     11     77     11    0.37%     207    211
#     4216     1.573333     1.567571     11     87     11    0.37%     202    212
# Elapsed time (sec): 228, estimated tree completion: 0.00000
# Heap usage: 530MB (peak 573MB, 39MB system)
# B&B tree size: 6.1MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4316     1.573333     1.567571     11    178     18    0.37%     250    228
#     4416     1.573333     1.567571     11    269     21    0.37%     211    240
#     4516     1.573333     1.567571     11    356     36    0.37%     238    250
#     4616     1.573333     1.567571     11    444     46    0.37%     238    258
#     4716     1.573333     1.567571     11    530     57    0.37%     153    265
#     4816     1.573333     1.567571     11    646     84    0.37%     144    271
#     4916     1.573333     1.567571     11    759     71    0.37%     165    275
#     5016     1.573333     1.567571     11    863     43    0.37%     238    280
#     5116     1.573333     1.567571     11    954     66    0.37%     188    284
#     5216     1.573333     1.567571     11   1038     90    0.37%     123    288
#     5316     1.573333     1.567571     11   1117     88    0.37%     122    292
#     5416     1.573333     1.567571     11   1207    161    0.37%     124    296
#     5516     1.573333     1.567571     11   1281     25    0.37%     235    302
#     5616     1.573333     1.567571     11   1358    116    0.37%     126    308
#     5719     1.573333     1.567571     11   1407    169    0.37%      34    315
#     5819     1.573333     1.567571     11   1439     30    0.37%     203    322
#     5919     1.573333     1.567571     11   1531     27    0.37%     173    330
#     6019     1.573333     1.567571     11   1593     39    0.37%     168    336
#     6120     1.573333     1.567571     11   1672    154    0.37%     120    342
#     6222     1.573333     1.567571     11   1741    178    0.37%      81    347
# Elapsed time (sec): 353, estimated tree completion: 0.00000
# Heap usage: 619MB (peak 619MB, 42MB system)
# B&B tree size: 26MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6322     1.573333     1.567571     11   1905     41    0.37%     235    353
#     6422     1.573333     1.567571     11   2020     57    0.37%     152    359
#     6523     1.573333     1.567571     11   2045     56    0.37%     173    367
#     6623     1.573333     1.567571     11   2105     53    0.37%     219    373
#     6723     1.573333     1.567571     11   2133     59    0.37%     167    379
#     6823     1.573333     1.567571     11   2195     30    0.37%     189    384
#     6923     1.573333     1.567571     11   2319     75    0.37%     192    390
#     7023     1.573333     1.567571     11   2367     36    0.37%     246    396
#     7123     1.573333     1.567571     11   2449     91    0.37%     172    401
#     7223     1.573333     1.567571     11   2485    104    0.37%     100    406
#     7323     1.573333     1.567571     11   2576     36    0.37%     227    411
#     7424     1.573333     1.567571     11   2651    149    0.37%      61    414
#     7526     1.573333     1.567571     11   2662    124    0.37%      23    418
#     7626     1.573333     1.567571     11   2722    174    0.37%      51    422
#     7727     1.573333     1.567571     11   2754    114    0.37%     172    425
#     7827     1.573333     1.567571     11   2761     33    0.37%     297    429
#     7928     1.573333     1.567571     11   2890    167    0.37%      14    433
#     8028     1.573333     1.567571     11   2937    212    0.37%      37    437
#     8128     1.573333     1.567571     11   3054    151    0.37%     111    440
#     8228     1.573333     1.567571     11   3054     95    0.37%     157    443
# Elapsed time (sec): 446, estimated tree completion: 0.00000
# Heap usage: 654MB (peak 654MB, 42MB system)
# B&B tree size: 47MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     8328     1.573333     1.567571     11   3084    230    0.37%      42    446
#     8428     1.573333     1.567571     11   3116    200    0.37%      25    449
#     8528     1.573333     1.567571     11   3750    131    0.37%     166    451
#     8628     1.573333     1.567571     11   3750    116    0.37%     190    454
#     8728     1.573333     1.567571     11   3788     45    0.37%     239    458
#     8828     1.573333     1.567571     11   3847     44    0.37%     215    461
#     8928     1.573333     1.567571     11   4051    249    0.37%      52    465
#     9028     1.573333     1.567571     11   4225     22    0.37%     225    469
#     9128     1.573333     1.567571     11   4268     73    0.37%     148    472
#     9229     1.573333     1.567571     11   4268    273    0.37%      35    476
#     9329     1.573333     1.567571     11   4334     71    0.37%     203    479
#     9430     1.573333     1.567571     11   4356    164    0.37%      46    483
#     9531     1.573333     1.567571     11   4380    293    0.37%      23    486
#     9631     1.573333     1.567571     11   4558     89    0.37%     148    489
#     9732     1.573333     1.567571     11   4685    186    0.37%      62    492
#     9832     1.573333     1.567571     11   4685     70    0.37%     192    496
#     9933     1.573333     1.567571     11   4840    208    0.37%      62    499
#    10033     1.573333     1.567571     11   5051     13    0.37%     211    503
#    10133     1.573333     1.567571     11   5230     52    0.37%     209    509
#    10233     1.573333     1.567571     11   5293    100    0.37%     190    514
# Elapsed time (sec): 519, estimated tree completion: 0.00000
# Heap usage: 690MB (peak 690MB, 42MB system)
# B&B tree size: 65MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    10333     1.573333     1.567571     11   5329    105    0.37%     195    519
#    10433     1.573333     1.567571     11   5426     18    0.37%     244    524
#    10533     1.573333     1.567571     11   5426     42    0.37%     235    529
#    10634     1.573333     1.567571     11   5496    166    0.37%     122    533
#    10734     1.573333     1.567571     11   5647     58    0.37%     137    537
#    10834     1.573333     1.567571     11   5725     23    0.37%     186    541
#    10934     1.573333     1.567571     11   5725    138    0.37%     150    545
#    11034     1.573333     1.567571     11   5946     77    0.37%     218    549
#    11134     1.573333     1.567571     11   5946     84    0.37%     193    553
#    11235     1.573333     1.567571     11   6017     30    0.37%     211    557
#    11335     1.573333     1.567571     11   6097     37    0.37%     233    561
#    11435     1.573333     1.567571     11   6208     83    0.37%     215    564
#    11535     1.573333     1.567571     11   6330    128    0.37%     182    568
#    11635     1.573333     1.567571     11   6395     76    0.37%     195    572
#    11735     1.573333     1.567571     11   6395     69    0.37%     174    575
#    11835     1.573333     1.567571     11   6437    120    0.37%     146    578
#    11936     1.573333     1.567571     11   6477    186    0.37%      52    581
#    12040     1.573333     1.567571     11   6477    244    0.37%      77    584
#    12140     1.573333     1.567571     11   6706     43    0.37%     188    587
#    12240     1.573333     1.567571     11   6837     84    0.37%      62    591
# Elapsed time (sec): 593, estimated tree completion: 0.00000
# Heap usage: 694MB (peak 694MB, 42MB system)
# B&B tree size: 85MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    12340     1.573333     1.567571     11   6947     85    0.37%     195    593
#    12440     1.573333     1.567571     11   6971    120    0.37%     136    595
#    12540     1.573333     1.567571     11   6987     96    0.37%     174    598
#    12642     1.573333     1.567571     11   6987    248    0.37%      84    600
#    12745     1.573333     1.567571     11   6987    167    0.37%     120    602
#    12847     1.573333     1.567571     11   7019     93    0.37%     174    604
#    12947     1.573333     1.567571     11   7058    192    0.37%      46    606
#    13047     1.573333     1.567571     11   7144    128    0.37%     134    609
#    13147     1.573333     1.567571     11   7144    128    0.37%     100    612
#    13247     1.573333     1.567571     11   7342    250    0.37%     160    614
#    13347     1.573333     1.567571     11   7512     78    0.37%     200    617
#    13447     1.573333     1.567571     11   7705    123    0.37%     155    619
#    13547     1.573333     1.567571     11   7819     89    0.37%     175    621
#    13647     1.573333     1.567571     11   8088    192    0.37%      77    624
#    13748     1.573333     1.567571     11   8170    161    0.37%     155    627
#    13848     1.573333     1.567571     11   8283    162    0.37%     129    630
#    13948     1.573333     1.567571     11   8354     34    0.37%     227    633
#    14048     1.573333     1.567571     11   8378    183    0.37%      53    636
#    14148     1.573333     1.567571     11   8415    234    0.37%     117    639
#    15148     1.573333     1.567571     11   9419     59    0.37%     195    666
# Elapsed time (sec): 696, estimated tree completion: 0.00000
# Heap usage: 735MB (peak 735MB, 42MB system)
# B&B tree size: 118MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    16148     1.573333     1.567571     11  10246    148    0.37%     116    696
#    17149     1.573333     1.567571     11  11170    159    0.37%     142    722
#    18151     1.573333     1.567571     11  11819    216    0.37%      20    743
#    19151     1.573333     1.567571     11  12976     34    0.37%     229    768
#    20152     1.573333     1.567571     11  13886     61    0.37%     207    793
#    21153     1.573333     1.567571     11  14047    106    0.37%      74    815
#    22154     1.573333     1.567571     11  15536    175    0.37%      65    834
#    23154     1.573333     1.567571     11  16471    168    0.37%     125    852
#    24154     1.573333     1.567571     11  17408     57    0.37%     179    875
#    25155     1.573333     1.567571     11  17996     78    0.37%     154    896
#    26158     1.573333     1.567571     11  19276    212    0.37%      60    914
#    27158     1.573333     1.567571     11  19956     38    0.37%     234    932
#    28158     1.573333     1.567571     11  20582     87    0.37%     152    951
#    29158     1.573333     1.567571     11  21803    115    0.37%      91    966
#    30158     1.573333     1.567571     11  22436     93    0.37%     132    985
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
#  *** Search unfinished ***    Time:  1000.14 Nodes:      31044
# Numerical issues encountered:
#    Singular bases   :      1 out of     24542 (ratio: 0.0000)
# Final MIP objective                   : 1.573333333333331e+00
# Final MIP bound                       : 1.567570611017857e+00
#   Solution time / primaldual integral :   1000.14s/ 12.454675%
#   Number of solutions found / nodes   :        11 /     31044
#   Max primal violation      (abs/rel) : 1.847e-13 / 1.269e-16
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.STOPPED: 1>, <SolStatus.FEASIBLE: 2>)

# %% [markdown]
# **Calculate the average preference score for each user**

# %%
# Calculate the average preference score for each user

# Extracting the Value of a Variable in a Solution
y_sol = stage2.getSolution(y)  #The number of times user p selects dish i
u_sol = stage2.getSolution(u)  # Card swiping record of user p

# Initialize the storage dictionary
avg_preference = {p: 0.0 for p in P}  # The average preference score of user p
total_preference = {p: 0.0 for p in P}  # The total preference score of user p
total_swipes = {p: 0 for p in P}       # Number of card swipes by user p

# Calculate total preference score and number of swipes
for p in P:
    for i in I:
        for j in M_ld:
            for t in T:
                total_preference[p] += y_sol[i, p, j, t] * pi[p][i]
    
    
    for j in M_ld:
        for t in T:
            total_swipes[p] += u_sol[p, j, t]
    
    # Calculate the average preference score
    if total_swipes[p] > 0:
        avg_preference[p] = total_preference[p] / total_swipes[p]
    else:
        avg_preference[p] = 0.0 


print("\n Average preference score per user")
for p in P:
    print(f"- Users{p}（Weight={dw[p]}）: {avg_preference[p]:.2f} mins/frequency")
# Out:
# 【每个用户的平均偏好得分】
# - 用户0（权重=0.25）: 4.12 分/次
# - 用户1（权重=0.43）: 4.96 分/次
# - 用户2（权重=0.32）: 8.20 分/次

# %% [markdown]
# **Calculating optimal total cost and optimal nutrition deviation score in Model 2**

# %%
x_opt = stage2.getSolution(x)
y_opt = stage2.getSolution(y)

optimal_preference_score = sum(dw[p] * y_opt[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
optimal_total_cost = sum(cost[i] * x_opt[i, j, t] for i in I for j in M for t in T)

print(f"Optimal Total Cost: {optimal_total_cost}")
print(f"Optimal Nutrition Deviation Score: {optimal_preference_score}")
# Out:
# Optimal Total Cost: 418.3100000000001
# Optimal Nutrition Deviation Score: 90.10738095238092

# %% [markdown]
# **Save the optimal menu in model 2**

# %%
y_solution = {key: stage2.getSolution(var) for key, var in y.items()}

# show the items that selected
selected_y = {key: value for key, value in y_solution.items() if value > 0.5}

df_y = pd.DataFrame([
    {"Item": key[0], "Guest": key[1], "Meal": key[2], "Time": key[3], "Value": value}
    for key, value in selected_y.items()
])
df_y.to_csv("model2_result.csv", index=False)

# %% [markdown]
# **Model 3---optimal model---Multi-objective model---preference score, cost, nutrition deviations**

# %%
model3 = xp.problem()
max_time=1000
model3.addVariable(x)
model3.addVariable(y)
model3.addVariable(Q)

dw = {0: 0.25, 1: 0.43, 2: 0.32}
Total_preference_score = xp.Sum(dw[p] * y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

Deviations_from_the_HEGs = xp.Sum(Q.get(p, {}).get(k, {}).get(t, 0) for p in P for k in K for t in T)
w_pi=0.6
w_c = 0.2
w_D = 0.2
model3.setObjective(w_pi * Total_preference_score - (w_c * Total_cost+ w_D * Deviations_from_the_HEGs) , sense=xp.maximize)

# A.6 item inclusion
for j in M:
    for l in L:
        for t in T:
            model3.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7 maximum number of items per subcategory
for t in T:
    for j in M:
        for l in L:
            if l in {"Main dish", "Side", "Soup", "Breakfast"}:    
                for s in S_l:
                    if ns.get((j,l),0) >= 1:
                       model3.addConstraint(
                           xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                       )

# A.8 Minimum Number of Items in a Subcategory
s_l_min = {'dark green','red orange','starch'}
for t in T:
    for j in M:
        for l in L:
            if l == "side":
                for s in s_l_min:
                    model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) >= 1, name=f'Minimum_Number_of_Items_in_a_Subcategory_{t}_{j}_{l}_{s}')

# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            model3.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            model3.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )

# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        model3.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            model3.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 10
                )
        if l == "Soup":
            for s in S_l[l]:
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
        if l == "Dessert":
            if s == "cake":
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
            else:
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 0
                )

# A.16 limiting consecutive repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            model3.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            model3.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model3.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items
for p in P:
    for j in M:
        for l in L:
            for t in T:
                if ns.get((j,l),0) >= 1:
                    model3.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model3.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model3.addConstraint(
                nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
            )

# A.23
Q_m = {0:0.3, 1:0.3, 2:0.3}
for p in P:
    for k in K:
        for t in T:
            model3.addConstraint(Q[(p, k, t)] <= Q_m[p])

# A.24 meal cost
breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
model3.addConstraint(
    xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
)
non_breakfast_courses = [l for l in L if l != 'Breakfast']
lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
model3.addConstraint(
    xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
)
dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
model3.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
)
model3.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
)

# %%
model3.setControl('maxtime', max_time )
print(model3.getControl('maxtime'))
best_bound = model3.getAttrib('bestbound')
mip_gap = 150*((model3.getObjVal()-best_bound)/model3.getObjVal())

xp.setOutputEnabled(True)
model3.solve()
# Out:
# 1000
# FICO Xpress v9.4.2, Hyper, solve started 18:10:16, Mar 26, 2025
# Heap usage: 12MB (peak 12MB, 29MB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      19129 rows        12660 cols       148695 elements     12600 entities
# Presolved problem has:
#       6609 rows         7495 cols        53462 elements      7495 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 15MB (peak 26MB, 29MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.04e-01,  1.00e+30] / [ 1.17e-03,  1.53e+00]
#   RHS and bounds [min,max] : [ 3.00e-01,  2.30e+03] / [ 1.50e-01,  1.00e+01]
#   Objective      [min,max] : [ 1.04e-01,  1.73e+00] / [ 1.04e-01,  1.73e+00]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 5996
#  Number of orbits: 2998, largest orbit: 2
#  Row orbits: 2538, row support: 5076
# Will try to keep branch and bound tree memory usage below 5.4GB
#  *** Solution found:   -16.307690   Time:   0.23    Heuristic: e ***
#  *** Solution found:   -14.177452   Time:   0.24    Heuristic: h ***
#  *** Solution found:   -12.815452   Time:   0.25    Heuristic: i ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  73.255039   .0000000 |  B  11.429606  1114.1571
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 5464 simplex iterations, 0.30s
#         Barrier: 21 barrier and 226 simplex iterations, 0.29s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0         61.024575      P      0     0        .000000     0
# Barrier solved problem
#   21 barrier and 226 simplex iterations in 0.31 seconds at time 0
#
# Final objective                       : 6.102457519922321e+01
#   Max primal violation      (abs/rel) : 9.159e-16 / 9.159e-16
#   Max dual violation        (abs/rel) : 6.413e-15 / 4.275e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# g           37.264667    61.024575      4                 38.93%       0      0
# R           44.148952    59.238782      5                 25.47%       0      1
# R           44.340952    59.238782      6                 25.15%       0      1
# R           44.578881    59.238782      7                 24.75%       0      1
# R           44.857452    59.238782      8                 24.28%       0      1
# R           44.992405    59.238782      9                 24.05%       0      1
# R           45.292405    59.238782     10                 23.54%       0      1
# R           45.549548    59.238782     11                 23.11%       0      1
# R           45.890881    59.238782     12                 22.53%       0      1
# R           46.317548    59.238782     13                 21.81%       0      1
# R           46.722881    59.238782     14                 21.13%       0      1
# R           47.256714    59.238782     15                 20.23%       0      1
# R           47.556714    59.238782     16                 19.72%       0      1
# R           47.835286    59.238782     17                 19.25%       0      1
# R           47.921286    59.238782     18                 19.10%       0      1
# R           49.027095    59.238782     19                 17.24%       0      1
# R           49.115500    59.238782     20                 17.09%       0      1
# R           49.287000    59.238782     21                 16.80%       0      1
# R           49.393667    59.238782     22                 16.62%       0      1
#    1  K     49.393667    59.238782     22     54      0   16.62%     674      2
#    2  K     49.393667    59.123886     22     22     30   16.46%     573      2
#    3  K     49.393667    59.066079     22      3     10   16.38%     570      2
#    4  K     49.393667    59.066079     22      2      2   16.38%     563      2
#    5  K     49.393667    59.066079     22      1      2   16.38%     574      2
#    6  K     49.393667    59.065684     22     12      3   16.38%     525      2
#    7  K     49.393667    59.065684     22      5     11   16.38%     525      2
#    8  K     49.393667    59.059511     22      3      4   16.37%     511      2
#    9  K     49.393667    59.053046     22      7      0   16.36%     558      2
# R           49.479667    59.009699     23                 16.15%       0      2
#   10  K     49.479667    59.009699     23      3      3   16.15%     544      3
#   11  K     49.479667    59.001758     23      6      4   16.14%     544      3
#   12  K     49.479667    59.001758     23      7      6   16.14%     542      3
#   13  K     49.479667    59.000237     23      3      3   16.14%     553      3
#   14  K     49.479667    59.000237     23      7      6   16.14%     541      3
#   15  K     49.479667    59.000237     23      0      5   16.14%     544      3
#   16  G     49.479667    59.000237     23      9      0   16.14%     544      3
#   17  G     49.479667    58.993473     23      8      7   16.13%     547      4
#   18  G     49.479667    58.993473     23      9     20   16.13%     583      4
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# M           49.723667    58.993473     24                 15.71%       0      4
# M           50.214333    58.993473     25                 14.88%       0      4
#
# Cuts in the matrix         : 45
# Cut elements in the matrix : 14466
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 38MB (peak 62MB, 34MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1    50.214333    58.623107     25      2      1   14.34%     578      6
#        2    50.214333    58.623107     25      2      3   14.34%     531      7
#        3    50.214333    58.408254     25      3      4   14.03%     500      7
#        4    50.214333    58.408254     25      4      4   14.03%     503      7
#        5    50.214333    58.408254     25      5      3   14.03%     522      7
#        6    50.214333    58.408254     25      6      4   14.03%     498      7
#        7    50.214333    58.408254     25      7      5   14.03%     499      7
#        8    50.214333    58.408254     25      8      5   14.03%     572      7
#        9    50.214333    58.399603     25      9      5   14.02%     486      7
#       10    50.214333    58.399603     25     10      6   14.02%     545      8
#       20    50.214333    58.032643     25     19      9   13.47%     491      9
#       30    50.214333    57.810992     25     26      9   13.14%     431     10
#       40    50.214333    57.804489     25     33     11   13.13%     480     11
#       50    50.214333    57.804489     25     36     14   13.13%     453     12
#       60    50.214333    57.804489     25     38     16   13.13%     461     12
#       70    50.214333    57.804489     25     54     18   13.13%     375     13
#       80    50.214333    57.804489     25     56     22   13.13%     360     13
#       90    50.214333    57.804489     25     58     22   13.13%     435     14
#      100    50.214333    57.804489     25     61     27   13.13%     359     14
# Elapsed time (sec): 19, estimated tree completion: 0.00000
# Heap usage: 155MB (peak 155MB, 34MB system)
# B&B tree size: 1.3MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200    50.214333    57.804489     25     85     54   13.13%     367     19
#      300    50.214333    57.804489     25    116     82   13.13%     242     23
#      400    50.214333    57.804489     25    214    102   13.13%     256     26
#      501    50.214333    57.804489     25    420    147   13.13%     230     29
#      601    50.214333    57.804489     25    439    135   13.13%     276     31
#      701    50.214333    57.804489     25    574    235   13.13%     207     34
#      801    50.214333    57.804489     25    595    186   13.13%     246     36
#      901    50.214333    57.804489     25    797    210   13.13%     236     39
#     1001    50.214333    57.804489     25    824    197   13.13%     276     41
#     1101    50.214333    57.804489     25    843    402   13.13%     174     43
# R   1131    50.240333    57.804489     26    892      6   13.09%       0     44
# R   1156    50.292095    57.804489     27    897      6   13.00%       0     45
# R   1199    50.330810    57.804489     28   1126     11   12.93%       0     46
# R   1199    50.545095    57.804489     29   1126     11   12.56%       0     46
#     1201    50.545095    57.804489     29   1126     12   12.56%     427     47
# R   1206    50.916119    57.804489     30   1127     11   11.92%       0     47
# R   1206    50.960405    57.804489     31   1127     11   11.84%       0     47
# R   1206    51.237071    57.804489     32   1127     11   11.36%       0     47
# R   1206    51.322786    57.804489     33   1127     11   11.21%       0     47
# R   1206    51.343952    57.804489     34   1127     11   11.18%       0     47
# Elapsed time (sec): 48, estimated tree completion: 0.00000
# Heap usage: 222MB (peak 222MB, 34MB system)
# B&B tree size: 8.3MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# b   1225    51.587500    57.804489     35   1130    266   10.76%       0     48
#     1301    51.587500    57.804489     35   1241     17   10.76%     430     52
#     1401    51.587500    57.804489     35   1241     27   10.76%     326     59
#     1501    51.587500    57.804489     35   1311     39   10.76%     205     63
#     1601    51.587500    57.803203     35   1464     50   10.75%     208     68
#     1701    51.587500    57.803203     35   1477     51   10.75%     275     72
#     1801    51.587500    57.803203     35   1519     57   10.75%     211     76
#     1901    51.587500    57.803203     35   1608     59   10.75%     230     80
#     2001    51.587500    57.803203     35   1719     61   10.75%     234     84
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:    6646 rows    7491 columns     67331 elements
# Presolve dropped   :       8 rows       4 columns       597 elements
# Will try to keep branch and bound tree memory usage below 5.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  87s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  82.407339   .0000000 |  B  40.503773  626.30412
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 525774 simplex iterations, 0.32s
#         Barrier: 22 barrier and 201 simplex iterations, 0.30s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0         60.952332      P      0     0        .000000    87
# Barrier solved problem
#   22 barrier and 201 simplex iterations in 0.33 seconds at time 87
#
# Final objective                       : 6.095233175685164e+01
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.142e-15 / 1.428e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P           51.930357    57.803203     36                 10.16%       0     87
# R           52.043214    57.803203     37                  9.96%       0     88
# R           52.921071    57.803203     38                  8.45%       0     89
#    1  K     52.921071    57.803203     38     36     11    8.45%     485     89
#    2  K     52.921071    57.803203     38     19     31    8.45%     482     89
#    3  K     52.921071    57.803203     38      9     17    8.45%     499     89
#    4  K     52.921071    57.803203     38     11      9    8.45%     496     89
#    5  K     52.921071    57.803203     38     10      8    8.45%     531     89
#    6  K     52.921071    57.803203     38      9     10    8.45%     498     89
#    7  K     52.921071    57.803203     38      3      7    8.45%     518     89
#    8  K     52.921071    57.803203     38      2      2    8.45%     542     89
#    9  K     52.921071    57.803203     38      4      3    8.45%     534     89
# R           53.006786    57.803203     39                  8.30%       0     90
# R           53.071286    57.803203     40                  8.19%       0     90
# R           53.135571    57.803203     41                  8.08%       0     90
# R           53.220905    57.803203     42                  7.93%       0     90
#   10  K     53.220905    57.803203     42      0      3    7.93%     546     90
#   11  G     53.220905    57.803203     42      6      0    7.93%     546     90
#   12  G     53.220905    57.803203     42      7     20    7.93%     542     90
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# M           53.306571    57.803203     43                  7.78%       0     92
#
# Cuts in the matrix         : 40
# Cut elements in the matrix : 9217
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 41MB (peak 286MB, 34MB system)
# Elapsed time (sec): 92, estimated tree completion: 0.00000
# Heap usage: 41MB (peak 286MB, 34MB system)
# B&B tree size: 95k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2099    53.306571    57.803203     43      2      1    7.78%     507     92
#     2100    53.306571    57.803203     43      2      3    7.78%     490     92
#     2101    53.306571    57.803203     43      2      3    7.78%     458     92
#     2102    53.306571    57.803203     43      2      4    7.78%     458     93
#     2103    53.306571    57.803203     43      3      4    7.78%     490     93
#     2104    53.306571    57.803203     43      4      4    7.78%     455     93
#     2105    53.306571    57.803203     43      4      5    7.78%     499     93
#     2106    53.306571    57.803203     43      5      4    7.78%     491     93
#     2107    53.306571    57.803203     43      5      5    7.78%     531     93
#     2108    53.306571    57.803203     43      6      5    7.78%     459     94
#     2118    53.306571    57.803203     43     13      6    7.78%     455     95
#     2128    53.306571    57.803203     43     22      7    7.78%     501     97
#     2138    53.306571    57.803203     43     32     10    7.78%     446     99
#     2148    53.306571    57.803203     43     42     10    7.78%     474    100
#     2158    53.306571    57.803203     43     52     10    7.78%     418    101
#     2168    53.306571    57.803203     43     62     13    7.78%     404    102
#     2178    53.306571    57.803203     43     72     15    7.78%     396    104
#     2188    53.306571    57.803203     43     82     16    7.78%     422    105
#     2198    53.306571    57.803203     43     92     16    7.78%     441    106
# Elapsed time (sec): 119, estimated tree completion: 0.00000
# Heap usage: 270MB (peak 286MB, 34MB system)
# B&B tree size: 0.9MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2298    53.306571    57.803203     43    192     28    7.78%     297    119
#     2398    53.306571    57.803203     43    292     41    7.78%     291    128
#     2498    53.306571    57.803203     43    392     63    7.78%     222    136
#     2598    53.306571    57.803203     43    492     58    7.78%     249    142
#     2698    53.306571    57.803203     43    592     63    7.78%     364    148
#     2798    53.306571    57.803203     43    692    100    7.78%     182    154
#     2898    53.306571    57.803203     43    792    130    7.78%     181    160
#     2998    53.306571    57.803203     43    892    144    7.78%     231    166
#     3098    53.306571    57.803203     43    992     99    7.78%     305    172
#     3198    53.306571    57.803203     43   1092    147    7.78%     232    179
#     3298    53.306571    57.803203     43   1186    118    7.78%     281    185
#     3398    53.306571    57.803203     43   1276    172    7.78%     271    193
#     3498    53.306571    57.803203     43   1354    137    7.78%     319    201
#     3598    53.306571    57.803203     43   1424    199    7.78%     307    211
#     3698    53.306571    57.803203     43   1493    196    7.78%     261    219
#     3798    53.306571    57.803203     43   1579    237    7.78%      59    228
#     3898    53.306571    57.803203     43   1662     29    7.78%     308    236
#     3998    53.306571    57.803203     43   1765    188    7.78%     186    244
#     4098    53.306571    57.803203     43   1820     20    7.78%     260    254
#     4198    53.306571    57.803203     43   1853     61    7.78%     164    261
# Elapsed time (sec): 267, estimated tree completion: 0.00000
# Heap usage: 429MB (peak 429MB, 34MB system)
# B&B tree size: 14MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4298    53.306571    57.803203     43   1882     27    7.78%     270    267
#     4398    53.306571    57.803203     43   1916     17    7.78%     313    274
#     4498    53.306571    57.621782     43   1993     58    7.49%     219    280
#     4598    53.306571    57.621782     43   2007      8    7.49%     496    288
#     4698    53.306571    57.621782     43   2152     72    7.49%     242    297
#     4798    53.306571    57.621782     43   2175    103    7.49%     130    306
#     4898    53.306571    57.621782     43   2275     87    7.49%     237    314
#     4998    53.306571    57.621782     43   2275     68    7.49%     217    322
#     5098    53.306571    57.621782     43   2356     18    7.49%     296    330
#     5198    53.306571    57.621782     43   2573    117    7.49%     296    337
#     5298    53.306571    57.621782     43   2601    110    7.49%     337    345
#     5398    53.306571    57.621782     43   2813    150    7.49%     234    352
#     5498    53.306571    57.621782     43   2886    122    7.49%     335    358
#     5598    53.306571    57.621782     43   3003     88    7.49%     240    364
#     5698    53.306571    57.621782     43   3003     91    7.49%     209    371
#     5798    53.306571    57.621782     43   3028    198    7.49%     204    378
#     5898    53.306571    57.621782     43   3105    104    7.49%     204    385
#     5998    53.306571    57.621782     43   3244     99    7.49%     203    391
#     6098    53.306571    57.621782     43   3244     56    7.49%     216    397
#     6198    53.306571    57.621782     43   3301     94    7.49%     275    403
# Elapsed time (sec): 408, estimated tree completion: 0.00000
# Heap usage: 529MB (peak 529MB, 35MB system)
# B&B tree size: 29MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6298    53.306571    57.621782     43   3542     76    7.49%     268    408
#     6398    53.306571    57.621782     43   3652     86    7.49%     222    412
#     6498    53.306571    57.621782     43   3696     72    7.49%     216    417
#     6598    53.306571    57.621782     43   3999     84    7.49%     284    422
#     6698    53.306571    57.621782     43   4021     12    7.49%     446    427
#     6798    53.306571    57.621782     43   4141     84    7.49%     249    432
#     6898    53.306571    57.621782     43   4141    132    7.49%     265    437
#     6998    53.306571    57.621782     43   4242    126    7.49%     314    441
#     7099    53.306571    57.621782     43   4417    153    7.49%      63    446
#     7199    53.306571    57.621782     43   4417    105    7.49%     177    450
#     7299    53.306571    57.621782     43   4441    172    7.49%     132    455
#     7401    53.306571    57.621782     43   4481    187    7.49%     131    459
#     7503    53.306571    57.621782     43   4558    233    7.49%      35    462
#     7604    53.306571    57.621782     43   4798    194    7.49%     274    466
#     7704    53.306571    57.621782     43   4826    152    7.49%     126    470
#     7804    53.306571    57.621782     43   4890     14    7.49%     344    475
#     7904    53.306571    57.621782     43   4966     43    7.49%     308    479
#     8004    53.306571    57.621782     43   5074     89    7.49%     250    483
#     8104    53.306571    57.621782     43   5293     39    7.49%     342    488
#     8204    53.306571    57.621782     43   5484    106    7.49%     279    493
# Elapsed time (sec): 497, estimated tree completion: 0.00000
# Heap usage: 540MB (peak 540MB, 35MB system)
# B&B tree size: 45MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     8304    53.306571    57.621782     43   5519     32    7.49%     391    497
#     8404    53.306571    57.621782     43   5568     54    7.49%     234    500
#     8504    53.306571    57.621782     43   5612     61    7.49%     250    503
#     8604    53.306571    57.621782     43   5698     34    7.49%     374    508
#     8704    53.306571    57.621782     43   5724    128    7.49%     273    513
#     8804    53.306571    57.621782     43   5748     64    7.49%     211    517
#     8904    53.306571    57.621782     43   5748     48    7.49%     378    521
#     9004    53.306571    57.621782     43   5748    139    7.49%     267    524
#     9104    53.306571    57.621782     43   5809    144    7.49%     286    528
#     9204    53.306571    57.621782     43   6124      8    7.49%     494    532
#     9304    53.306571    57.621782     43   6363     69    7.49%     248    535
#     9404    53.306571    57.621782     43   6363    106    7.49%     311    539
#     9504    53.306571    57.621782     43   6465     22    7.49%     418    543
#     9604    53.306571    57.621782     43   6518     91    7.49%     204    546
#     9704    53.306571    57.621782     43   6765     32    7.49%     405    551
#     9804    53.306571    57.621782     43   6890    102    7.49%     296    555
#     9904    53.306571    57.621782     43   6914    131    7.49%     406    559
#    10004    53.306571    57.621782     43   6914    109    7.49%     277    563
#    10104    53.306571    57.621782     43   7014     41    7.49%     249    567
#    10204    53.306571    57.621782     43   7014     72    7.49%     243    570
# Elapsed time (sec): 574, estimated tree completion: 0.00000
# Heap usage: 562MB (peak 562MB, 35MB system)
# B&B tree size: 59MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    10304    53.306571    57.621782     43   7186    146    7.49%     183    574
#    10404    53.306571    57.621782     43   7236    117    7.49%     226    577
#    10504    53.306571    57.621782     43   7395    136    7.49%     284    581
#    10604    53.306571    57.621782     43   7479     27    7.49%     323    586
#    10704    53.306571    57.621782     43   7660    167    7.49%     239    589
#    10804    53.306571    57.621782     43   7781     81    7.49%     265    593
#    10904    53.306571    57.621782     43   7963    164    7.49%     158    596
#    11004    53.306571    57.621782     43   8207    196    7.49%     254    600
#    11104    53.306571    57.621782     43   8231    141    7.49%     232    603
#    11204    53.306571    57.621782     43   8231    118    7.49%     227    607
#    11304    53.306571    57.621782     43   8300    176    7.49%     204    610
#    11406    53.306571    57.621782     43   8396    137    7.49%     208    614
#    11506    53.306571    57.621782     43   8396    174    7.49%     213    617
#    11606    53.306571    57.621782     43   8584     66    7.49%     286    621
#    11706    53.306571    57.621782     43   8640     38    7.49%     297    624
#    11806    53.306571    57.621782     43   8847     82    7.49%     292    629
#    11906    53.306571    57.621782     43   8909    147    7.49%     300    633
#    12006    53.306571    57.621782     43   9030    182    7.49%     266    637
#    12107    53.306571    57.621782     43   9218     32    7.49%     279    642
#    13107    53.306571    57.621782     43   9955     49    7.49%     370    676
# Elapsed time (sec): 706, estimated tree completion: 0.00000
# Heap usage: 599MB (peak 599MB, 35MB system)
# B&B tree size: 86MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    14107    53.306571    57.621782     43  10974    125    7.49%     201    706
#    15107    53.306571    57.621782     43  11845     25    7.49%     316    738
#    16107    53.306571    57.621782     43  13235    115    7.49%     133    770
#    17107    53.306571    57.621782     43  13959     44    7.49%     246    801
#    18107    53.306571    57.621782     43  15035     15    7.49%     430    826
#    19107    53.306571    57.621782     43  15901    228    7.49%     112    866
#    20107    53.306571    57.613783     43  17049     71    7.48%     235    896
#    21107    53.306571    57.613783     43  17721    124    7.48%     182    930
#    22108    53.306571    57.613783     43  18849    184    7.48%     231    959
#    23108    53.306571    57.613783     43  20117     38    7.48%     327    996
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
#  *** Search unfinished ***    Time:  1000.23 Nodes:      23219
# Final MIP objective                   : 5.330657142857140e+01
# Final MIP bound                       : 5.761378284597526e+01
#   Solution time / primaldual integral :   1000.23s/  8.030740%
#   Number of solutions found / nodes   :        43 /     23219
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.STOPPED: 1>, <SolStatus.FEASIBLE: 2>)

# %%
x_opt = model3.getSolution(x)
y_opt = model3.getSolution(y)

optimal_total_cost = sum(cost[i] * x_opt[i, j, t] for i in I for j in M for t in T)

print(f"Optimal Total Cost: {optimal_total_cost}")


daily_costs = {t: sum(cost[i] * x_opt[i, j, t] for i in I for j in M) for t in T}


for t, cost_t in daily_costs.items():
    print(f"Day {t} Cost: {cost_t}")
# Out:
# Optimal Total Cost: 361.13999999999993
# Day 0 Cost: 48.099999999999994
# Day 1 Cost: 54.47
# Day 2 Cost: 52.74000000000001
# Day 3 Cost: 52.86999999999999
# Day 4 Cost: 46.69
# Day 5 Cost: 48.75000000000001
# Day 6 Cost: 57.519999999999804

# %%
optimal_preference_score = sum(dw[p] * y_opt[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)

print(f"Optimal Preference Score: {optimal_preference_score}")
# Out:
# Optimal Preference Score: 183.91265873015894

# %%
Q_opt = { (p, k, t): model3.getSolution(Q[p, k, t]) for p in P for k in K for t in T }

# The optimized minimum nutritional deviation score was calculated
optimal_nutrition_deviation = sum(Q_opt.get((p, k, t), 0) for p in P for k in K for t in T)

print(f"Optimal Nutrition Deviation Score: {optimal_nutrition_deviation}")
# Out:
# Optimal Nutrition Deviation Score: 18.0

# %%
y_solution = {key: model3.getSolution(var) for key, var in y.items()}

# show the items that selected
selected_y = {key: value for key, value in y_solution.items() if value > 0.5}

df_y = pd.DataFrame([
    {"Item": key[0], "Guest": key[1], "Meal": key[2], "Time": key[3], "Value": value}
    for key, value in selected_y.items()
])
df_y.to_csv("model3_y_result.csv", index=False)

# %% [markdown]
# **Model 3 parameter tunning-----NSGA-II parameter tunning**

# %%
pip install pymoo

# %%
import pymoo
from pymoo.core.problem import Problem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ----------------------------
# Part 1: Xpress model encapsulation
# ----------------------------
def build_xpress_model(w_pi, w_c, w_D):
    
    model3 = xp.problem()
    max_time=1000
    model3.addVariable(x)
    model3.addVariable(y)
    model3.addVariable(Q)

    dw = {0: 0.25, 1: 0.43, 2: 0.32}
    Total_preference_score = xp.Sum(dw[p] * y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
    Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)
    Deviations_from_the_HEGs = xp.Sum(Q.get(p, {}).get(k, {}).get(t, 0) for p in P for k in K for t in T)
    
    model3.setObjective(w_pi * Total_preference_score - (w_c * Total_cost+ w_D * Deviations_from_the_HEGs) , sense=xp.maximize)
    
    
    # A.6 item inclusion
    for j in M:
        for l in L:
            for t in T:
                model3.addConstraint(
                    xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
                )

    # A.7 maximum number of items per subcategory
    for t in T:
        for j in M:
            for l in L:
                if l in {"Main dish", "Side", "Soup", "Breakfast"}:    
                    for s in S_l:
                        if ns.get((j,l),0) >= 1:
                            model3.addConstraint(
                            xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                            )

    # A.8 Minimum Number of Items in a Subcategory
    s_l_min = {'dark green','red orange','starch'}
    for t in T:
        for j in M:
            for l in L:
                if l == "side":
                    for s in s_l_min:
                        model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) >= 1, name=f'Minimum_Number_of_Items_in_a_Subcategory_{t}_{j}_{l}_{s}')

    # A.9 course subcategory dependencies
    s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
    for t in T:
        for j in M:
            for l in L:
                if ns.get((j,l),0) >= 2:
                    for s in s_l_com[1]:
                        model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                    for s in s_l_com[2]:
                        model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                    for s in s_l_com[3]:
                        model3.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

    # A.10 item dependencies
    s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
    for t in T:
        for j in M:
            if "Main dish" in L and "Side" in L:
                model3.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                    <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
                )
            if "Main dish" in L and "Side" in L:
                model3.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                    <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
                )

    # A.11-12 maximum number of servings of items in a menu cycle
    nsT_max = 3
    for i in I:
        if "Main dish" in L:
            model3.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
            )          



    # A.16 limiting consecutive repetitions of items
    G_i = {i: 1 for i in I}
    for i in I:
        for t in T:
            if t > G_i[i]:
                model3.addConstraint(
                    xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                    <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
                )

    # A.17: item repetition constraints within a day
    for l in L:
        for i in I:
            for t in T:
                model3.addConstraint(
                    xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
                )

    # A.18: diet types: p can choose only the items that offered
    for p in P: 
        for j in M:
            for i in I:
                for t in T:
                    model3.addConstraint(
                        y[(i, p, j, t)]<= x[(i, j, t)]
                    )

    # A.19: diet types: p is allowed to choose np number of items
    for p in P:
        for j in M:
            for l in L:
                for t in T:
                    if ns.get((j,l),0) >= 1:
                        model3.addConstraint(
                            xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                        )
                        
    # # A.20-21 ?
    # for p in P:
    #     for k in K:
    #         for t in T:
    #             nutrient_intake = xp.Sum(
    #                 w[k][i] * y[(i, p, j, t)] 
    #                 for j in M 
    #                 for i in I 
    #                 if (i, p, j, t) in y
    #             )
    #             model3.addConstraint(
    #                 nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
    #             )
    # for p in P:
    #     for k in K:
    #         for t in T:
    #             nutrient_intake = xp.Sum(
    #                 w[k][i] * y[(i, p, j, t)] 
    #                 for j in M 
    #                 for i in I 
    #                 if (i, p, j, t) in y
    #             )
    #             model3.addConstraint(
    #                 nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
    #             )

    # A.23
    Q_m = {0:0.3, 1:0.3, 2:0.3}
    for p in P:
        for k in K:
            for t in T:
                model3.addConstraint(Q[(p, k, t)] <= Q_m[p])

    # A.24 meal cost
    breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
    model3.addConstraint(
        xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
    )
    non_breakfast_courses = [l for l in L if l != 'Breakfast']
    lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
    model3.addConstraint(
        xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
    )
    dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
    model3.addConstraint(
        xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
    )
    model3.addConstraint(
        xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
    )


    # Solve the model (disable output for speed)
    
    # model3.setControl('maxtime', max_time )
    # # print(model3.getControl('maxtime'))
    # best_bound = model3.getAttrib('bestbound')
    # mip_gap = 150*((model3.getObjVal()-best_bound)/model3.getObjVal())

    
    xp.setOutputEnabled(False)
    model3.solve()
    
    x_opt = model3.getSolution(x)
    y_opt = model3.getSolution(y)
    Q_opt = model3.getSolution(Q)

    
    optimal_total_cost = sum(cost[i] * x_opt[i, j, t] for i in I for j in M for t in T)
    optimal_preference_score = sum(pi[p][i] * y_opt[i, p, j, t] for i in I for p in P for j in M for t in T)
    optimal_deviations = sum(Q_opt[p, k, t] for p in P for k in K for t in T)
    

    
    return (optimal_preference_score, optimal_total_cost, optimal_deviations)

# ----------------------------
# Part 2: Multi-objective optimization problem class
# ----------------------------
class MenuOptimizationProblem(Problem):      
    def __init__(self):
        super().__init__(
            n_var=3,
            n_obj=3,
            n_constr=1,  # Add constraint: w_pi + w_c + w_D = 1.
            xl=np.array([0, 0, 0]),
            xu=np.array([1, 1, 1])
        )

    def _evaluate(self, weights, out, *args, **kwargs):
        objs = []
        constraints = []
        for w in weights:
            w_pi, w_c, w_D = w[0], w[1], w[2]
            # Constraint: Sum of weights must be 1
            constraints.append(w_pi + w_c + w_D - 1)
            preference_scores, total_cost, deviations = build_xpress_model(w_pi, w_c, w_D)
            objs.append([preference_scores, -total_cost, -deviations])
        out["F"] = np.array(objs)
        out["G"] = np.array(constraints)  
        

# ----------------------------
# Part 3: Run optimization and visualization
# ----------------------------
if __name__ == "__main__":
    
    # Initialize problem
    problem = MenuOptimizationProblem()
    
    # Configure algorithm (NSGA-II)
    algorithm = NSGA2(
        pop_size= 20,  
        eliminate_duplicates=True
    )
    
    # Run optimization (reduce generations for quick demonstration)
    res = minimize(
        problem,
        algorithm,
        ('n_gen', 10),
        seed=3407,
        verbose=True
    )
    

    pareto_weights = res.X
    pareto_objectives = res.F
        
        
    # Extract Pareto front
    pareto_weights = res.X / np.sum(res.X, axis = 1)[:,None]    # Optimal weight combination [w_pi, w_c, w_D]
    pareto_objectives = res.F   # Corresponding objective values [pref_score, -cost, -deviations]
    
    # Visualization
    fig = plt.figure(figsize=(20, 5))
    
    # 3D Pareto front
    ax1 = fig.add_subplot(131, projection='3d')
    ax1.scatter(pareto_objectives[:, 0], pareto_objectives[:, 1], pareto_objectives[:, 2])
    ax1.set_xlabel("Preference Score")
    ax1.set_ylabel("Negative Cost")
    ax1.set_zlabel("Negative Deviations")
    ax1.set_title("3D Pareto Front")
    
    # 2D projection
    ax2 = fig.add_subplot(132)
    ax2.scatter(pareto_objectives[:, 0], pareto_objectives[:, 1])
    ax2.set_xlabel("Preference Score")
    ax2.set_ylabel("Negative Cost")
    ax2.set_title("Preference vs Cost")
    
    # ax3 = fig.add_subplot(133)
    # ax3.scatter(pareto_objectives[:, 0], pareto_objectives[:, 2])
    # ax3.set_xlabel("Preference Score")
    # ax3.set_ylabel("Negative Deviations")
    # ax3.set_title("Preference vs Deviations")
    
    plt.tight_layout()
    plt.show()
    print(pareto_weights)
    print(pareto_objectives)
    # Print results
    print("\nPareto optimal solution：")
    for i, (w, obj) in enumerate(zip(pareto_weights, pareto_objectives)):
        print(f"solution {i+1}:")
        print(f"  weight: w_pi={w[0]:.3f}, w_c={w[1]:.3f}, w_D={w[2]:.3f}")
        print(f"  object:")
        print(f"    - Preference: {obj[0]:.1f}")
        print(f"    - Cost: {-obj[1]:.1f}")
        print(f"    - Deviations: {-obj[2]:.1f}")
        print("-" * 40)

# %% [markdown]
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       20 |      2 |  0.000000E+00 |  0.6688555722 |             - |             -
#      2 |       40 |      6 |  0.000000E+00 |  0.2204506546 |  1.067592E-15 |             f
#      3 |       60 |     15 |  0.000000E+00 |  0.0133816558 |  0.4023220596 |         ideal
#      4 |       80 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0350706283 |         ideal
#      5 |      100 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0440050685 |             f
#      6 |      120 |     20 |  0.000000E+00 |  0.000000E+00 |  0.8518652139 |         ideal
#      7 |      140 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0023508004 |             f
#      8 |      160 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0400898582 |             f
#      9 |      180 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0182860973 |             f
#     10 |      200 |     20 |  0.000000E+00 |  0.000000E+00 |  0.0096469916 |         ideal

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# [[0.92630075 0.01704684 0.05665241]
#  [0.11773693 0.82246823 0.05979484]
#  [0.88698264 0.10339463 0.00962273]
#  [0.65472901 0.16299098 0.18228002]
#  [0.61875728 0.04000581 0.34123691]
#  [0.95314594 0.03534428 0.01150978]
#  [0.06979732 0.12933663 0.80086605]
#  [0.62612463 0.02907786 0.34479751]
#  [0.81178017 0.11603148 0.07218835]
#  [0.9077241  0.06875708 0.02351882]
#  [0.06144686 0.05300171 0.88555143]
#  [0.77467712 0.0182683  0.20705458]
#  [0.63169261 0.17703924 0.19126815]
#  [0.81396934 0.11422274 0.07180791]
#  [0.62266722 0.03919347 0.33813931]
#  [0.65732151 0.27575178 0.06692672]
#  [0.66351026 0.1121836  0.22430614]
#  [0.71337708 0.10010682 0.1865161 ]
#  [0.77606472 0.1586691  0.06526618]
#  [0.75797669 0.20544203 0.03658128]]
# [[ 915.64285714 -393.72        -25.2       ]
#  [ 852.0952381  -253.78        -25.2       ]
#  [ 903.09126984 -314.65        -25.2       ]
#  [ 885.46031746 -273.59        -25.2       ]
#  [ 908.53968254 -337.55        -25.2       ]
#  [ 913.99206349 -369.51        -25.2       ]
#  [ 859.23809524 -254.56        -25.2       ]
#  [ 912.03174603 -356.17        -25.2       ]
#  [ 895.96428571 -295.37        -25.2       ]
#  [ 906.05555556 -325.1         -25.2       ]
#  [ 868.43650794 -256.87        -25.2       ]
#  [ 915.40079365 -377.75        -25.2       ]
#  [ 878.71428571 -265.62        -25.2       ]
#  [ 896.8968254  -298.12        -25.2       ]
#  [ 910.74206349 -345.1         -25.2       ]
#  [ 871.42063492 -258.47        -25.2       ]
#  [ 892.57936508 -287.46        -25.2       ]
#  [ 896.8968254  -298.12        -25.2       ]
#  [ 889.08333333 -279.09        -25.2       ]
#  [ 878.71428571 -265.62        -25.2       ]]

# Pareto optimal solution：
# solution 1:
#   weight: w_pi=0.926, w_c=0.017, w_D=0.057
#   object:
#     - Preference: 915.6
#     - Cost: 393.7
#     - Deviations: 25.2
# ----------------------------------------
# solution 2:
#   weight: w_pi=0.118, w_c=0.822, w_D=0.060
#   object:
#     - Preference: 852.1
#     - Cost: 253.8
#     - Deviations: 25.2
# ----------------------------------------
# solution 3:
#   weight: w_pi=0.887, w_c=0.103, w_D=0.010
#   object:
#     - Preference: 903.1
#     - Cost: 314.6
#     - Deviations: 25.2
# ----------------------------------------
# solution 4:
#   weight: w_pi=0.655, w_c=0.163, w_D=0.182
#   object:
#     - Preference: 885.5
#     - Cost: 273.6
#     - Deviations: 25.2
# ----------------------------------------
# solution 5:
#   weight: w_pi=0.619, w_c=0.040, w_D=0.341
#   object:
#     - Preference: 908.5
#     - Cost: 337.6
#     - Deviations: 25.2
# ----------------------------------------
# solution 6:
#   weight: w_pi=0.953, w_c=0.035, w_D=0.012
#   object:
#     - Preference: 914.0
#     - Cost: 369.5
#     - Deviations: 25.2
# ----------------------------------------
# solution 7:
#   weight: w_pi=0.070, w_c=0.129, w_D=0.801
#   object:
#     - Preference: 859.2
#     - Cost: 254.6
#     - Deviations: 25.2
# ----------------------------------------
# solution 8:
#   weight: w_pi=0.626, w_c=0.029, w_D=0.345
#   object:
#     - Preference: 912.0
#     - Cost: 356.2
#     - Deviations: 25.2
# ----------------------------------------
# solution 9:
#   weight: w_pi=0.812, w_c=0.116, w_D=0.072
#   object:
#     - Preference: 896.0
#     - Cost: 295.4
#     - Deviations: 25.2
# ----------------------------------------
# solution 10:
#   weight: w_pi=0.908, w_c=0.069, w_D=0.024
#   object:
#     - Preference: 906.1
#     - Cost: 325.1
#     - Deviations: 25.2
# ----------------------------------------
# solution 11:
#   weight: w_pi=0.061, w_c=0.053, w_D=0.886
#   object:
#     - Preference: 868.4
#     - Cost: 256.9
#     - Deviations: 25.2
# ----------------------------------------
# solution 12:
#   weight: w_pi=0.775, w_c=0.018, w_D=0.207
#   object:
#     - Preference: 915.4
#     - Cost: 377.8
#     - Deviations: 25.2
# ----------------------------------------
# solution 13:
#   weight: w_pi=0.632, w_c=0.177, w_D=0.191
#   object:
#     - Preference: 878.7
#     - Cost: 265.6
#     - Deviations: 25.2
# ----------------------------------------
# solution 14:
#   weight: w_pi=0.814, w_c=0.114, w_D=0.072
#   object:
#     - Preference: 896.9
#     - Cost: 298.1
#     - Deviations: 25.2
# ----------------------------------------
# solution 15:
#   weight: w_pi=0.623, w_c=0.039, w_D=0.338
#   object:
#     - Preference: 910.7
#     - Cost: 345.1
#     - Deviations: 25.2
# ----------------------------------------
# solution 16:
#   weight: w_pi=0.657, w_c=0.276, w_D=0.067
#   object:
#     - Preference: 871.4
#     - Cost: 258.5
#     - Deviations: 25.2
# ----------------------------------------
# solution 17:
#   weight: w_pi=0.664, w_c=0.112, w_D=0.224
#   object:
#     - Preference: 892.6
#     - Cost: 287.5
#     - Deviations: 25.2
# ----------------------------------------
# solution 18:
#   weight: w_pi=0.713, w_c=0.100, w_D=0.187
#   object:
#     - Preference: 896.9
#     - Cost: 298.1
#     - Deviations: 25.2
# ----------------------------------------
# solution 19:
#   weight: w_pi=0.776, w_c=0.159, w_D=0.065
#   object:
#     - Preference: 889.1
#     - Cost: 279.1
#     - Deviations: 25.2
# ----------------------------------------
# solution 20:
#   weight: w_pi=0.758, w_c=0.205, w_D=0.037
#   object:
#     - Preference: 878.7
#     - Cost: 265.6
#     - Deviations: 25.2
# ----------------------------------------
