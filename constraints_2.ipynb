# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import xpress as xp
import pandas as pd

# %% [markdown]
# initialisation

# %%
meal_data_path = 'meal_data.xlsx'
meal_data = pd.read_excel(meal_data_path)
meal_data.head()
# Out:
#                           item_name course_type subcategories  meal_type  \
# 0          Trick OR Treat Ice Cream        Soup         cream        NaN
# 1                 Sweet Fries Snack        Side         fried        NaN
# 2                  Tomatoes - Salad        Side    red orange        NaN
# 3  Chicken BBQ Caesar Salad EntrÌ©e   Main dish       poultry        NaN
# 4         Corn and Black Bean Salad        Side        legume        NaN
#
#    cost  nf_calories  nf_calories_from_fat  nf_total_fat  nf_saturated_fat  \
# 0  2.08       300.00                 140.0          16.0               9.0
# 1  2.27      1150.00                 690.0          79.0               7.0
# 2  3.45         9.58                   2.4           0.0               0.0
# 3  3.95       203.00                   NaN           NaN               2.1
# 4  3.59       140.00                  10.0           1.0               0.0
#
#    nf_trans_fatty_acid  ...  nf_vitamin_a_dv  nf_vitamin_c_dv  nf_calcium_dv  \
# 0                  0.0  ...              8.0              2.0           15.0
# 1                  0.0  ...              NaN              NaN            NaN
# 2                  0.0  ...              5.0             14.0            0.0
# 3                  NaN  ...              NaN              NaN            NaN
# 4                  0.0  ...              2.0              4.0            2.0
#
#    nf_iron_dv  nf_potassium  nf_servings_per_container  nf_serving_size_qty  \
# 0         4.0           NaN                        NaN                 4.00
# 1         NaN           NaN                        NaN                13.40
# 2         0.0           NaN                        NaN                45.52
# 3         NaN           NaN                        NaN                 2.00
# 4        10.0           NaN                        NaN                 1.00
#
#    nf_serving_size_unit  nf_serving_weight_grams  images_front_full_url
# 0             oz scoops                      NaN                    NaN
# 1                    oz                      NaN                    NaN
# 2                 Grams                    45.52                    NaN
# 3              servings                      NaN                    NaN
# 4                 Salad                      NaN                    NaN
#
# [5 rows x 28 columns]

# %%
score_preference_path = 'score_preference.xlsx'
score_preference = pd.read_excel(score_preference_path)
score_preference.set_index('Unnamed: 0', inplace=True)
score_preference.head()
# Out:
#             Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# Unnamed: 0
# 0                                  1                  3                 3
# 1                                  3                  2                 1
# 2                                  3                  2                 3
# 3                                  1                  2                 1
# 4                                  2                  1                 1
#
#             Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  \
# Unnamed: 0
# 0                                          3                          3
# 1                                          1                          1
# 2                                          2                          2
# 3                                          2                          3
# 4                                          3                          1
#
#             Mango Cake  Egg  Flavored Fresh Lemonade, Peach  \
# Unnamed: 0
# 0                    2    1                               2
# 1                    3    3                               2
# 2                    2    2                               2
# 3                    3    1                               1
# 4                    1    3                               3
#
#             Add Pirate Tossed Salad  Blueberry Vinaigrette  ...  \
# Unnamed: 0                                                  ...
# 0                                 3                      1  ...
# 1                                 3                      1  ...
# 2                                 1                      3  ...
# 3                                 1                      2  ...
# 4                                 1                      1  ...
#
#             Vegetable Spring Rolls  All Natural Spinach Hummus  \
# Unnamed: 0
# 0                                2                           2
# 1                                1                           1
# 2                                2                           2
# 3                                3                           2
# 4                                1                           2
#
#             Cooked Mushrooms  Green Pepper And Onion Omelette  \
# Unnamed: 0
# 0                          2                                3
# 1                          1                                2
# 2                          2                                3
# 3                          1                                1
# 4                          2                                2
#
#             Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  \
# Unnamed: 0
# 0                                                           3
# 1                                                           1
# 2                                                           1
# 3                                                           3
# 4                                                           2
#
#             Whole Grain Waffle  xiao main  \
# Unnamed: 0
# 0                            3          1
# 1                            3          3
# 2                            3          3
# 3                            1          3
# 4                            1          1
#
#             Burrito Main, Braised Pork Carnitas  \
# Unnamed: 0
# 0                                             1
# 1                                             1
# 2                                             2
# 3                                             1
# 4                                             2
#
#             Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# Unnamed: 0
# 0                                            1                        1
# 1                                            1                        3
# 2                                            3                        2
# 3                                            3                        1
# 4                                            3                        3
#
# [5 rows x 130 columns]

# %%
nutrition_criteria_path = 'nutrition_criteria.xlsx'
nutrition_criteria = pd.read_excel(nutrition_criteria_path)
nutrition_criteria.head()
# Out:
#    ID        Element     F     M  Average
# 0   1       Calories  1600  2000     1800
# 1   2         Sodium  2300  2300     2300
# 2   3   Carbohydrate   130   130      130
# 3   4  Dietary_fiber    22    28       25
# 4   5        Protein    46    56       51

# %%
table3_path = 'table3.xlsx'
meal_constraints = pd.read_excel(table3_path, sheet_name='meal_constraints', index_col=0)
diet_types = pd.read_excel(table3_path, sheet_name='diet_types', index_col=0)
maximum_servings = pd.read_excel(table3_path, sheet_name='maximum_servings')
day_item = pd.read_excel(table3_path, sheet_name='day_item')
wp = pd.read_excel(table3_path, sheet_name='wp')
wc = pd.read_excel(table3_path, sheet_name='wc')
day_item.head()
# Out:
#    Breakfast  Soup  Salad  Main dish  Side  Appetizer  Dessert
# 0          1     1      1          1   NaN        NaN        1

# %%
# model = xp.problem()
num_item = 130
num_day = 7
num_meal = 3
num_patron = 3
num_course = 7
#num_nutrition = 5

I = list(range(num_item)) # i∈I
M = ['breakfast', 'lunch', 'dinner'] # j∈M
T = list(range(num_day)) # t∈T
P = list(range(num_patron)) # p∈P
L = ['Breakfast', 'Soup', 'Salad', 'Main dish', 'Side', 'Appetizer', 'Dessert'] # l∈L
#K = ['calories','cholesterol','sodium','dietary_fiber']
K = ['calories','dietary_fiber']


l_i = {meal_data.index[i]: meal_data.iloc[i]["course_type"] for i in range(len(meal_data))}
I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
S_l = meal_data.groupby("course_type")["subcategories"].unique().apply(list).to_dict()
I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

# w = {
#     "calories": {i: meal_data.iloc[i]["nf_calories"] for i in I},
#     "cholesterol": {i: meal_data.iloc[i]["nf_cholesterol"] for i in I},
#     "sodium": {i: meal_data.iloc[i]["nf_sodium"] for i in I},
#     "dietary_fiber": {i: meal_data.iloc[i]["nf_dietary_fiber"] for i in I},
# }
w = {
    "calories": {i: meal_data.iloc[i]["nf_calories"] for i in I},
    #"cholesterol": {i: meal_data.iloc[i]["nf_cholesterol"] for i in I},
    "dietary_fiber": {i: meal_data.iloc[i]["nf_dietary_fiber"] for i in I},
}


ns = meal_constraints.to_dict(orient='index')
np = diet_types.to_dict(orient='index')
np_expanded = {p: {j: {l: np[j][l] for l in L} for j in M} for p in P}
nsOWP = maximum_servings.to_dict(orient='records')[0]
nsd = day_item.to_dict(orient='records')[0]
wp_l = wp.to_dict(orient='records')[0]
wc_l = wc.to_dict(orient='records')[0]
pi_raw = score_preference.to_dict(orient='index')
cost = {i: meal_data.loc[i, 'cost'] for i in I}

x = {
    (i, j, t): xp.var(
        vartype=xp.binary,
        name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
    )
    for i in I for j in M for t in T
}
y = {
    (i, p, j, t): xp.var(
        vartype=xp.binary,
        name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
    )
    for i in I for p in P for j in M for t in T
}
Q = {
    (p, k, t): xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Q_{p}_{k}_{t}'
    )
    for p in P 
    for k in K 
    for t in T
}


# x = {
#     (i, j, t): model.addVariable(
#         vartype=xp.binary,
#         name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
#     )
#     for i in I 
#     for j in M 
#     for t in T
# }

# y = {
#     (i, p, j, t): model.addVariable(
#         vartype=xp.binary,
#         name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
#     )
#     for i in I 
#     for p in P 
#     for j in M 
#     for t in T
# }

# Q = {
#     (p, k, t): model.addVariable(
#         vartype=xp.continuous,
#         lb=0,
#         name=f'Q_{p}_{k}_{t}'
#     )
#     for p in P 
#     for k in K 
#     for t in T
# }


alpha_max = {
    p: {
        "calories": 2000,
        #"cholesterol": 300,
        #"sodium": 2300,
        "dietary_fiber": 1e30 
    }
    for p in P
}
alpha_min = {
    p: {
        "calories": 2000,
        #"cholesterol": 0,
        #"sodium": 0,
        "dietary_fiber": 28
    }
    for p in P
}
gamma_max = {
    p: {
        "calories": 2000,    
        #"cholesterol": 300,
        #"sodium": 2300,
        "dietary_fiber": 1e30
    }
    for p in P
}
gamma_min = {
    p: {
        "calories": 2000,    
        #"cholesterol": 0,
        #"sodium": 0,
        "dietary_fiber": 28
    }
    for p in P
}
# Out:
# C:\Users\18320\AppData\Local\Temp\ipykernel_40276\1804568764.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
# C:\Users\18320\AppData\Local\Temp\ipykernel_40276\1804568764.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# calculate pi
X = score_preference.copy()
features = list(X.columns)
X = X.values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=5) 
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_pca) 
score_preference['cluster'] = clusters

def p_score(score_preference, p_number):
    score_mean = pd.DataFrame()

    total_samples = len(score_preference)
    p_weight = []
    for cluster_label in range(p_number):
        cluster_size = len(score_preference[score_preference['cluster'] == cluster_label])
        p_weight.append(cluster_size / total_samples)

    for i, p_weight in enumerate(p_weight):
        print(f"p {i+1}: {p_weight:.2f}")

    for cluster_label in range(p_number):
        cluster_data = score_preference[score_preference['cluster'] == cluster_label] 
        cluster_mean = cluster_data.drop('cluster', axis=1).mean() 
        score_mean[cluster_label] = cluster_mean 

    score_mean = score_mean.T
    print("\nAverage values for each p:")
    print(score_mean)

    return p_weight, score_mean

p_score(score_preference, p_number=3)
p_weight, score_mean = p_score(score_preference, p_number=3)
patron_cluster = dict(enumerate(clusters))

item_names = [meal_data.loc[i, "item_name"] for i in range(num_item)]

pi = { p: { i: 0 for i in range(num_item) } for p in range(3) }
for p in range(3):
    for i in range(num_item):
        dish_name = item_names[i]
        try:
            pi[p][i] = score_mean.loc[p, dish_name]
        except KeyError:
            print(f"在 score_mean 中未找到聚类 {p} 对应的菜品 {dish_name} 数据，默认赋值为0")
            pi[p][i] = 0

# check pi
for p in range(3):
    print(f"聚类 {p} 对各菜品的偏好得分：", pi[p])
# Out:
# c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\18320\AppData\Local\Temp\ipykernel_40276\76535748.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   score_preference['cluster'] = clusters
# p 1: 0.36
# p 2: 0.29
# p 3: 0.36
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                      1.70              1.800             1.500
# 1                      1.75              2.125             2.625
# 2                      2.30              2.100             2.300
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                             2.700                       1.60       1.800
# 1                             2.375                       2.75       1.625
# 2                             2.200                       2.30       2.300
#
#    Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.8                             2.0                    1.500
# 1  2.0                             2.0                    2.625
# 2  1.9                             2.2                    1.900
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0                    1.6  ...                   2.300
# 1                    2.0  ...                   2.625
# 2                    2.0  ...                   1.900
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                        2.10             2.100
# 1                        1.75             2.375
# 2                        2.30             1.600
#
#    Green Pepper And Onion Omelette  \
# 0                            2.100
# 1                            1.375
# 2                            2.400
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                              2.300                  1.900
# 1                                              2.625                  1.125
# 2                                              1.600                  2.000
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0       1.40                                2.500
# 1       1.75                                1.375
# 2       2.20                                1.700
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                                2.40                    2.300
# 1                                1.75                    1.875
# 2                                1.80                    2.100
#
# [3 rows x 130 columns]
# p 1: 0.36
# p 2: 0.29
# p 3: 0.36
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                      1.70              1.800             1.500
# 1                      1.75              2.125             2.625
# 2                      2.30              2.100             2.300
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                             2.700                       1.60       1.800
# 1                             2.375                       2.75       1.625
# 2                             2.200                       2.30       2.300
#
#    Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.8                             2.0                    1.500
# 1  2.0                             2.0                    2.625
# 2  1.9                             2.2                    1.900
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0                    1.6  ...                   2.300
# 1                    2.0  ...                   2.625
# 2                    2.0  ...                   1.900
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                        2.10             2.100
# 1                        1.75             2.375
# 2                        2.30             1.600
#
#    Green Pepper And Onion Omelette  \
# 0                            2.100
# 1                            1.375
# 2                            2.400
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                              2.300                  1.900
# 1                                              2.625                  1.125
# 2                                              1.600                  2.000
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0       1.40                                2.500
# 1       1.75                                1.375
# 2       2.20                                1.700
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                                2.40                    2.300
# 1                                1.75                    1.875
# 2                                1.80                    2.100
#
# [3 rows x 130 columns]
# 聚类 0 对各菜品的偏好得分： {0: 1.7, 1: 1.8, 2: 1.5, 3: 2.7, 4: 1.6, 5: 1.8, 6: 1.8, 7: 2.0, 8: 1.5, 9: 1.6, 10: 1.4, 11: 2.6, 12: 2.3, 13: 1.7, 14: 1.6, 15: 2.0, 16: 1.9, 17: 2.1, 18: 2.6, 19: 2.4, 20: 1.8, 21: 2.3, 22: 1.9, 23: 2.0, 24: 1.9, 25: 2.2, 26: 2.6, 27: 1.6, 28: 2.1, 29: 2.0, 30: 2.0, 31: 2.3, 32: 2.3, 33: 1.8, 34: 1.4, 35: 2.0, 36: 2.3, 37: 2.1, 38: 2.2, 39: 2.2, 40: 2.6, 41: 2.0, 42: 1.6, 43: 1.8, 44: 2.5, 45: 2.0, 46: 2.5, 47: 2.1, 48: 1.7, 49: 2.0, 50: 1.9, 51: 2.3, 52: 2.2, 53: 1.9, 54: 2.2, 55: 1.4, 56: 1.7, 57: 1.8, 58: 1.7, 59: 2.5, 60: 1.5, 61: 1.9, 62: 1.9, 63: 1.5, 64: 2.0, 65: 1.8, 66: 2.3, 67: 2.2, 68: 2.0, 69: 2.1, 70: 1.5, 71: 1.1, 72: 1.3, 73: 2.5, 74: 1.5, 75: 1.7, 76: 2.6, 77: 1.8, 78: 1.8, 79: 2.0, 80: 1.9, 81: 2.3, 82: 2.3, 83: 2.1, 84: 2.4, 85: 1.6, 86: 1.4, 87: 2.2, 88: 1.6, 89: 2.0, 90: 2.4, 91: 1.7, 92: 2.0, 93: 2.4, 94: 1.5, 95: 1.6, 96: 1.3, 97: 2.0, 98: 2.4, 99: 1.9, 100: 2.6, 101: 1.7, 102: 2.0, 103: 2.1, 104: 1.6, 105: 2.1, 106: 2.3, 107: 2.0, 108: 2.0, 109: 2.5, 110: 1.9, 111: 1.9, 112: 1.8, 113: 2.8, 114: 1.8, 115: 2.5, 116: 2.2, 117: 2.1, 118: 2.0, 119: 1.8, 120: 2.3, 121: 2.1, 122: 2.1, 123: 2.1, 124: 2.3, 125: 1.9, 126: 1.4, 127: 2.5, 128: 2.4, 129: 2.3}
# 聚类 1 对各菜品的偏好得分： {0: 1.75, 1: 2.125, 2: 2.625, 3: 2.375, 4: 2.75, 5: 1.625, 6: 2.0, 7: 2.0, 8: 2.625, 9: 2.0, 10: 2.375, 11: 1.5, 12: 2.0, 13: 1.75, 14: 2.875, 15: 2.0, 16: 1.75, 17: 2.125, 18: 1.75, 19: 1.375, 20: 2.125, 21: 2.25, 22: 2.5, 23: 1.875, 24: 2.125, 25: 1.75, 26: 2.875, 27: 1.625, 28: 2.0, 29: 2.125, 30: 1.625, 31: 2.125, 32: 2.0, 33: 2.0, 34: 1.75, 35: 1.5, 36: 2.0, 37: 1.875, 38: 2.0, 39: 2.0, 40: 2.25, 41: 1.875, 42: 2.625, 43: 2.375, 44: 2.125, 45: 2.25, 46: 1.875, 47: 2.75, 48: 2.125, 49: 2.125, 50: 2.125, 51: 2.0, 52: 2.125, 53: 1.75, 54: 1.75, 55: 2.5, 56: 2.625, 57: 1.875, 58: 2.375, 59: 2.5, 60: 1.875, 61: 1.875, 62: 1.5, 63: 1.875, 64: 1.875, 65: 2.375, 66: 2.0, 67: 2.25, 68: 1.375, 69: 2.25, 70: 2.25, 71: 2.25, 72: 2.5, 73: 2.625, 74: 2.875, 75: 2.125, 76: 2.125, 77: 2.375, 78: 1.875, 79: 1.875, 80: 2.75, 81: 1.875, 82: 2.125, 83: 2.125, 84: 2.375, 85: 1.75, 86: 1.5, 87: 1.625, 88: 2.25, 89: 1.5, 90: 1.875, 91: 1.5, 92: 1.5, 93: 2.0, 94: 2.5, 95: 2.0, 96: 1.75, 97: 2.125, 98: 2.5, 99: 1.625, 100: 2.0, 101: 2.25, 102: 1.875, 103: 2.0, 104: 2.125, 105: 2.0, 106: 1.5, 107: 1.625, 108: 2.0, 109: 1.875, 110: 1.5, 111: 1.625, 112: 1.625, 113: 1.75, 114: 2.0, 115: 1.75, 116: 2.125, 117: 1.75, 118: 1.875, 119: 2.75, 120: 2.625, 121: 1.75, 122: 2.375, 123: 1.375, 124: 2.625, 125: 1.125, 126: 1.75, 127: 1.375, 128: 1.75, 129: 1.875}
# 聚类 2 对各菜品的偏好得分： {0: 2.3, 1: 2.1, 2: 2.3, 3: 2.2, 4: 2.3, 5: 2.3, 6: 1.9, 7: 2.2, 8: 1.9, 9: 2.0, 10: 2.1, 11: 2.2, 12: 2.4, 13: 2.2, 14: 2.1, 15: 2.5, 16: 2.0, 17: 2.3, 18: 1.6, 19: 1.7, 20: 2.0, 21: 1.7, 22: 2.2, 23: 1.9, 24: 2.0, 25: 2.0, 26: 2.0, 27: 1.8, 28: 1.7, 29: 1.6, 30: 2.2, 31: 1.6, 32: 1.5, 33: 2.3, 34: 2.1, 35: 2.2, 36: 2.3, 37: 2.2, 38: 2.4, 39: 1.3, 40: 2.2, 41: 1.9, 42: 1.9, 43: 1.9, 44: 2.1, 45: 2.3, 46: 1.9, 47: 1.7, 48: 1.8, 49: 2.7, 50: 1.6, 51: 2.0, 52: 2.3, 53: 1.5, 54: 1.9, 55: 1.9, 56: 1.8, 57: 2.6, 58: 2.7, 59: 2.2, 60: 2.0, 61: 2.6, 62: 2.2, 63: 2.0, 64: 2.3, 65: 2.2, 66: 2.1, 67: 1.9, 68: 2.2, 69: 2.1, 70: 1.9, 71: 2.5, 72: 2.0, 73: 1.9, 74: 2.1, 75: 2.0, 76: 1.5, 77: 2.1, 78: 1.8, 79: 2.4, 80: 1.6, 81: 2.3, 82: 1.7, 83: 2.0, 84: 1.8, 85: 2.2, 86: 2.0, 87: 2.1, 88: 1.6, 89: 2.2, 90: 2.5, 91: 2.3, 92: 2.3, 93: 1.6, 94: 2.4, 95: 2.4, 96: 2.0, 97: 1.4, 98: 2.1, 99: 2.0, 100: 2.4, 101: 2.0, 102: 1.5, 103: 2.5, 104: 1.5, 105: 2.0, 106: 2.0, 107: 2.2, 108: 2.1, 109: 1.6, 110: 2.1, 111: 1.9, 112: 2.3, 113: 2.1, 114: 1.7, 115: 1.9, 116: 2.1, 117: 2.0, 118: 2.0, 119: 2.2, 120: 1.9, 121: 2.3, 122: 1.6, 123: 2.4, 124: 1.6, 125: 2.0, 126: 2.2, 127: 1.7, 128: 1.8, 129: 2.1}

# %% [markdown]
# model-1

# %%
pi
# Out:
# {0: {0: 1.7,
#   1: 1.8,
#   2: 1.5,
#   3: 2.7,
#   4: 1.6,
#   5: 1.8,
#   6: 1.8,
#   7: 2.0,
#   8: 1.5,
#   9: 1.6,
#   10: 1.4,
#   11: 2.6,
#   12: 2.3,
#   13: 1.7,
#   14: 1.6,
#   15: 2.0,
#   16: 1.9,
#   17: 2.1,
#   18: 2.6,
#   19: 2.4,
#   20: 1.8,
#   21: 2.3,
#   22: 1.9,
#   23: 2.0,
#   24: 1.9,
#   25: 2.2,
#   26: 2.6,
#   27: 1.6,
#   28: 2.1,
#   29: 2.0,
#   30: 2.0,
#   31: 2.3,
#   32: 2.3,
#   33: 1.8,
#   34: 1.4,
#   35: 2.0,
#   36: 2.3,
#   37: 2.1,
#   38: 2.2,
#   39: 2.2,
#   40: 2.6,
#   41: 2.0,
#   42: 1.6,
#   43: 1.8,
#   44: 2.5,
#   45: 2.0,
#   46: 2.5,
#   47: 2.1,
#   48: 1.7,
#   49: 2.0,
#   50: 1.9,
#   51: 2.3,
#   52: 2.2,
#   53: 1.9,
#   54: 2.2,
#   55: 1.4,
#   56: 1.7,
#   57: 1.8,
#   58: 1.7,
#   59: 2.5,
#   60: 1.5,
#   61: 1.9,
#   62: 1.9,
#   63: 1.5,
#   64: 2.0,
#   65: 1.8,
#   66: 2.3,
#   67: 2.2,
#   68: 2.0,
#   69: 2.1,
#   70: 1.5,
#   71: 1.1,
#   72: 1.3,
#   73: 2.5,
#   74: 1.5,
#   75: 1.7,
#   76: 2.6,
#   77: 1.8,
#   78: 1.8,
#   79: 2.0,
#   80: 1.9,
#   81: 2.3,
#   82: 2.3,
#   83: 2.1,
#   84: 2.4,
#   85: 1.6,
#   86: 1.4,
#   87: 2.2,
#   88: 1.6,
#   89: 2.0,
#   90: 2.4,
#   91: 1.7,
#   92: 2.0,
#   93: 2.4,
#   94: 1.5,
#   95: 1.6,
#   96: 1.3,
#   97: 2.0,
#   98: 2.4,
#   99: 1.9,
#   100: 2.6,
#   101: 1.7,
#   102: 2.0,
#   103: 2.1,
#   104: 1.6,
#   105: 2.1,
#   106: 2.3,
#   107: 2.0,
#   108: 2.0,
#   109: 2.5,
#   110: 1.9,
#   111: 1.9,
#   112: 1.8,
#   113: 2.8,
#   114: 1.8,
#   115: 2.5,
#   116: 2.2,
#   117: 2.1,
#   118: 2.0,
#   119: 1.8,
#   120: 2.3,
#   121: 2.1,
#   122: 2.1,
#   123: 2.1,
#   124: 2.3,
#   125: 1.9,
#   126: 1.4,
#   127: 2.5,
#   128: 2.4,
#   129: 2.3},
#  1: {0: 1.75,
#   1: 2.125,
#   2: 2.625,
#   3: 2.375,
#   4: 2.75,
#   5: 1.625,
#   6: 2.0,
#   7: 2.0,
#   8: 2.625,
#   9: 2.0,
#   10: 2.375,
#   11: 1.5,
#   12: 2.0,
#   13: 1.75,
#   14: 2.875,
#   15: 2.0,
#   16: 1.75,
#   17: 2.125,
#   18: 1.75,
#   19: 1.375,
#   20: 2.125,
#   21: 2.25,
#   22: 2.5,
#   23: 1.875,
#   24: 2.125,
#   25: 1.75,
#   26: 2.875,
#   27: 1.625,
#   28: 2.0,
#   29: 2.125,
#   30: 1.625,
#   31: 2.125,
#   32: 2.0,
#   33: 2.0,
#   34: 1.75,
#   35: 1.5,
#   36: 2.0,
#   37: 1.875,
#   38: 2.0,
#   39: 2.0,
#   40: 2.25,
#   41: 1.875,
#   42: 2.625,
#   43: 2.375,
#   44: 2.125,
#   45: 2.25,
#   46: 1.875,
#   47: 2.75,
#   48: 2.125,
#   49: 2.125,
#   50: 2.125,
#   51: 2.0,
#   52: 2.125,
#   53: 1.75,
#   54: 1.75,
#   55: 2.5,
#   56: 2.625,
#   57: 1.875,
#   58: 2.375,
#   59: 2.5,
#   60: 1.875,
#   61: 1.875,
#   62: 1.5,
#   63: 1.875,
#   64: 1.875,
#   65: 2.375,
#   66: 2.0,
#   67: 2.25,
#   68: 1.375,
#   69: 2.25,
#   70: 2.25,
#   71: 2.25,
#   72: 2.5,
#   73: 2.625,
#   74: 2.875,
#   75: 2.125,
#   76: 2.125,
#   77: 2.375,
#   78: 1.875,
#   79: 1.875,
#   80: 2.75,
#   81: 1.875,
#   82: 2.125,
#   83: 2.125,
#   84: 2.375,
#   85: 1.75,
#   86: 1.5,
#   87: 1.625,
#   88: 2.25,
#   89: 1.5,
#   90: 1.875,
#   91: 1.5,
#   92: 1.5,
#   93: 2.0,
#   94: 2.5,
#   95: 2.0,
#   96: 1.75,
#   97: 2.125,
#   98: 2.5,
#   99: 1.625,
#   100: 2.0,
#   101: 2.25,
#   102: 1.875,
#   103: 2.0,
#   104: 2.125,
#   105: 2.0,
#   106: 1.5,
#   107: 1.625,
#   108: 2.0,
#   109: 1.875,
#   110: 1.5,
#   111: 1.625,
#   112: 1.625,
#   113: 1.75,
#   114: 2.0,
#   115: 1.75,
#   116: 2.125,
#   117: 1.75,
#   118: 1.875,
#   119: 2.75,
#   120: 2.625,
#   121: 1.75,
#   122: 2.375,
#   123: 1.375,
#   124: 2.625,
#   125: 1.125,
#   126: 1.75,
#   127: 1.375,
#   128: 1.75,
#   129: 1.875},
#  2: {0: 2.3,
#   1: 2.1,
#   2: 2.3,
#   3: 2.2,
#   4: 2.3,
#   5: 2.3,
#   6: 1.9,
#   7: 2.2,
#   8: 1.9,
#   9: 2.0,
#   10: 2.1,
#   11: 2.2,
#   12: 2.4,
#   13: 2.2,
#   14: 2.1,
#   15: 2.5,
#   16: 2.0,
#   17: 2.3,
#   18: 1.6,
#   19: 1.7,
#   20: 2.0,
#   21: 1.7,
#   22: 2.2,
#   23: 1.9,
#   24: 2.0,
#   25: 2.0,
#   26: 2.0,
#   27: 1.8,
#   28: 1.7,
#   29: 1.6,
#   30: 2.2,
#   31: 1.6,
#   32: 1.5,
#   33: 2.3,
#   34: 2.1,
#   35: 2.2,
#   36: 2.3,
#   37: 2.2,
#   38: 2.4,
#   39: 1.3,
#   40: 2.2,
#   41: 1.9,
#   42: 1.9,
#   43: 1.9,
#   44: 2.1,
#   45: 2.3,
#   46: 1.9,
#   47: 1.7,
#   48: 1.8,
#   49: 2.7,
#   50: 1.6,
#   51: 2.0,
#   52: 2.3,
#   53: 1.5,
#   54: 1.9,
#   55: 1.9,
#   56: 1.8,
#   57: 2.6,
#   58: 2.7,
#   59: 2.2,
#   60: 2.0,
#   61: 2.6,
#   62: 2.2,
#   63: 2.0,
#   64: 2.3,
#   65: 2.2,
#   66: 2.1,
#   67: 1.9,
#   68: 2.2,
#   69: 2.1,
#   70: 1.9,
#   71: 2.5,
#   72: 2.0,
#   73: 1.9,
#   74: 2.1,
#   75: 2.0,
#   76: 1.5,
#   77: 2.1,
#   78: 1.8,
#   79: 2.4,
#   80: 1.6,
#   81: 2.3,
#   82: 1.7,
#   83: 2.0,
#   84: 1.8,
#   85: 2.2,
#   86: 2.0,
#   87: 2.1,
#   88: 1.6,
#   89: 2.2,
#   90: 2.5,
#   91: 2.3,
#   92: 2.3,
#   93: 1.6,
#   94: 2.4,
#   95: 2.4,
#   96: 2.0,
#   97: 1.4,
#   98: 2.1,
#   99: 2.0,
#   100: 2.4,
#   101: 2.0,
#   102: 1.5,
#   103: 2.5,
#   104: 1.5,
#   105: 2.0,
#   106: 2.0,
#   107: 2.2,
#   108: 2.1,
#   109: 1.6,
#   110: 2.1,
#   111: 1.9,
#   112: 2.3,
#   113: 2.1,
#   114: 1.7,
#   115: 1.9,
#   116: 2.1,
#   117: 2.0,
#   118: 2.0,
#   119: 2.2,
#   120: 1.9,
#   121: 2.3,
#   122: 1.6,
#   123: 2.4,
#   124: 1.6,
#   125: 2.0,
#   126: 2.2,
#   127: 1.7,
#   128: 1.8,
#   129: 2.1}}

# %%
xp.init('C:/xpressmp/bin/xpauth.xpr')

# %%
model = xp.problem()
max_time=1000
model.addVariable(x)
model.addVariable(y)
model.addVariable(Q)


dw = {0: 0.36, 1: 0.29, 2: 0.36}
Total_preference_score = xp.Sum(dw[p] * y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

model.setObjective(Total_preference_score, sense=xp.maximize)

#A.6
for j in M:
    for l in L:
        for t in T:
            model.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7
for t in T:
    for j in M:
        for l in L:
            if l in {"Main dish", "Side", "Soup", "Breakfast"}:    
                for s in S_l:
                    if ns.get((j,l),0) >= 1:
                       model.addConstraint(
                           xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                       )


# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )

# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        model.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            model.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 5
                )
        if l == "Soup":
            for s in S_l[l]:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
        if l == "Dessert":
            if s == "cake":
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
            else:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 0
                )

# A.16 limiting consecutive repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            model.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# def wrap_day(day: int, total_days: int) -> int:
#     return day % total_days

# num_day = len(T)

# for i in I:
#     Gi = G_i.get(i, 0)  # 从字典 G 中获取菜品 i 的间隔天数
#     if Gi <= 0:
#         continue
    
#     for t in T:
#         if t <= Gi:
#             continue
        
#         lhs_terms = []
#         for j in M:
#             for c in range(1, Gi + 1):
#                 target_day = wrap_day(t + c - Gi, num_day)
#                 # 若使用全局供应变量 x，则直接使用 x[i,j,t]
#                 # 若需从 y 推导 x，则 x[i,j,t] = 1 ↔ Σ_p y[i,p,j,t] ≥ 1
#                 # 此处假设 x 存在且定义为 x[i,j,t] = xp.Indicator(y[i,p,j,t] >= 1 for p in P)
#                 lhs_terms.append(x[i, j, target_day])
#         lhs = xp.Sum(lhs_terms)
        
#         # --- 右侧项：1 - Σ_{j∈M} x[i,j,t-Gi] ---
#         rhs_terms = [x[i, j, t - Gi] for j in M]
#         rhs = 1 - xp.Sum(rhs_terms)
        
#         model.addConstraint(lhs <= rhs)

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items

for p in P:
    for j in M:
        for l in L:
            for t in T:
                #if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )

for p in P:
    for k in K:
        for t in T:
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y
            )
            model.addConstraint(
                nutrient_intake >= alpha_min[p][k] - gamma_min[p][k] * Q[(p, k, t)]
            )

# A.23
for p in P:
    for k in K:
        for t in T:
            model.addConstraint(Q[(p, k, t)] <= 0.3)

# breakfast cost
breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
)
non_breakfast_courses = [l for l in L if l != 'Breakfast']
# lunch cost
lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
)
# dinner cost
dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
)
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
)

print(f"optimal objective:{model.getObjVal()}")
# for t in T:
#     for c in range(W):
#         print(f"nw(t={t}, c={c}) = {nw(t, T, c)}")
# Out:
# optimal objective:1e+40

# %%
model.setControl('maxtime', max_time )
print(model.getControl('maxtime'))
best_bound = model.getAttrib('bestbound')
mip_gap = 150*((model.getObjVal()-best_bound)/model.getObjVal())

xp.setOutputEnabled(True)
model.solve()
# Out:
# 1000

# %%
xp.setOutputEnabled(True)
model.solve()
# Out:
# FICO Xpress v9.4.2, Hyper, solve started 17:25:51, Mar 11, 2025
# Heap usage: 10MB (peak 10MB, 2775KB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      17171 rows        10962 cols       109131 elements     10920 entities
# Presolved problem has:
#       5690 rows         5908 cols        42309 elements      5908 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 12MB (peak 23MB, 2775KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.04e-01,  1.00e+30] / [ 9.36e-03,  1.51e+00]
#   RHS and bounds [min,max] : [ 3.00e-01,  2.00e+03] / [ 2.10e-01,  5.00e+00]
#   Objective      [min,max] : [ 3.26e-01,  1.01e+00] / [ 3.26e-01,  2.35e+00]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 5064
#  Number of orbits: 2532, largest orbit: 2
#  Row orbits: 2374, row support: 4748
# Will try to keep branch and bound tree memory usage below 224MB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  215.37781   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 3401 simplex iterations, 0.44s
#         Barrier: 14 barrier and 552 simplex iterations, 0.43s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0        215.377811      P      0     0        .000000     0
# Barrier solved problem
#   14 barrier and 552 simplex iterations in 0.44 seconds at time 0
#
# Final objective                       : 2.153778106034925e+02
#   Max primal violation      (abs/rel) : 8.882e-16 / 8.882e-16
#   Max dual violation        (abs/rel) : 4.259e-15 / 4.259e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                 215.377811      0     13      0              956     13
# P          198.912250   215.377811      1                  7.64%       0     13
#    2  K    198.912250   215.373364      1      4     10    7.64%     973     13
#    3  K    198.912250   215.373364      1      9      5    7.64%     918     13
#    4  K    198.912250   215.373364      1      9      6    7.64%     961     14
#    5  K    198.912250   215.373364      1      8      9    7.64%     957     14
#    6  K    198.912250   215.348875      1      4      8    7.63%     945     14
#    7  K    198.912250   215.348875      1      1      4    7.63%     973     14
#    8  K    198.912250   215.348875      1      0      1    7.63%     973     14
#    9  G    198.912250   215.348812      1      7      0    7.63%     973     14
# R          199.705750   215.348529      2                  7.26%       0     14
# R          200.174750   215.348529      3                  7.05%       0     16
# R          200.464500   215.348529      4                  6.91%       0     16
# R          200.680500   215.348529      5                  6.81%       0     16
# R          200.932500   215.348529      6                  6.69%       0     16
# R          201.400500   215.348529      7                  6.48%       0     16
# R          201.689750   215.348529      8                  6.34%       0     16
# R          202.233750   215.348529      9                  6.09%       0     16
# R          202.558500   215.348529     10                  5.94%       0     16
# R          202.776000   215.348529     11                  5.84%       0     16
# R          202.993750   215.348529     12                  5.74%       0     16
# R          203.281750   215.348529     13                  5.60%       0     16
# R          203.501250   215.348529     14                  5.50%       0     16
# R          203.718500   215.348529     15                  5.40%       0     16
# R          203.970500   215.348529     16                  5.28%       0     16
# R          204.114250   215.348529     17                  5.22%       0     16
# R          204.257250   215.348529     18                  5.15%       0     16
# R          204.473250   215.348529     19                  5.05%       0     16
# R          204.581500   215.348529     20                  5.00%       0     16
# R          204.871500   215.348529     21                  4.87%       0     16
# R          205.159500   215.348529     22                  4.73%       0     16
# R          205.267500   215.348529     23                  4.68%       0     16
# R          205.374500   215.348529     24                  4.63%       0     16
# R          205.555750   215.348529     25                  4.55%       0     16
# R          205.663250   215.348529     26                  4.50%       0     16
# R          205.846000   215.348529     27                  4.41%       0     16
# R          205.991000   215.348529     28                  4.35%       0     16
# R          206.245000   215.348529     29                  4.23%       0     16
# R          206.390250   215.348529     30                  4.16%       0     16
# R          206.498250   215.348529     31                  4.11%       0     16
# R          206.604500   215.348529     32                  4.06%       0     16
# R          206.819250   215.348529     33                  3.96%       0     16
# R          207.215000   215.348529     34                  3.78%       0     16
# R          207.323000   215.348529     35                  3.73%       0     16
# R          207.432250   215.348529     36                  3.68%       0     16
# R          207.540250   215.348529     37                  3.63%       0     16
# R          207.685750   215.348529     38                  3.56%       0     16
# R          207.795000   215.348529     39                  3.51%       0     16
# R          207.867000   215.348529     40                  3.47%       0     16
# R          207.938750   215.348529     41                  3.44%       0     16
# R          208.047000   215.348529     42                  3.39%       0     16
#   10  G    208.047000   215.348529     42     19      6    3.39%     960     17
#   11  G    208.047000   215.347863     42      6     17    3.39%     963     17
#   12  G    208.047000   215.347863     42      7     13    3.39%     971     17
# Heuristic search 'R' started
# R          208.299000   215.347863     43                  3.27%       0     19
# R          208.514750   215.347863     44                  3.17%       0     19
# R          208.586750   215.347863     45                  3.14%       0     19
# R          208.659250   215.347863     46                  3.11%       0     19
# Heuristic search 'R' stopped
# M          208.768000   215.347863     47                  3.06%       0     21
# M          208.840000   215.347863     48                  3.02%       0     21
# M          209.127000   215.347863     49                  2.89%       0     21
# M          209.307000   215.347863     50                  2.81%       0     21
# M          209.379000   215.347863     51                  2.77%       0     21
# M          209.451000   215.347863     52                  2.74%       0     21
# M          209.559000   215.347863     53                  2.69%       0     22
# M          209.631000   215.347863     54                  2.65%       0     22
# M          209.775000   215.347863     55                  2.59%       0     22
# M          209.883000   215.347863     56                  2.54%       0     22
# M          209.956750   215.347863     57                  2.50%       0     22
#
# Cuts in the matrix         : 8
# Cut elements in the matrix : 22105
# Will try to keep branch and bound tree memory usage below 157MB
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 36MB (peak 83MB, 6274KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1   209.956750   215.347863     57      2      1    2.50%     976     25
#        2   209.956750   215.347863     57      2      3    2.50%     935     26
#        3   209.956750   215.274546     57      3      3    2.47%     876     26
#        4   209.956750   215.274546     57      4      4    2.47%     877     27
#        5   209.956750   215.274546     57      4      4    2.47%     770     27
#        6   209.956750   215.274546     57      4      4    2.47%     950     28
#        7   209.956750   215.274546     57      6      4    2.47%     782     28
#        8   209.956750   215.274546     57      8      5    2.47%     798     29
#        9   209.956750   215.274546     57      8      5    2.47%     947     29
# Will try to keep branch and bound tree memory usage below 24MB
# Will try to keep branch and bound tree memory usage below 21MB
#       10   209.956750   215.274546     57      9      5    2.47%     880     30
#       20   209.956750   215.236584     57     18      8    2.45%     843     33
#       30   209.956750   215.227770     57     26     11    2.45%     830     37
#       40   209.956750   215.227770     57     34      9    2.45%     778     40
#       50   209.956750   215.197891     57     41     15    2.44%     751     44
#       60   209.956750   215.197891     57     43     14    2.44%     801     48
#       70   209.956750   215.197891     57     46     21    2.44%     760     51
#       80   209.956750   215.197891     57     63     19    2.44%     827     54
#       90   209.956750   215.197891     57     66     28    2.44%     784     58
#      100   209.956750   215.197891     57     79     26    2.44%     739     62
# Will try to keep branch and bound tree memory usage below 33MB
# Will try to keep branch and bound tree memory usage below 36MB
# Elapsed time (sec): 90, estimated tree completion: 0.00000
# Heap usage: 138MB (peak 138MB, 10211KB system)
# B&B tree size: 1.0MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200   209.956750   215.197891     57    162     49    2.44%     741     90
#      300   209.956750   215.197891     57    203     69    2.44%     765    106
# Will try to keep branch and bound tree memory usage below 38MB
#      400   209.956750   215.197891     57    249    100    2.44%     627    115
#      500   209.956750   215.197891     57    357    192    2.44%     362    123
#      600   209.956750   215.197891     57    411    111    2.44%     654    129
#      700   209.956750   215.197891     57    542    292    2.44%     357    135
#      800   209.956750   215.197891     57    587    195    2.44%     424    139
#      900   209.956750   215.197891     57    624    374    2.44%     348    144
#     1000   209.956750   215.197891     57    864    161    2.44%     525    147
#     1100   209.956750   215.197891     57    893    448    2.44%     303    151
#     1200   209.956750   215.197891     57    921    228    2.44%     500    155
#     1301   209.956750   215.197891     57    963    224    2.44%     437    157
#     1401   209.956750   215.197891     57   1011    258    2.44%     506    160
#     1501   209.956750   215.197891     57   1011     15    2.44%     845    166
#     1602   209.956750   215.197891     57   1210    309    2.44%     414    171
#     1702   209.956750   215.197891     57   1210    450    2.44%     337    176
#     1802   209.956750   215.197891     57   1210    377    2.44%     403    179
#     1902   209.956750   215.197891     57   1210    404    2.44%     381    182
#     2002   209.956750   215.197891     57   1210    434    2.44%     361    186
# R   2077   210.100750   215.197891     58   1559      4    2.37%       0    190
# Elapsed time (sec): 191, estimated tree completion: 0.00000
# Heap usage: 210MB (peak 214MB, 12MB system)
# B&B tree size: 12MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# R   2094   210.930500   215.197891     59   1559      4    1.98%       0    191
#     2103   210.930500   215.197891     59   1559    430    1.98%     274    192
#     2203   210.930500   215.197891     59   1560    530    1.98%     351    197
#     2303   210.930500   215.197891     59   2030    588    1.98%     396    203
#     2403   210.930500   215.197891     59   2291     10    1.98%     801    220
#     2503   210.930500   215.197891     59   2335     68    1.98%     765    246
#     2604   210.930500   215.189763     59   2451     47    1.98%     769    264
#     2704   210.930500   215.189763     59   2496     70    1.98%     688    279
#     2804   210.930500   215.189763     59   2598    111    1.98%     631    294
#     2905   210.930500   215.189763     59   2598     80    1.98%     640    307
#     3005   210.930500   215.189763     59   2598    157    1.98%     575    320
#     3105   210.930500   215.189763     59   2685     93    1.98%     665    329
#     3205   210.930500   215.189763     59   2838    149    1.98%     551    337
#     3305   210.930500   215.189763     59   2981     78    1.98%     645    344
#     3406   210.930500   215.189763     59   2981    247    1.98%     501    353
#     3506   210.930500   215.189763     59   3079    201    1.98%     419    362
#     3606   210.930500   215.189763     59   3079     97    1.98%     594    370
#     3706   210.930500   215.189763     59   3079    143    1.98%     586    377
#     3806   210.930500   215.189763     59   3079    338    1.98%     386    383
#     3906   210.930500   215.189763     59   3079    230    1.98%     454    390
# Elapsed time (sec): 396, estimated tree completion: 0.00000
# Heap usage: 306MB (peak 310MB, 17MB system)
# B&B tree size: 27MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4006   210.930500   215.189763     59   3312    121    1.98%     634    396
#     4106   210.930500   215.189763     59   3402     36    1.98%     768    402
#     4207   210.930500   215.189763     59   3732    523    1.98%     270    407
#     4309   210.930500   215.189763     59   3732    565    1.98%     278    412
# Resetting tree to root.
#
# Performing root presolve...
# Will try to keep branch and bound tree memory usage below 5.4GB
#
# Reduced problem has:    5694 rows    5903 columns     63841 elements
# Presolve dropped   :       4 rows       5 columns       573 elements
# Will try to keep branch and bound tree memory usage below 5.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve, 418s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  215.31942   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 2389816 simplex iterations, 0.52s
#         Barrier: 15 barrier and 484 simplex iterations, 0.51s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0        215.319417      P      0     0        .000000   418
# Barrier solved problem
#   15 barrier and 484 simplex iterations in 0.53 seconds at time 418
#
# Final objective                       : 2.153194168683970e+02
#   Max primal violation      (abs/rel) : 1.055e-15 / 1.055e-15
#   Max dual violation        (abs/rel) : 2.460e-15 / 2.460e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K    210.930500   215.189763     59     26      5    1.98%     866    423
# P          211.003000   215.189763     60                  1.95%       0    423
# P          211.038500   215.189763     61                  1.93%       0    423
# P          211.038750   215.189763     62                  1.93%       0    423
# P          211.074500   215.189763     63                  1.91%       0    423
# P          211.111000   215.189763     64                  1.90%       0    423
# P          211.147000   215.189763     65                  1.88%       0    423
# P          211.290000   215.189763     66                  1.81%       0    423
# P          211.326000   215.189763     67                  1.80%       0    423
# P          211.362000   215.189763     68                  1.78%       0    423
# P          211.398000   215.189763     69                  1.76%       0    423
# P          211.468000   215.189763     70                  1.73%       0    423
#    2  K    211.468000   215.189763     70     13     21    1.73%     827    424
#    3  K    211.468000   215.189763     70     18     12    1.73%     770    425
#    4  K    211.468000   215.189763     70     32     17    1.73%     839    425
#    5  K    211.468000   215.180943     70     16     28    1.73%     909    426
# P          211.756000   215.180943     71                  1.59%       0    426
# P          211.828000   215.180943     72                  1.56%       0    426
#    6  K    211.828000   215.164279     72     33     22    1.55%     834    426
# P          211.900750   215.164279     73                  1.52%       0    426
# P          211.936750   215.164279     74                  1.50%       0    426
#    7  K    211.936750   215.136868     74     18     28    1.49%     901    427
#    8  K    211.936750   215.130391     74     17     21    1.48%     855    428
# P          212.008750   215.130391     75                  1.45%       0    428
#    9  K    212.008750   215.110162     75     26     15    1.44%     869    428
#   10  K    212.008750   215.109686     75     18     27    1.44%     909    431
#   11  K    212.008750   215.099778     75     10     15    1.44%     938    431
#   12  K    212.008750   215.070414     75     23      9    1.42%     938    432
#   13  K    212.008750   215.029320     75     12     21    1.40%     931    432
#   14  K    212.008750   215.013214     75     13     10    1.40%     927    432
#   15  K    212.008750   214.988897     75     27     13    1.39%     943    433
#   16  K    212.008750   214.978377     75      8     34    1.38%     832    433
#   17  K    212.008750   214.978377     75     12      8    1.38%     869    433
#   18  K    212.008750   214.959494     75     15      8    1.37%     896    434
# P          212.080750   214.959494     76                  1.34%       0    434
#   19  K    212.080750   214.946703     76     12     11    1.33%     889    434
#   20  K    212.080750   214.941888     76      7     11    1.33%     908    434
#   21  K    212.080750   214.922480     76      7      9    1.32%     914    435
#   22  K    212.080750   214.922480     76     10     16    1.32%     869    435
#   23  K    212.080750   214.922480     76      3      6    1.32%     879    435
#   24  K    212.080750   214.922480     76      4      2    1.32%     881    435
#   25  K    212.080750   214.922480     76      7      5    1.32%     879    435
#   26  K    212.080750   214.922480     76      0      3    1.32%     897    435
#   27  G    212.080750   214.922480     76     17      0    1.32%     897    436
#   28  G    212.080750   214.922480     76     15     26    1.32%     922    436
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# P          212.189250   214.922480     77                  1.27%       0    443
# P          212.227500   214.922480     78                  1.25%       0    443
# P          212.263500   214.922480     79                  1.24%       0    443
#
# Cuts in the matrix         : 24
# Cut elements in the matrix : 6406
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 39MB (peak 310MB, 6283KB system)
# Elapsed time (sec): 444, estimated tree completion: 0.00000
# Heap usage: 39MB (peak 310MB, 6283KB system)
# B&B tree size: 94k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4395   212.263500   214.922480     79      2      1    1.24%     947    444
#     4396   212.263500   214.922480     79      2      3    1.24%     950    446
#     4397   212.263500   214.922480     79      2      3    1.24%     841    446
#     4398   212.263500   214.922480     79      2      4    1.24%     950    447
#     4399   212.263500   214.922480     79      3      4    1.24%     841    447
#     4400   212.263500   214.915537     79      4      5    1.23%     942    448
#     4401   212.263500   214.915537     79      5      4    1.23%     845    449
#     4402   212.263500   214.915537     79      5      5    1.23%     861    449
#     4403   212.263500   214.915537     79      6      6    1.23%     942    450
#     4404   212.263500   214.899682     79      7      4    1.23%     806    451
#     4414   212.263500   214.899064     79     12      7    1.23%     801    455
#     4424   212.263500   214.899064     79     21      7    1.23%     734    459
#     4434   212.263500   214.875412     79     31      8    1.22%     833    463
#     4444   212.263500   214.875412     79     41     11    1.22%     864    467
#     4454   212.263500   214.875412     79     51     10    1.22%     826    471
#     4464   212.263500   214.875412     79     61     11    1.22%     797    474
#     4474   212.263500   214.875412     79     71     13    1.22%     841    479
#     4484   212.263500   214.875412     79     81     15    1.22%     751    483
#     4494   212.263500   214.875412     79     91     15    1.22%     777    487
# Elapsed time (sec): 519, estimated tree completion: 0.00000
# Heap usage: 245MB (peak 310MB, 6555KB system)
# B&B tree size: 309k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4594   212.263500   214.875412     79    191     26    1.22%     717    519
#     4694   212.263500   214.875412     79    291     40    1.22%     771    551
#     4794   212.263500   214.875412     79    391     47    1.22%     720    585
#     4894   212.263500   214.875412     79    491     57    1.22%     750    614
#     4994   212.263500   214.875412     79    591     83    1.22%     560    638
#     5094   212.263500   214.875412     79    691     76    1.22%     729    652
#     5194   212.263500   214.875412     79    791    100    1.22%     556    666
#     5294   212.263500   214.875412     79    891    103    1.22%     453    679
#     5394   212.263500   214.875412     79    991    121    1.22%     505    689
#     5494   212.263500   214.875412     79   1091    148    1.22%     512    699
#     5594   212.263500   214.875412     79   1191    148    1.22%     525    709
#     5694   212.263500   214.875412     79   1291    158    1.22%     463    718
#     5794   212.263500   214.875412     79   1391    162    1.22%     533    727
#     5894   212.263500   214.875412     79   1491    158    1.22%     581    736
#     5994   212.263500   214.875412     79   1591    200    1.22%     405    744
#     6094   212.263500   214.875412     79   1691    129    1.22%     689    753
#     6194   212.263500   214.875412     79   1786    189    1.22%     475    760
#     6294   212.263500   214.875412     79   1884    203    1.22%     390    768
#     6394   212.263500   214.875412     79   1980    147    1.22%     520    776
#     6494   212.263500   214.875412     79   2078    283    1.22%     381    784
# Elapsed time (sec): 793, estimated tree completion: 0.00000
# Heap usage: 282MB (peak 310MB, 6586KB system)
# B&B tree size: 11MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6594   212.263500   214.875412     79   2175    286    1.22%     342    793
#     6694   212.263500   214.875412     79   2272    368    1.22%     177    799
#     6794   212.263500   214.875412     79   2362    264    1.22%     397    810
#     6894   212.263500   214.875412     79   2453    247    1.22%     253    818
#     6994   212.263500   214.875412     79   2538    319    1.22%     277    826
#     7094   212.263500   214.875412     79   2622    317    1.22%     258    837
#     7194   212.263500   214.875412     79   2686    305    1.22%     279    854
#     7294   212.263500   214.875412     79   2756    344    1.22%     227    868
#     7394   212.263500   214.875412     79   2817     28    1.22%     775    881
#     7494   212.263500   214.875412     79   2896    261    1.22%     392    897
#     7594   212.263500   214.875412     79   2971     43    1.22%     789    918
#     7694   212.263500   214.875412     79   3022    322    1.22%     320    936
#     7794   212.263500   214.875412     79   3111     37    1.22%     777    952
#     7894   212.263500   214.875412     79   3167     18    1.22%     665    972
#     7994   212.263500   214.875412     79   3287     18    1.22%     657    989
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=1000.00  time=1000.00).
#  *** Search unfinished ***    Time:  1000.31 Nodes:       8073
# Final MIP objective                   : 2.122635000000001e+02
# Final MIP bound                       : 2.148754116374893e+02
#   Solution time / primaldual integral :   1000.31s/  2.944324%
#   Number of solutions found / nodes   :        79 /      8073
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.STOPPED: 1>, <SolStatus.FEASIBLE: 2>)

# %% [markdown]
# model 2

# %%
# add variables and parameters
Qmax = {
    p: xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Qmax_{p}'
    )
    for p in P 
}

model2 = xp.problem()
model2.addVariable(x)
model2.addVariable(y)
model2.addVariable(Qmax)

W_Q = 1
W_pi = 0
Total_variation = xp.Sum(W_Q * Qmax[p]/2 + W_pi * (300-y[i, p, j, t] * pi[p][i])/300  for i in I for p in P for j in M for t in T)

model2.setObjective(Total_variation, sense=xp.minimize)

# %%
model2.setControl('maxtime', max_time )
print(model2.getControl('maxtime'))
best_bound = model2.getAttrib('bestbound')
mip_gap = 150*((model2.getObjVal()-best_bound)/model2.getObjVal())

xp.setOutputEnabled(True)
model2.solve()
# Out:
# 1000
# FICO Xpress v9.4.2, Hyper, solve started 18:53:32, Mar 11, 2025
# Heap usage: 4141KB (peak 4141KB, 9050KB system)
# Minimizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = 1
# Original problem has:
#          0 rows        10923 cols            0 elements     10920 entities
# Presolved problem has:
#          0 rows        10923 cols            0 elements     10920 entities
# Presolve finished in 0 seconds
# Heap usage: 5763KB (peak 6020KB, 9050KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [      0.0,       0.0] / [      0.0,       0.0]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [ 1.36e+03,  1.36e+03] / [ 1.36e+03,  1.36e+03]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 5.4GB
#  *** Solution found:      .000000   Time:   0.09    Heuristic: T ***
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=0).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 0.000000000000000e-01
# Final MIP bound                       : 0.000000000000000e-01
#   Solution time / primaldual integral :      0.10s/ 92.572095%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.COMPLETED: 3>, <SolStatus.OPTIMAL: 1>)

# %%
y_solution = {key: model.getSolution(var) for key, var in y.items()}

# show the items that selected
selected_y = {key: value for key, value in y_solution.items() if value > 0.5}

df_y = pd.DataFrame([
    {"Item": key[0], "Guest": key[1], "Meal": key[2], "Time": key[3], "Value": value}
    for key, value in selected_y.items()
])
df_y.to_csv("3.11y_result.csv", index=False)

preference_scores = {}

for t in T:
    score = 0
    for p in P:
        for j in M:
            for i in I:
                score += y_solution[(i, p, j, t)] * pi[p][i]
    preference_scores[t] = score
    
df = pd.DataFrame(list(preference_scores.items()), columns=['Day', 'Preference Score'])

df.to_csv('3.11daily_preference_scores.csv', index=False)
