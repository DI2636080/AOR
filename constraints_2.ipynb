# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xpress as xp
import pandas as pd

# %% [markdown]
# initialisation

# %%
meal_data_path = 'meal_data.xlsx'
meal_data = pd.read_excel(meal_data_path)
meal_data.head()
# Out:
#                           item_name course_type subcategories  meal_type  \
# 0          Trick OR Treat Ice Cream        Soup         cream        NaN
# 1                 Sweet Fries Snack        Side         fried        NaN
# 2                  Tomatoes - Salad        Side    red orange        NaN
# 3  Chicken BBQ Caesar Salad EntrÌ©e   Main dish       poultry        NaN
# 4         Corn and Black Bean Salad        Side        legume        NaN
#
#    cost  nf_calories  nf_calories_from_fat  nf_total_fat  nf_saturated_fat  \
# 0  2.08       300.00                 140.0          16.0               9.0
# 1  2.27      1150.00                 690.0          79.0               7.0
# 2  3.45         9.58                   2.4           0.0               0.0
# 3  3.95       203.00                   NaN           NaN               2.1
# 4  3.59       140.00                  10.0           1.0               0.0
#
#    nf_trans_fatty_acid  ...  nf_vitamin_a_dv  nf_vitamin_c_dv  nf_calcium_dv  \
# 0                  0.0  ...              8.0              2.0           15.0
# 1                  0.0  ...              NaN              NaN            NaN
# 2                  0.0  ...              5.0             14.0            0.0
# 3                  NaN  ...              NaN              NaN            NaN
# 4                  0.0  ...              2.0              4.0            2.0
#
#    nf_iron_dv  nf_potassium  nf_servings_per_container  nf_serving_size_qty  \
# 0         4.0           NaN                        NaN                 4.00
# 1         NaN           NaN                        NaN                13.40
# 2         0.0           NaN                        NaN                45.52
# 3         NaN           NaN                        NaN                 2.00
# 4        10.0           NaN                        NaN                 1.00
#
#    nf_serving_size_unit  nf_serving_weight_grams  images_front_full_url
# 0             oz scoops                      NaN                    NaN
# 1                    oz                      NaN                    NaN
# 2                 Grams                    45.52                    NaN
# 3              servings                      NaN                    NaN
# 4                 Salad                      NaN                    NaN
#
# [5 rows x 28 columns]

# %%
score_preference_path = 'score_preference.xlsx'
score_preference = pd.read_excel(score_preference_path)
score_preference.set_index('Unnamed: 0', inplace=True)
score_preference.head()
# Out:
#             Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# Unnamed: 0
# 0                                  1                  3                 3
# 1                                  3                  2                 1
# 2                                  3                  2                 3
# 3                                  1                  2                 1
# 4                                  2                  1                 1
#
#             Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  \
# Unnamed: 0
# 0                                          3                          3
# 1                                          1                          1
# 2                                          2                          2
# 3                                          2                          3
# 4                                          3                          1
#
#             Mango Cake  Egg  Flavored Fresh Lemonade, Peach  \
# Unnamed: 0
# 0                    2    1                               2
# 1                    3    3                               2
# 2                    2    2                               2
# 3                    3    1                               1
# 4                    1    3                               3
#
#             Add Pirate Tossed Salad  Blueberry Vinaigrette  ...  \
# Unnamed: 0                                                  ...
# 0                                 3                      1  ...
# 1                                 3                      1  ...
# 2                                 1                      3  ...
# 3                                 1                      2  ...
# 4                                 1                      1  ...
#
#             Vegetable Spring Rolls  All Natural Spinach Hummus  \
# Unnamed: 0
# 0                                2                           2
# 1                                1                           1
# 2                                2                           2
# 3                                3                           2
# 4                                1                           2
#
#             Cooked Mushrooms  Green Pepper And Onion Omelette  \
# Unnamed: 0
# 0                          2                                3
# 1                          1                                2
# 2                          2                                3
# 3                          1                                1
# 4                          2                                2
#
#             Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  \
# Unnamed: 0
# 0                                                           3
# 1                                                           1
# 2                                                           1
# 3                                                           3
# 4                                                           2
#
#             Whole Grain Waffle  xiao main  \
# Unnamed: 0
# 0                            3          1
# 1                            3          3
# 2                            3          3
# 3                            1          3
# 4                            1          1
#
#             Burrito Main, Braised Pork Carnitas  \
# Unnamed: 0
# 0                                             1
# 1                                             1
# 2                                             2
# 3                                             1
# 4                                             2
#
#             Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# Unnamed: 0
# 0                                            1                        1
# 1                                            1                        3
# 2                                            3                        2
# 3                                            3                        1
# 4                                            3                        3
#
# [5 rows x 130 columns]

# %%
nutrition_criteria_path = 'nutrition_criteria.xlsx'
nutrition_criteria = pd.read_excel(nutrition_criteria_path)
nutrition_criteria.head()
# Out:
#    ID        Element     F     M  Average
# 0   1       Calories  1600  2000     1800
# 1   2         Sodium  2300  2300     2300
# 2   3   Carbohydrate   130   130      130
# 3   4  Dietary_fiber    22    28       25
# 4   5        Protein    46    56       51

# %%
table3_path = 'table3.xlsx'
meal_constraints = pd.read_excel(table3_path, sheet_name='meal_constraints', index_col=0)
diet_types = pd.read_excel(table3_path, sheet_name='diet_types', index_col=0)
maximum_servings = pd.read_excel(table3_path, sheet_name='maximum_servings')
day_item = pd.read_excel(table3_path, sheet_name='day_item')
wp = pd.read_excel(table3_path, sheet_name='wp')
wc = pd.read_excel(table3_path, sheet_name='wc')
day_item.head()
# Out:
#    Breakfast  Soup  Salad  Main dish  Side  Appetizer  Dessert
# 0          1     1      1          1   NaN        NaN        1

# %%
num_item = 130
num_day = 7
num_meal = 3
num_patron = 3
num_course = 7
num_nutrition = 5

I = list(range(num_item)) # i∈I
M = ['breakfast', 'lunch', 'dinner'] # j∈M
T = list(range(num_day)) # t∈T
P = list(range(num_patron)) # p∈P
L = ['Breakfast', 'Soup', 'Salad', 'Main dish', 'Side', 'Appetizer', 'Dessert'] # l∈L
K = list(range(num_nutrition)) # k∈K

l_i = {meal_data.index[i]: meal_data.iloc[i]["course_type"] for i in range(len(meal_data))}
I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
S_l = meal_data.groupby("course_type")["subcategories"].unique().apply(list).to_dict()
I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

ns = meal_constraints.to_dict(orient='index')
np = diet_types.to_dict(orient='index')
nsOWP = maximum_servings.to_dict(orient='records')[0]
nsd = day_item.to_dict(orient='records')[0]
wp_l = wp.to_dict(orient='records')[0]
wc_l = wc.to_dict(orient='records')[0]
pi_raw = score_preference.to_dict(orient='index')

x = {
    (i, j, t): xp.var(
        vartype=xp.binary,
        name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
    )
    for i in I for j in M for t in T
}
y = {
    (i, p, j, t): xp.var(
        vartype=xp.binary,
        name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
    )
    for i in I for p in P for j in M for t in T
}
#x = {(meal_data.loc[i,'item_name'], j, t): xp.var(vartype=xp.binary, name='x_{0}_{1}'.format(meal_data.loc[i,'item_name'],j,t)) for j in M for t in T for i in I}
#y = {(meal_data.loc[i,'item_name'],p,j,t):xp.var(vartype=xp.binary, name='y_{0}'.format(meal_data.loc[i,'item_name'],p,j,t))for p in P for j in M for t in T for i in I}
Q = {(nutrition_criteria.loc[k,'Element'],p,t):xp.var(vartype=xp.continuous, name='Q_{0}'.format(nutrition_criteria.loc[k,'Element']))for p in P for t in T for k in K }
# Out:
# C:\Users\18320\AppData\Local\Temp\ipykernel_10000\123832208.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
# C:\Users\18320\AppData\Local\Temp\ipykernel_10000\123832208.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# calculate pi
X = score_preference.copy()
features = list(X.columns)
X = X.values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=5) 
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_pca) 
score_preference['cluster'] = clusters

def p_score(score_preference, p_number):
    score_mean = pd.DataFrame()

    total_samples = len(score_preference)
    p_weight = []
    for cluster_label in range(p_number):
        cluster_size = len(score_preference[score_preference['cluster'] == cluster_label])
        p_weight.append(cluster_size / total_samples)

    for i, p_weight in enumerate(p_weight):
        print(f"p {i+1}: {p_weight:.2f}")

    for cluster_label in range(p_number):
        cluster_data = score_preference[score_preference['cluster'] == cluster_label] 
        cluster_mean = cluster_data.drop('cluster', axis=1).mean() 
        score_mean[cluster_label] = cluster_mean 

    score_mean = score_mean.T
    print("\nAverage values for each p:")
    print(score_mean)

    return p_weight, score_mean

p_score(score_preference, p_number=3)
p_weight, score_mean = p_score(score_preference, p_number=3)
patron_cluster = dict(enumerate(clusters))

item_names = [meal_data.loc[i, "item_name"] for i in range(num_item)]

pi = { p: { i: 0 for i in range(num_item) } for p in range(3) }
for p in range(3):
    for i in range(num_item):
        dish_name = item_names[i]
        try:
            pi[p][i] = score_mean.loc[p, dish_name]
        except KeyError:
            print(f"在 score_mean 中未找到聚类 {p} 对应的菜品 {dish_name} 数据，默认赋值为0")
            pi[p][i] = 0

# check pi
for p in range(3):
    print(f"聚类 {p} 对各菜品的偏好得分：", pi[p])
pi
# Out:
# c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# p 1: 0.39
# p 2: 0.29
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  1.818182           1.818182          1.636364
# 1                  1.750000           2.125000          2.625000
# 2                  2.222222           2.111111          2.222222
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          2.727273                   1.727273    1.909091
# 1                          2.375000                   2.750000    1.625000
# 2                          2.111111                   2.222222    2.222222
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.727273                        2.000000                 1.636364
# 1  2.000000                        2.000000                 2.625000
# 2  2.000000                        2.222222                 1.777778
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0               1.545455  ...                2.363636
# 1               2.000000  ...                2.625000
# 2               2.111111  ...                1.777778
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                    2.181818          2.000000
# 1                    1.750000          2.375000
# 2                    2.222222          1.666667
#
#    Green Pepper And Onion Omelette  \
# 0                         2.090909
# 1                         1.375000
# 2                         2.444444
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                           2.181818               1.818182
# 1                                           2.625000               1.125000
# 2                                           1.666667               2.111111
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0   1.363636                             2.454545
# 1   1.750000                             1.375000
# 2   2.333333                             1.666667
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                            2.454545                 2.363636
# 1                            1.750000                 1.875000
# 2                            1.666667                 2.000000
#
# [3 rows x 130 columns]
# p 1: 0.39
# p 2: 0.29
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  1.818182           1.818182          1.636364
# 1                  1.750000           2.125000          2.625000
# 2                  2.222222           2.111111          2.222222
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          2.727273                   1.727273    1.909091
# 1                          2.375000                   2.750000    1.625000
# 2                          2.111111                   2.222222    2.222222
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.727273                        2.000000                 1.636364
# 1  2.000000                        2.000000                 2.625000
# 2  2.000000                        2.222222                 1.777778
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0               1.545455  ...                2.363636
# 1               2.000000  ...                2.625000
# 2               2.111111  ...                1.777778
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                    2.181818          2.000000
# 1                    1.750000          2.375000
# 2                    2.222222          1.666667
#
#    Green Pepper And Onion Omelette  \
# 0                         2.090909
# 1                         1.375000
# 2                         2.444444
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                           2.181818               1.818182
# 1                                           2.625000               1.125000
# 2                                           1.666667               2.111111
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0   1.363636                             2.454545
# 1   1.750000                             1.375000
# 2   2.333333                             1.666667
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                            2.454545                 2.363636
# 1                            1.750000                 1.875000
# 2                            1.666667                 2.000000
#
# [3 rows x 130 columns]
# 聚类 0 对各菜品的偏好得分： {0: 1.8181818181818181, 1: 1.8181818181818181, 2: 1.6363636363636365, 3: 2.727272727272727, 4: 1.7272727272727273, 5: 1.9090909090909092, 6: 1.7272727272727273, 7: 2.0, 8: 1.6363636363636365, 9: 1.5454545454545454, 10: 1.3636363636363635, 11: 2.4545454545454546, 12: 2.3636363636363638, 13: 1.8181818181818181, 14: 1.6363636363636365, 15: 2.090909090909091, 16: 2.0, 17: 2.0, 18: 2.5454545454545454, 19: 2.4545454545454546, 20: 1.9090909090909
#   53: 1.8181818181818181,
#   54: 2.1818181818181817,
#   55: 1.3636363636363635,
#   56: 1.6363636363636365,
#   57: 1.9090909090909092,
#   58: 1.8181818181818181,
#   59: 2.5454545454545454,
#   60: 1.6363636363636365,
#   61: 1.9090909090909092,
#   62: 2.0,
#   63: 1.4545454545454546,
#   64: 2.0,
#   65: 1.9090909090909092,
#   66: 2.1818181818181817,
#   67: 2.1818181818181817,
#   68: 2.0,
#   69: 2.1818181818181817,
#   70: 1.5454545454545454,
#   71: 1.0909090909090908,
#   72: 1.3636363636363635,
#   73: 2.3636363636363638,
#   74: 1.5454545454545454,
#   75: 1.8181818181818181,
#   76: 2.4545454545454546,
#   77: 1.8181818181818181,
#   78: 1.8181818181818181,
#   79: 2.0,
#   80: 1.8181818181818181,
#   81: 2.1818181818181817,
#   82: 2.1818181818181817,
#   83: 2.1818181818181817,
#   84: 2.4545454545454546,
#   85: 1.5454545454545454,
#   86: 1.4545454545454546,
#   87: 2.272727272727273,
#   88: 1.5454545454545454,
#   89: 2.0,
#   90: 2.4545454545454546,
#   91: 1.7272727272727273,
#   92: 2.0,
#   93: 2.3636363636363638,
#   94: 1.6363636363636365,
#   95: 1.7272727272727273,
#   96: 1.4545454545454546,
#   97: 1.9090909090909092,
#   98: 2.4545454545454546,
#   99: 1.9090909090909092,
#   100: 2.6363636363636362,
#   101: 1.7272727272727273,
#   102: 1.9090909090909092,
#   103: 2.090909090909091,
#   104: 1.6363636363636365,
#   105: 2.090909090909091,
#   106: 2.1818181818181817,
#   107: 2.090909090909091,
#   108: 2.090909090909091,
#   109: 2.3636363636363638,
#   110: 1.9090909090909092,
#   111: 2.0,
#   112: 1.7272727272727273,
#   113: 2.8181818181818183,
#   114: 1.7272727272727273,
#   115: 2.4545454545454546,
#   116: 2.272727272727273,
#   117: 2.0,
#   118: 2.090909090909091,
#   119: 1.9090909090909092,
#   120: 2.3636363636363638,
#   121: 2.1818181818181817,
#   122: 2.0,
#   123: 2.090909090909091,
#   124: 2.1818181818181817,
#   125: 1.8181818181818181,
#   126: 1.3636363636363635,
#   127: 2.4545454545454546,
#   128: 2.4545454545454546,
#   129: 2.3636363636363638},
#  1: {0: 1.75,
#   1: 2.125,
#   2: 2.625,
#   3: 2.375,
#   4: 2.75,
#   5: 1.625,
#   6: 2.0,
#   7: 2.0,
#   8: 2.625,
#   9: 2.0,
#   10: 2.375,
#   11: 1.5,
#   12: 2.0,
#   13: 1.75,
#   14: 2.875,
#   15: 2.0,
#   16: 1.75,
#   17: 2.125,
#   18: 1.75,
#   19: 1.375,
#   20: 2.125,
#   21: 2.25,
#   22: 2.5,
#   23: 1.875,
#   24: 2.125,
#   25: 1.75,
#   26: 2.875,
#   27: 1.625,
#   28: 2.0,
#   29: 2.125,
#   30: 1.625,
#   31: 2.125,
#   32: 2.0,
#   33: 2.0,
#   34: 1.75,
#   35: 1.5,
#   36: 2.0,
#   37: 1.875,
#   38: 2.0,
#   39: 2.0,
#   40: 2.25,
#   41: 1.875,
#   42: 2.625,
#   43: 2.375,
#   44: 2.125,
#   45: 2.25,
#   46: 1.875,
#   47: 2.75,
#   48: 2.125,
#   49: 2.125,
#   50: 2.125,
#   51: 2.0,
#   52: 2.125,
#   53: 1.75,
#   54: 1.75,
#   55: 2.5,
#   56: 2.625,
#   57: 1.875,
#   58: 2.375,
#   59: 2.5,
#   60: 1.875,
#   61: 1.875,
#   62: 1.5,
#   63: 1.875,
#   64: 1.875,
#   65: 2.375,
#   66: 2.0,
#   67: 2.25,
#   68: 1.375,
#   69: 2.25,
#   70: 2.25,
#   71: 2.25,
#   72: 2.5,
#   73: 2.625,
#   74: 2.875,
#   75: 2.125,
#   76: 2.125,
#   77: 2.375,
#   78: 1.875,
#   79: 1.875,
#   80: 2.75,
#   81: 1.875,
#   82: 2.125,
#   83: 2.125,
#   84: 2.375,
#   85: 1.75,
#   86: 1.5,
#   87: 1.625,
#   88: 2.25,
#   89: 1.5,
#   90: 1.875,
#   91: 1.5,
#   92: 1.5,
#   93: 2.0,
#   94: 2.5,
#   95: 2.0,
#   96: 1.75,
#   97: 2.125,
#   98: 2.5,
#   99: 1.625,
#   100: 2.0,
#   101: 2.25,
#   102: 1.875,
#   103: 2.0,
#   104: 2.125,
#   105: 2.0,
#   106: 1.5,
#   107: 1.625,
#   108: 2.0,
#   109: 1.875,
#   110: 1.5,
#   111: 1.625,
#   112: 1.625,
#   113: 1.75,
#   114: 2.0,
#   115: 1.75,
#   116: 2.125,
#   117: 1.75,
#   118: 1.875,
#   119: 2.75,
#   120: 2.625,
#   121: 1.75,
#   122: 2.375,
#   123: 1.375,
#   124: 2.625,
#   125: 1.125,
#   126: 1.75,
#   127: 1.375,
#   128: 1.75,
#   129: 1.875},
#  2: {0: 2.2222222222222223,
#   1: 2.111111111111111,
#   2: 2.2222222222222223,
#   3: 2.111111111111111,
#   4: 2.2222222222222223,
#   5: 2.2222222222222223,
#   6: 2.0,
#   7: 2.2222222222222223,
#   8: 1.7777777777777777,
#   9: 2.111111111111111,
#   10: 2.2222222222222223,
#   11: 2.3333333333333335,
#   12: 2.3333333333333335,
#   13: 2.111111111111111,
#   14: 2.111111111111111,
#   15: 2.4444444444444446,
#   16: 1.8888888888888888,
#   17: 2.4444444444444446,
#   18: 1.5555555555555556,
#   19: 1.5555555555555556,
#   20: 1.8888888888888888,
#   21: 1.7777777777777777,
#   22: 2.3333333333333335,
#   23: 1.7777777777777777,
#   24: 2.0,
#   25: 2.0,
#   26: 2.111111111111111,
#   27: 1.8888888888888888,
#   28: 1.5555555555555556,
#   29: 1.6666666666666667,
#   30: 2.111111111111111,
#   31: 1.5555555555555556,
#   32: 1.4444444444444444,
#   33: 2.2222222222222223,
#   34: 2.2222222222222223,
#   35: 2.2222222222222223,
#   36: 2.4444444444444446,
#   37: 2.2222222222222223,
#   38: 2.3333333333333335,
#   39: 1.1111111111111112,
#   40: 2.111111111111111,
#   41: 1.8888888888888888,
#   42: 2.0,
#   43: 2.0,
#   44: 2.2222222222222223,
#   45: 2.3333333333333335,
#   46: 1.8888888888888888,
#   47: 1.6666666666666667,
#   48: 1.7777777777777777,
#   49: 2.7777777777777777,
#   50: 1.6666666666666667,
#   51: 2.0,
#   52: 2.3333333333333335,
#   53: 1.5555555555555556,
#   54: 1.8888888888888888,
#   55: 2.0,
#   56: 1.8888888888888888,
#   57: 2.5555555555555554,
#   58: 2.6666666666666665,
#   59: 2.111111111111111,
#   60: 1.8888888888888888,
#   61: 2.6666666666666665,
#   62: 2.111111111111111,
#   63: 2.111111111111111,
#   64: 2.3333333333333335,
#   65: 2.111111111111111,
#   66: 2.2222222222222223,
#   67: 1.8888888888888888,
#   68: 2.2222222222222223,
#   69: 2.0,
#   70: 1.8888888888888888,
#   71: 2.6666666666666665,
#   72: 2.0,
#   73: 2.0,
#   74: 2.111111111111111,
#   75: 1.8888888888888888,
#   76: 1.5555555555555556,
#   77: 2.111111111111111,
#   78: 1.7777777777777777,
#   79: 2.4444444444444446,
#   80: 1.6666666666666667,
#   81: 2.4444444444444446,
#   82: 1.7777777777777777,
#   83: 1.8888888888888888,
#   84: 1.6666666666666667,
#   85: 2.3333333333333335,
#   86: 2.0,
#   87: 2.0,
#   88: 1.6666666666666667,
#   89: 2.2222222222222223,
#   90: 2.4444444444444446,
#   91: 2.3333333333333335,
#   92: 2.3333333333333335,
#   93: 1.5555555555555556,
#   94: 2.3333333333333335,
#   95: 2.3333333333333335,
#   96: 1.8888888888888888,
#   97: 1.4444444444444444,
#   98: 2.0,
#   99: 2.0,
#   100: 2.3333333333333335,
#   101: 2.0,
#   102: 1.5555555555555556,
#   103: 2.5555555555555554,
#   104: 1.4444444444444444,
#   105: 2.0,
#   106: 2.111111111111111,
#   107: 2.111111111111111,
#   108: 2.0,
#   109: 1.6666666666666667,
#   110: 2.111111111111111,
#   111: 1.7777777777777777,
#   112: 2.4444444444444446,
#   113: 2.0,
#   114: 1.7777777777777777,
#   115: 1.8888888888888888,
#   116: 2.0,
#   117: 2.111111111111111,
#   118: 1.8888888888888888,
#   119: 2.111111111111111,
#   120: 1.7777777777777777,
#   121: 2.2222222222222223,
#   122: 1.6666666666666667,
#   123: 2.4444444444444446,
#   124: 1.6666666666666667,
#   125: 2.111111111111111,
#   126: 2.3333333333333335,
#   127: 1.6666666666666667,
#   128: 1.6666666666666667,
#   129: 2.0}}

# %% [markdown]
# model-1

# %%
ns
# Out:
# {'breakfast': {'Breakfast': 2,
#   'Soup': 0,
#   'Salad': 0,
#   'Main dish': 0,
#   'Side': 0,
#   'Appetizer': 0,
#   'Dessert': 0},
#  'lunch': {'Breakfast': 0,
#   'Soup': 2,
#   'Salad': 1,
#   'Main dish': 2,
#   'Side': 3,
#   'Appetizer': 0,
#   'Dessert': 1},
#  'dinner': {'Breakfast': 0,
#   'Soup': 2,
#   'Salad': 1,
#   'Main dish': 2,
#   'Side': 3,
#   'Appetizer': 0,
#   'Dessert': 1}}

# %%
xp.init('C:/xpressmp/bin/xpauth.xpr')

# %%
model = xp.problem()
max_time=700
model.addVariable(x)
model.addVariable(y)

#Total_cost = xp.Sum(meal_data.loc[i,'cost'] * x[meal_data.loc[i,'item_name'], j, t] for i in I for j in M for t in T)
Total_preference_score = xp.Sum(y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)

model.setObjective(Total_preference_score, sense=xp.maximize)

#A.6
for j in M:
    for l in L:
        for t in T:
            model.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7
for t in T:
    for j in M:
        for l in L:
            for s in S_l:
                if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                       xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                    )

# A.9
s_l_com ={1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )
                

# xp.setOutputEnabled(True)
# model.solve()

print(f"最优解的目标值：{model.getObjVal()}")
# Out:
# ?120 Error: Problem has too many rows and columns. The maximum is 5000
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Cell In[347], line 4
#       2 max_time=700
#       3 model.addVariable(x)
# ----> 4 model.addVariable(y)
#       6 #Total_cost = xp.Sum(meal_data.loc[i,'cost'] * x[meal_data.loc[i,'item_name'], j, t] for i in I for j in M for t in T)
#       7 Total_preference_score = xp.Sum(y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
#
# SolverError: ?120 Error: Problem has too many rows and columns. The maximum is 5000

# %%
model.setControl('maxtime', max_time )
print(model.getControl('maxtime'))
best_bound = model.getAttrib('bestbound')
mip_gap = 100*((model.getObjVal()-best_bound)/model.getObjVal())
# Out:
# 700

# %%
xp.setOutputEnabled(True)
model.solve()
# Out:
# FICO Xpress v9.4.2, Community, solve started 18:25:43, Feb 20, 2025
# Heap usage: 1381KB (peak 1381KB, 568KB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 700
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#       2101 rows         1560 cols         5460 elements      1560 entities
# Presolved problem has:
#        122 rows          224 cols          448 elements       224 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 1634KB (peak 2853KB, 568KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  3.00e+00] / [ 1.00e+00,  3.00e+00]
#   Objective      [min,max] : [ 1.09e+00,  2.88e+00] / [ 5.05e+00,  7.44e+00]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 2, support set: 24
#  Number of orbits: 12, largest orbit: 2
#  Row orbits: 2, row support: 4
# Will try to keep branch and bound tree memory usage below 33MB
# Fixed 120 (of 120) columns in 4 (of 4) subproblems
#
#  *** Solution found:   132.176768   Time:   0.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  135.30934   .0000000
#
# ------- optimal --------
# Concurrent statistics:
#            Dual: 6 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#      6        135.309343      D      0     0        .000000     0
# Dual solved problem
#   6 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.353093434343434e+02
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a          135.309343   135.309343      2                 -0.00%       0      0
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 1.353093434343434e+02
# Final MIP bound                       : 1.353093434343434e+02
#   Solution time / primaldual integral :      0.02s/ 69.911533%
#   Number of solutions found / nodes   :         2 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# (<SolveStatus.COMPLETED: 3>, <SolStatus.OPTIMAL: 1>)

# %%
#A.6
for j in M:
    for l in L:
        for t in T:
            model.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7
for t in T:
    for j in M:
        for l in L:
            for s in S_l:
                if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                       xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                    )

# A.9
s_l_com ={1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.17: item repetition constraints within a day
for course_type in I_l.keys():
    for i in I:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[course_type]
            )
            
# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# %%
#Total_cost = xp.Sum(meal_data.loc[i,'cost'] * x[meal_data.loc[i,'item_name'], j, t] for i in I for j in M for t in T)
Total_preference_score = xp.Sum(y[meal_data.loc[i,'item_name'], p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)

model.setObjective(Total_preference_score, sense=xp.maximize)

model.solve()

print(f"最优解的目标值：{model.getObjVal()}")
# Out:
# FICO Xpress v9.4.2, Community, solve started 13:29:18, Feb 20, 2025
# Heap usage: 648KB (peak 648KB, 429KB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#          0 rows         1131 cols            0 elements      1131 entities
# Presolved problem has:
#          0 rows         1131 cols            0 elements      1131 entities
# Presolve finished in 0 seconds
# Heap usage: 819KB (peak 839KB, 429KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [      0.0,       0.0] / [      0.0,       0.0]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.00e+00,  1.00e+00]
#   Objective      [min,max] : [      0.0,       0.0] / [      0.0,       0.0]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 0.7GB
#  *** Solution found:      .000000   Time:   0.01    Heuristic: T ***
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=0).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 0.000000000000000e-01
# Final MIP bound                       : 0.000000000000000e-01
#   Solution time / primaldual integral :      0.01s/ 87.348481%
#   Number of solutions found / nodes   :         1 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 最优解的目标值：0.0

# %%
# A.17: item repetition constraints within a day
for course_type in I_l.keys():
    for i in I_l[course_type]:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[course_type]
            )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[153], line 3
#       1 # A.17: item repetition constraints within a day
#       2 for l in L:
# ----> 3     for i in I_l[l]:
#       4         for t in T:
#       5             model.addConstraint(
#       6                 xp.Sum(x[(i, j, t)] for j in M) <= nsd[l],
#       7                 name = f"item_repetition_{i}_{t}"
#       8             )
#
# KeyError: 0

# %%
# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    xp.y[(p, i, j, t)]<= xp.x[(i, j, t)],
                    name = f"diet_type_{i}_{j}_{t}"
                )

# %%
# A.19: diet types: p is allowed to choose np number of items
for p in P:
    for j in M:
        for l in L:
            for t in T:
                model.addConstraint(
                    xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np[p][j][l]
                )

# %%
# A.20: HEG maximum constraints

# %%
# A.21: HEG minimum constraints

# %%
# A.23: HEG deviarion constraints
for p in P:
    for k in K:
        for t in T:
            model.addConstraint(
                xp.Q[(p, k, t)] <= 
            )
