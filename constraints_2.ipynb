# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\18320\appdata\local\anaconda3\envs\xpress\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xpress as xp
import pandas as pd

# %% [markdown]
# initialisation

# %%
meal_data_path = 'meal_data.xlsx'
meal_data = pd.read_excel(meal_data_path)
meal_data.head()
# Out:
#                           item_name course_type subcategories  meal_type  \
# 0          Trick OR Treat Ice Cream        Soup         cream        NaN
# 1                 Sweet Fries Snack        Side         fried        NaN
# 2                  Tomatoes - Salad        Side    red orange        NaN
# 3  Chicken BBQ Caesar Salad EntrÌ©e   Main dish       poultry        NaN
# 4         Corn and Black Bean Salad        Side        legume        NaN
#
#    cost  nf_calories  nf_calories_from_fat  nf_total_fat  nf_saturated_fat  \
# 0  2.08       300.00                 140.0          16.0               9.0
# 1  2.27      1150.00                 690.0          79.0               7.0
# 2  3.45         9.58                   2.4           0.0               0.0
# 3  3.95       203.00                   NaN           NaN               2.1
# 4  3.59       140.00                  10.0           1.0               0.0
#
#    nf_trans_fatty_acid  ...  nf_vitamin_a_dv  nf_vitamin_c_dv  nf_calcium_dv  \
# 0                  0.0  ...              8.0              2.0           15.0
# 1                  0.0  ...              NaN              NaN            NaN
# 2                  0.0  ...              5.0             14.0            0.0
# 3                  NaN  ...              NaN              NaN            NaN
# 4                  0.0  ...              2.0              4.0            2.0
#
#    nf_iron_dv  nf_potassium  nf_servings_per_container  nf_serving_size_qty  \
# 0         4.0           NaN                        NaN                 4.00
# 1         NaN           NaN                        NaN                13.40
# 2         0.0           NaN                        NaN                45.52
# 3         NaN           NaN                        NaN                 2.00
# 4        10.0           NaN                        NaN                 1.00
#
#    nf_serving_size_unit  nf_serving_weight_grams  images_front_full_url
# 0             oz scoops                      NaN                    NaN
# 1                    oz                      NaN                    NaN
# 2                 Grams                    45.52                    NaN
# 3              servings                      NaN                    NaN
# 4                 Salad                      NaN                    NaN
#
# [5 rows x 28 columns]

# %%
score_preference_path = 'score_preference.xlsx'
score_preference = pd.read_excel(score_preference_path)
score_preference.set_index('Unnamed: 0', inplace=True)
score_preference.head()
# Out:
#             Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# Unnamed: 0
# 0                                  1                  3                 3
# 1                                  3                  2                 1
# 2                                  3                  2                 3
# 3                                  1                  2                 1
# 4                                  2                  1                 1
#
#             Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  \
# Unnamed: 0
# 0                                          3                          3
# 1                                          1                          1
# 2                                          2                          2
# 3                                          2                          3
# 4                                          3                          1
#
#             Mango Cake  Egg  Flavored Fresh Lemonade, Peach  \
# Unnamed: 0
# 0                    2    1                               2
# 1                    3    3                               2
# 2                    2    2                               2
# 3                    3    1                               1
# 4                    1    3                               3
#
#             Add Pirate Tossed Salad  Blueberry Vinaigrette  ...  \
# Unnamed: 0                                                  ...
# 0                                 3                      1  ...
# 1                                 3                      1  ...
# 2                                 1                      3  ...
# 3                                 1                      2  ...
# 4                                 1                      1  ...
#
#             Vegetable Spring Rolls  All Natural Spinach Hummus  \
# Unnamed: 0
# 0                                2                           2
# 1                                1                           1
# 2                                2                           2
# 3                                3                           2
# 4                                1                           2
#
#             Cooked Mushrooms  Green Pepper And Onion Omelette  \
# Unnamed: 0
# 0                          2                                3
# 1                          1                                2
# 2                          2                                3
# 3                          1                                1
# 4                          2                                2
#
#             Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  \
# Unnamed: 0
# 0                                                           3
# 1                                                           1
# 2                                                           1
# 3                                                           3
# 4                                                           2
#
#             Whole Grain Waffle  xiao main  \
# Unnamed: 0
# 0                            3          1
# 1                            3          3
# 2                            3          3
# 3                            1          3
# 4                            1          1
#
#             Burrito Main, Braised Pork Carnitas  \
# Unnamed: 0
# 0                                             1
# 1                                             1
# 2                                             2
# 3                                             1
# 4                                             2
#
#             Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# Unnamed: 0
# 0                                            1                        1
# 1                                            1                        3
# 2                                            3                        2
# 3                                            3                        1
# 4                                            3                        3
#
# [5 rows x 130 columns]

# %%
nutrition_criteria_path = 'nutrition_criteria.xlsx'
nutrition_criteria = pd.read_excel(nutrition_criteria_path)
nutrition_criteria.head()
# Out:
#    ID        Element     F     M  Average
# 0   1       Calories  1600  2000     1800
# 1   2         Sodium  2300  2300     2300
# 2   3   Carbohydrate   130   130      130
# 3   4  Dietary_fiber    22    28       25
# 4   5        Protein    46    56       51

# %%
table3_path = 'table3.xlsx'
meal_constraints = pd.read_excel(table3_path, sheet_name='meal_constraints', index_col=0)
diet_types = pd.read_excel(table3_path, sheet_name='diet_types', index_col=0)
maximum_servings = pd.read_excel(table3_path, sheet_name='maximum_servings')
day_item = pd.read_excel(table3_path, sheet_name='day_item')
wp = pd.read_excel(table3_path, sheet_name='wp')
wc = pd.read_excel(table3_path, sheet_name='wc')
day_item.head()
# Out:
#    Breakfast  Soup  Salad  Main dish  Side  Appetizer  Dessert
# 0          1     1      1          1   NaN        NaN        1

# %%
# model = xp.problem()
num_item = 130
num_day = 7
num_meal = 3
num_patron = 3
num_course = 7
#num_nutrition = 5

I = list(range(num_item)) # i∈I
M = ['breakfast', 'lunch', 'dinner'] # j∈M
T = list(range(num_day)) # t∈T
P = list(range(num_patron)) # p∈P
L = ['Breakfast', 'Soup', 'Salad', 'Main dish', 'Side', 'Appetizer', 'Dessert'] # l∈L
#K = list(range(num_nutrition)) # k∈K
K = ['calories','cholesterol','sodium','dietary_fiber']

l_i = {meal_data.index[i]: meal_data.iloc[i]["course_type"] for i in range(len(meal_data))}
I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
S_l = meal_data.groupby("course_type")["subcategories"].unique().apply(list).to_dict()
I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()
# w_ki_cal = {meal_data.index[i]: meal_data.iloc[i]["nf_calories"] for i in range(len(meal_data))}
# w_ki_cho = {meal_data.index[i]: meal_data.iloc[i]["nf_cholesterol"] for i in range(len(meal_data))}
# w_ki_sod = {meal_data.index[i]: meal_data.iloc[i]["nf_sodium"] for i in range(len(meal_data))}
# w_ki_diet = {meal_data.index[i]: meal_data.iloc[i]["nf_dietary_fiber"] for i in range(len(meal_data))}
w = {
    "calories": {i: meal_data.iloc[i]["nf_calories"] for i in I},
    "cholesterol": {i: meal_data.iloc[i]["nf_cholesterol"] for i in I},
    "sodium": {i: meal_data.iloc[i]["nf_sodium"] for i in I},
    "dietary_fiber": {i: meal_data.iloc[i]["nf_dietary_fiber"] for i in I},
}

ns = meal_constraints.to_dict(orient='index')
np = diet_types.to_dict(orient='index')
np_expanded = {p: {j: {l: np[j][l] for l in L} for j in M} for p in P}
nsOWP = maximum_servings.to_dict(orient='records')[0]
nsd = day_item.to_dict(orient='records')[0]
wp_l = wp.to_dict(orient='records')[0]
wc_l = wc.to_dict(orient='records')[0]
pi_raw = score_preference.to_dict(orient='index')
cost = {i: meal_data.loc[i, 'cost'] for i in I}

x = {
    (i, j, t): xp.var(
        vartype=xp.binary,
        name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
    )
    for i in I for j in M for t in T
}
y = {
    (i, p, j, t): xp.var(
        vartype=xp.binary,
        name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
    )
    for i in I for p in P for j in M for t in T
}
Q = {
    (p, k, t): xp.var(
        vartype=xp.continuous,
        lb=0,
        name=f'Q_{p}_{k}_{t}'
    )
    for p in P 
    for k in K 
    for t in T
}

# x = {
#     (i, j, t): model.addVariable(
#         vartype=xp.binary,
#         name=f'x_{i}_{meal_data.loc[i, "item_name"]}_{j}_{t}'
#     )
#     for i in I 
#     for j in M 
#     for t in T
# }

# y = {
#     (i, p, j, t): model.addVariable(
#         vartype=xp.binary,
#         name=f'y_{i}_{meal_data.loc[i, "item_name"]}_{p}_{j}_{t}'
#     )
#     for i in I 
#     for p in P 
#     for j in M 
#     for t in T
# }

# Q = {
#     (p, k, t): model.addVariable(
#         vartype=xp.continuous,
#         lb=0,
#         name=f'Q_{p}_{k}_{t}'
#     )
#     for p in P 
#     for k in K 
#     for t in T
# }


alpha_max = {
    p: {
        "calories": 2000,
        "cholesterol": 300,
        "sodium": 2300,
        "dietary_fiber": 1e30 
    }
    for p in P  # 假设 P 是人物集合，如 P = [0, 1, 2]
}
alpha_min = {
    p: {
        "calories": 2000,
        "cholesterol": 300,
        "sodium": 2300,
        "dietary_fiber": 28
    }
    for p in P  # 假设 P 是人物集合，如 P = [0, 1, 2]
}
gamma_max = {
    p: {
        "calories": 2000,    
        "cholesterol": 300,
        "sodium": 2300,
        "dietary_fiber": 1e30 #极大值表示无穷大
    }
    for p in P
}
gamma_min = {
    p: {
        "calories": 2000,    
        "cholesterol": 300,
        "sodium": 0,
        "dietary_fiber": 28 #极大值表示无穷大
    }
    for p in P
}
# Out:
# C:\Users\18320\AppData\Local\Temp\ipykernel_32236\4249856078.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_l = meal_data.groupby("course_type").apply(lambda x: list(x.index)).to_dict()
# C:\Users\18320\AppData\Local\Temp\ipykernel_32236\4249856078.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   I_ls = meal_data.groupby(["course_type", "subcategories"]).apply(lambda x: list(x.index)).to_dict()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# calculate pi
X = score_preference.copy()
features = list(X.columns)
X = X.values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=5) 
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_pca) 
score_preference['cluster'] = clusters

def p_score(score_preference, p_number):
    score_mean = pd.DataFrame()

    total_samples = len(score_preference)
    p_weight = []
    for cluster_label in range(p_number):
        cluster_size = len(score_preference[score_preference['cluster'] == cluster_label])
        p_weight.append(cluster_size / total_samples)

    for i, p_weight in enumerate(p_weight):
        print(f"p {i+1}: {p_weight:.2f}")

    for cluster_label in range(p_number):
        cluster_data = score_preference[score_preference['cluster'] == cluster_label] 
        cluster_mean = cluster_data.drop('cluster', axis=1).mean() 
        score_mean[cluster_label] = cluster_mean 

    score_mean = score_mean.T
    print("\nAverage values for each p:")
    print(score_mean)

    return p_weight, score_mean

p_score(score_preference, p_number=3)
p_weight, score_mean = p_score(score_preference, p_number=3)
patron_cluster = dict(enumerate(clusters))

item_names = [meal_data.loc[i, "item_name"] for i in range(num_item)]

pi = { p: { i: 0 for i in range(num_item) } for p in range(3) }
for p in range(3):
    for i in range(num_item):
        dish_name = item_names[i]
        try:
            pi[p][i] = score_mean.loc[p, dish_name]
        except KeyError:
            print(f"在 score_mean 中未找到聚类 {p} 对应的菜品 {dish_name} 数据，默认赋值为0")
            pi[p][i] = 0

# check pi
for p in range(3):
    print(f"聚类 {p} 对各菜品的偏好得分：", pi[p])
# Out:
# p 1: 0.39
# p 2: 0.29
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  1.818182           1.818182          1.636364
# 1                  1.750000           2.125000          2.625000
# 2                  2.222222           2.111111          2.222222
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          2.727273                   1.727273    1.909091
# 1                          2.375000                   2.750000    1.625000
# 2                          2.111111                   2.222222    2.222222
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.727273                        2.000000                 1.636364
# 1  2.000000                        2.000000                 2.625000
# 2  2.000000                        2.222222                 1.777778
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0               1.545455  ...                2.363636
# 1               2.000000  ...                2.625000
# 2               2.111111  ...                1.777778
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                    2.181818          2.000000
# 1                    1.750000          2.375000
# 2                    2.222222          1.666667
#
#    Green Pepper And Onion Omelette  \
# 0                         2.090909
# 1                         1.375000
# 2                         2.444444
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                           2.181818               1.818182
# 1                                           2.625000               1.125000
# 2                                           1.666667               2.111111
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0   1.363636                             2.454545
# 1   1.750000                             1.375000
# 2   2.333333                             1.666667
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                            2.454545                 2.363636
# 1                            1.750000                 1.875000
# 2                            1.666667                 2.000000
#
# [3 rows x 130 columns]
# p 1: 0.39
# p 2: 0.29
# p 3: 0.32
#
# Average values for each p:
#    Trick OR Treat Ice Cream  Sweet Fries Snack  Tomatoes - Salad  \
# 0                  1.818182           1.818182          1.636364
# 1                  1.750000           2.125000          2.625000
# 2                  2.222222           2.111111          2.222222
#
#    Chicken BBQ Caesar Salad EntrÌ©e  Corn and Black Bean Salad  Mango Cake  \
# 0                          2.727273                   1.727273    1.909091
# 1                          2.375000                   2.750000    1.625000
# 2                          2.111111                   2.222222    2.222222
#
#         Egg  Flavored Fresh Lemonade, Peach  Add Pirate Tossed Salad  \
# 0  1.727273                        2.000000                 1.636364
# 1  2.000000                        2.000000                 2.625000
# 2  2.000000                        2.222222                 1.777778
#
#    Blueberry Vinaigrette  ...  Vegetable Spring Rolls  \
# 0               1.545455  ...                2.363636
# 1               2.000000  ...                2.625000
# 2               2.111111  ...                1.777778
#
#    All Natural Spinach Hummus  Cooked Mushrooms  \
# 0                    2.181818          2.000000
# 1                    1.750000          2.375000
# 2                    2.222222          1.666667
#
#    Green Pepper And Onion Omelette  \
# 0                         2.090909
# 1                         1.375000
# 2                         2.444444
#
#    Pork Gyoza Pot Stickers Pork and Vegetable Dumplings  Whole Grain Waffle  \
# 0                                           2.181818               1.818182
# 1                                           2.625000               1.125000
# 2                                           1.666667               2.111111
#
#    xiao main  Burrito Main, Braised Pork Carnitas  \
# 0   1.363636                             2.454545
# 1   1.750000                             1.375000
# 2   2.333333                             1.666667
#
#    Nachos Main, Braised Pork Carnitas  Sausage Pizza Deep Dish
# 0                            2.454545                 2.363636
# 1                            1.750000                 1.875000
# 2                            1.666667                 2.000000
#
# [3 rows x 130 columns]
# 聚类 0 对各菜品的偏好得分： {0: 1.8181818181818181, 1: 1.8181818181818181, 2: 1.6363636363636365, 3: 2.727272727272727, 4: 1.7272727272727273, 5: 1.9090909090909092, 6: 1.7272727272727273, 7: 2.0, 8: 1.6363636363636365, 9: 1.5454545454545454, 10: 1.3636363636363635, 11: 2.4545454545454546, 12: 2.3636363636363638, 13: 1.8181818181818181, 14: 1.6363636363636365, 15: 2.090909090909091, 16: 2.0, 17: 2.0, 18: 2.5454545454545454, 19: 2.4545454545454546, 20: 1.9090909090909092, 21: 2.1818181818181817, 22: 1.8181818181818181, 23: 2.090909090909091, 24: 1.9090909090909092, 25: 2.1818181818181817, 26: 2.4545454545454546, 27: 1.5454545454545454, 28: 2.1818181818181817, 29: 1.9090909090909092, 30: 2.090909090909091, 31: 2.272727272727273, 32: 2.272727272727273, 33: 1.9090909090909092, 34: 1.3636363636363635, 35: 2.0, 36: 2.1818181818181817, 37: 2.090909090909091, 38: 2.272727272727273, 39: 2.272727272727273, 40: 2
222223, 67: 1.8888888888888888, 68: 2.2222222222222223, 69: 2.0, 70: 1.8888888888888888, 71: 2.6666666666666665, 72: 2.0, 73: 2.0, 74: 2.111111111111111, 75: 1.8888888888888888, 76: 1.5555555555555556, 77: 2.111111111111111, 78: 1.7777777777777777, 79: 2.4444444444444446, 80: 1.6666666666666667, 81: 2.4444444444444446, 82: 1.7777777777777777, 83: 1.8888888888888888, 84: 1.6666666666666667, 85: 2.3333333333333335, 86: 2.0, 87: 2.0, 88: 1.6666666666666667, 89: 2.2222222222222223, 90: 2.4444444444444446, 91: 2.3333333333333335, 92: 2.3333333333333335, 93: 1.5555555555555556, 94: 2.3333333333333335, 95: 2.3333333333333335, 96: 1.8888888888888888, 97: 1.4444444444444444, 98: 2.0, 99: 2.0, 100: 2.3333333333333335, 101: 2.0, 102: 1.5555555555555556, 103: 2.5555555555555554, 104: 1.4444444444444444, 105: 2.0, 106: 2.111111111111111, 107: 2.111111111111111, 108: 2.0, 109: 1.6666666666666667, 110: 2.111111111111111, 111: 1.7777777777777777, 112: 2.4444444444444446, 113: 2.0, 114: 1.7777777777777777, 115: 1.8888888888888888, 116: 2.0, 117: 2.111111111111111, 118: 1.8888888888888888, 119: 2.111111111111111, 120: 1.7777777777777777, 121: 2.2222222222222223, 122: 1.6666666666666667, 123: 2.4444444444444446, 124: 1.6666666666666667, 125: 2.111111111111111, 126: 2.3333333333333335, 127: 1.6666666666666667, 128: 1.6666666666666667, 129: 2.0}
# c:\Users\18320\AppData\Local\anaconda3\envs\Xpress\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# model-1

# %%
S_l
# Out:
# {'Appetizer': ['fried', 'vegetable', 'protein'],
#  'Breakfast': ['toast', 'batter', 'meat', 'egg'],
#  'Dessert': ['cake', 'ice cream', 'pie', 'pudding'],
#  'Main dish': ['poultry',
#   'beef',
#   'pork',
#   'grain',
#   'fish',
#   'shell',
#   'vegetable',
#   'pasta'],
#  'Salad': [nan],
#  'Side': ['fried',
#   'red orange',
#   'legume',
#   'protein',
#   'fruit',
#   'vegetable-other',
#   'dark green',
#   'starch',
#   'grain',
#   'Red orange'],
#  'Soup': ['cream', 'Pottage', 'Clear', 'Legume', 'Cream', 'Noodle']}

# %%
xp.init('C:/xpressmp/bin/xpauth.xpr')

# %%
model = xp.problem()
max_time=1000
model.addVariable(x)
model.addVariable(y)
model.addVariable(Q)

#Total_cost = xp.Sum(meal_data.loc[i,'cost'] * x[meal_data.loc[i,'item_name'], j, t] for i in I for j in M for t in T)
Total_preference_score = xp.Sum(y[i, p, j, t] * pi[p][i] for i in I for p in P for j in M for t in T)
Total_cost = xp.Sum(cost[i] * x[i,j,t] for i in I for j in M for t in T)

model.setObjective(Total_preference_score, sense=xp.maximize)

#A.6
for j in M:
    for l in L:
        for t in T:
            model.addConstraint(
                xp.Sum(x[i, j, t] for i in I_l[l]) == ns[j][l]
            )

# A.7
for t in T:
    for j in M:
        for l in L:
            for s in S_l:
                if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                       xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Maximum_Number_of_Items_per_Subcategory_{t}_{j}_{l}_{s}'
                    )


# A.9 course subcategory dependencies
s_l_com = {1:['beef','pork'],2:['fish','shellfish'],3:['grain','pasta']}
for t in T:
    for j in M:
        for l in L:
            if ns.get((j,l),0) >= 2:
                for s in s_l_com[1]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[2]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')
                for s in s_l_com[3]:
                    model.addConstraint(xp.Sum(x[i,j,t] for i in I_ls[l][s]) <=1, name=f'Course_Sbucategory_Dependencies_{t}_{j}_{l}_{s}')

# A.10 item dependencies
s_l_dependencies = {1:['beef','poultry','pork'],2:['starch'],3:['vegetable'],4:['grain']}
for t in T:
    for j in M:
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[1] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[2] if (l, s) in I_ls for i in I_ls[(l, s)])
            )
        if "Main dish" in L and "Side" in L:
            model.addConstraint(xp.Sum(x[(i, j, t)] for s in s_l_dependencies[3] if (l, s) in I_ls for i in I_ls[(l, s)]) \
                <= xp.Sum(x[(i, j, t)] for s in s_l_dependencies[4] if (l, s) in I_ls for i in I_ls[(l, s)])
            )


# A.11-12 maximum number of servings of items in a menu cycle
nsT_max = 3
for i in I:
    if "Main dish" in L:
        model.addConstraint(
            xp.Sum(x[(i, j, t)] for j in M for t in T) <= nsT_max
        )          

# A.13 maximum number of servings of items in OWPs
def nw(t, T, c):
    return (t + c) % len(T)
W = 3
for l in L:
    for t in T:
        for i in I_l[l]:
            model.addConstraint(
                #xp.Sum(x[(i, j, c)] for j in M for c in range(W)) <= nsOWP[l]
                xp.Sum(x[(i, j, nw(t, T, c))] for j in M for c in range(W)) <= nsOWP[l]    
            )

# A.14-15 maximum/minimum number of course subcategories in OWPs
for t in T:
    for l in L:
        if l == "Main dish":
            for s in S_l[l]:
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) >= 1
                )
                model.addConstraint(
                    xp.Sum(x[(i, j, nw(t, T, c))] for i in I_ls.get((l, s), []) for j in M for c in range(W)) <= 5
                )

# A.16 limiting consecutive  repetitions of items
G_i = {i: 1 for i in I}
for i in I:
    for t in T:
        if t > G_i[i]:
            model.addConstraint(
                xp.Sum(x[(i, j, nw(t + c - G_i[i], T, 1))] for j in M for c in range(1, G_i[i] + 1)) \
                <= 1 - xp.Sum(x[(i, j, t - G_i[i])] for j in M)
            )

# def wrap_day(day: int, total_days: int) -> int:
#     return day % total_days

# num_day = len(T)

# for i in I:
#     Gi = G_i.get(i, 0)  # 从字典 G 中获取菜品 i 的间隔天数
#     if Gi <= 0:
#         continue
    
#     for t in T:
#         if t <= Gi:
#             continue
        
#         lhs_terms = []
#         for j in M:
#             for c in range(1, Gi + 1):
#                 target_day = wrap_day(t + c - Gi, num_day)
#                 # 若使用全局供应变量 x，则直接使用 x[i,j,t]
#                 # 若需从 y 推导 x，则 x[i,j,t] = 1 ↔ Σ_p y[i,p,j,t] ≥ 1
#                 # 此处假设 x 存在且定义为 x[i,j,t] = xp.Indicator(y[i,p,j,t] >= 1 for p in P)
#                 lhs_terms.append(x[i, j, target_day])
#         lhs = xp.Sum(lhs_terms)
        
#         # --- 右侧项：1 - Σ_{j∈M} x[i,j,t-Gi] ---
#         rhs_terms = [x[i, j, t - Gi] for j in M]
#         rhs = 1 - xp.Sum(rhs_terms)
        
#         model.addConstraint(lhs <= rhs)

# A.17: item repetition constraints within a day
for l in L:
    for i in I:
        for t in T:
            model.addConstraint(
                xp.Sum(x[(i, j, t)] for j in M) <= nsd[l]
            )

# A.18: diet types: p can choose only the items that offered
for p in P: 
    for j in M:
        for i in I:
            for t in T:
                model.addConstraint(
                    y[(i, p, j, t)]<= x[(i, j, t)]
                )

# A.19: diet types: p is allowed to choose np number of items

for p in P:
    for j in M:
        for l in L:
            for t in T:
                #if ns.get((j,l),0) >= 1:
                    model.addConstraint(
                        xp.Sum(y[(i, p, j, t)] for i in I_l[l]) == np_expanded[p][j][l]
                    )
                    
# A.20-21
for p in P:
    for k in K:
        for t in T:
            # 计算总营养摄入量: ∑_{j∈M} ∑_{i∈I} ω[k][i] * y[p,i,j,t]
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y  # 确保变量存在
            )
            
            # 添加约束: 总摄入 ≤ α_max[p][k] + γ_max[p][k] * Q[p,k,t]
            model.addConstraint(
                nutrient_intake <= alpha_max[p][k] + gamma_max[p][k] * Q[(p, k, t)]
            )

for p in P:
    for k in K:
        for t in T:
            # 计算总营养摄入量: ∑_{j∈M} ∑_{i∈I} ω[k][i] * y[p,i,j,t]
            nutrient_intake = xp.Sum(
                w[k][i] * y[(i, p, j, t)] 
                for j in M 
                for i in I 
                if (i, p, j, t) in y  # 确保变量存在
            )
            
            # 添加约束: 总摄入 ≤ α_max[p][k] + γ_max[p][k] * Q[p,k,t]
            model.addConstraint(
                nutrient_intake >= alpha_min[p][k] + gamma_min[p][k] * Q[(p, k, t)]
            )

# cost
# 早餐成本 ≤ 20% 总成本
breakfast_items = [i for i in I if meal_data.loc[i, 'course_type'] == 'Breakfast']
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'breakfast', t] for i in breakfast_items for t in T) <= 0.2 * Total_cost
)
# 午餐成本 ≤ 40% 总成本（包含所有非早餐课程）
non_breakfast_courses = [l for l in L if l != 'Breakfast']
lunch_items = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'lunch', t] for i in lunch_items for t in T) <= 0.4 * Total_cost
)

# 晚餐成本 ∈ [40%, 70%] 总成本
dinner_items  = [i for l in non_breakfast_courses for i in I_l[l]]
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) >= 0.4 * Total_cost
)
model.addConstraint(
    xp.Sum(cost[i] * x[i, 'dinner', t] for i in dinner_items for t in T) <= 0.7 * Total_cost
)

print(f"optimal objective:{model.getObjVal()}")
# for t in T:
#     for c in range(W):
#         print(f"nw(t={t}, c={c}) = {nw(t, T, c)}")
# Out:
# optimal objective:1e+40

# %%
model.setControl('maxtime', max_time )
print(model.getControl('maxtime'))
best_bound = model.getAttrib('bestbound')
mip_gap = 150*((model.getObjVal()-best_bound)/model.getObjVal())
# Out:
# 1000

# %%
xp.setOutputEnabled(True)
model.solve()
# Out:
# FICO Xpress v9.4.2, Hyper, solve started 23:47:47, Mar 9, 2025
# Heap usage: 11MB (peak 11MB, 2821KB system)
# Maximizing MILP noname using up to 8 threads and up to 7965MB memory, with these control settings:
# MAXTIME = 1000
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      17164 rows        11004 cols       135423 elements     10920 entities
# Presolved problem has:
#       5739 rows         5950 cols        46089 elements      5950 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 13MB (peak 23MB, 2821KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.04e-01,  1.00e+30] / [ 2.34e-03,  1.74e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.30e+03] / [ 2.10e-01,  5.00e+00]
#   Objective      [min,max] : [ 1.09e+00,  2.88e+00] / [ 1.11e+00,  6.99e+00]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 5100
#  Number of orbits: 2550, largest orbit: 2
#  Row orbits: 2395, row support: 4790
# Will try to keep branch and bound tree memory usage below 5.4GB
#  *** Solution found:   598.142677   Time:   0.25    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  662.93434   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual:
B total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4230   660.063131   662.230962     90   2907     94    0.33%     609    185
#     4330   660.063131   662.230962     90   2952     47    0.33%     504    188
#     4430   660.063131   662.230962     90   3020    122    0.33%     362    190
#     4531   660.063131   662.220511     90   3044    208    0.33%      70    194
#     4631   660.063131   662.220511     90   3103     89    0.33%     462    196
#     4734   660.063131   662.220511     90   3147    247    0.33%      60    199
#     4834   660.063131   662.220511     90   3429     67    0.33%     551    201
#     4935   660.063131   662.220511     90   3458    163    0.33%     170    203
#     5035   660.063131   662.220511     90   3458    125    0.33%     529    205
#     5136   660.063131   662.220511     90   3458     73    0.33%     206    210
#     5237   660.063131   662.220511     90   3649    132    0.33%     297    213
#     5337   660.063131   662.220511     90   3673     71    0.33%     412    215
#     5437   660.063131   662.220511     90   3673     35    0.33%     614    217
#     5538   660.063131   662.220511     90   3673    164    0.33%     207    219
#     5638   660.063131   662.220511     90   3697     97    0.33%     192    222
#     5738   660.063131   662.220511     90   4162    190    0.33%     237    224
#     5839   660.063131   662.220511     90   4264     91    0.33%     545    227
#     5940   660.063131   662.220511     90   4365     51    0.33%     630    230
#     6040   660.063131   662.220511     90   4488     67    0.33%     658    233
#     6141   660.063131   662.220511     90   4598    229    0.33%     311    236
# Elapsed time (sec): 239, estimated tree completion: 0.00000
# Heap usage: 478MB (peak 478MB, 21MB system)
# B&B tree size: 48MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6243   660.063131   662.220511     90   4669    193    0.33%     381    239
#     6343   660.063131   662.220511     90   4669     69    0.33%     618    241
#     6443   660.063131   662.220511     90   4844    209    0.33%     271    243
#     6544   660.063131   662.220511     90   5014     30    0.33%     552    245
#     6645   660.063131   662.220511     90   5038     99    0.33%     587    247
# Resetting tree to root.
#
# Performing root presolve...
#
# Reduced problem has:    5746 rows    5949 columns     50814 elements
# Presolve dropped   :       1 rows       1 columns      1319 elements
# Presolve tightened :       923 elements
# Will try to keep branch and bound tree memory usage below 5.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve, 249s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  662.93434   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 1496569 simplex iterations, 0.36s
#         Barrier: 13 barrier and 590 simplex iterations, 0.36s
#             Barrier used 7 threads 4 cores
#             Barrier used AVX2 support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0        662.934343      P      0     0        .000000   249
# Barrier solved problem
#   13 barrier and 590 simplex iterations in 0.37 seconds at time 249
#
# Final objective                       : 6.629343434343432e+02
#   Max primal violation      (abs/rel) : 1.110e-15 / 1.110e-15
#   Max dual violation        (abs/rel) : 6.269e-15 / 6.269e-15
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P          660.244949   662.220490     91                  0.30%       0    250
#    1  K    660.244949   662.220490     91     35      3    0.30%     724    251
#    2  K    660.244949   662.220490     91     27     25    0.30%     781    252
#    3  K    660.244949   662.220490     91     28     29    0.30%     706    253
#    4  K    660.244949   662.220490     91     40     29    0.30%     672    254
#    5  K    660.244949   662.220490     91     45     37    0.30%     729    255
#    6  K    660.244949   662.211700     91     15     40    0.30%     665    255
#    7  K    660.244949   662.211700     91      5     11    0.30%     691    255
B total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    14883   660.911616   661.047138     96   6141     60    0.02%     421    695
#    14983   660.911616   661.047138     96   6184    110    0.02%     436    697
#    15083   660.911616   661.047138     96   6310     68    0.02%     303    699
# a  15124   660.921717   661.047138     97   6326    121    0.02%       0    700
#    15268   660.921717   661.047138     97   6225      1    0.02%       2    700
#    15368   660.921717   661.047138     97   6266     16    0.02%     685    702
#    15468   660.921717   661.047138     97   6349     39    0.02%     564    704
#    15568   660.921717   661.047138     97   6435     90    0.02%     211    706
#    15669   660.921717   661.047138     97   6452     85    0.02%     212    709
#    15769   660.921717   661.047138     97   6519     39    0.02%     431    711
#    15869   660.921717   661.047138     97   6546     74    0.02%     334    714
#    15969   660.921717   661.047138     97   6653     34    0.02%     384    717
#    16070   660.921717   661.047138     97   6778     48    0.02%     260    720
#    16172   660.921717   661.047138     97   6888     96    0.02%     167    722
#    16272   660.921717   661.047138     97   7028     46    0.02%     579    724
#    16372   660.921717   661.047138     97   7048     84    0.02%     321    726
#    16472   660.921717   661.047138     97   7069     40    0.02%     284    728
#    16573   660.921717   661.047138     97   7146     35    0.02%     455    731
#    16678   660.921717   661.047138     97   7188    107    0.02%     139    732
#    16782   660.921717   661.047138     97   7372     92    0.02%     121    735
# Elapsed time (sec): 756, estimated tree completion: 0.00000
# Heap usage: 524MB (peak 524MB, 21MB system)
# B&B tree size: 82MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    17782   660.921717   661.047138     97   8267     44    0.02%     360    756
#    18783   660.921717   661.047138     97   9058     83    0.02%     289    773
#    19783   660.921717   661.047138     97   9677    116    0.02%     162    797
# b  20272   661.022727   661.047138     98  10164     75    0.00%       0    807
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=3.69274e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=3.69274e-05).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 6.610227272727276e+02
# Final MIP bound                       : 6.610467171717172e+02
#   Solution time / primaldual integral :    807.43s/  0.240460%
#   Number of solutions found / nodes   :        98 /     20272
#   Max primal violation      (abs/rel) : 1.819e-12 / 5.466e-16
#   Max integer violation     (abs    ) : 4.441e-16
# (<SolveStatus.COMPLETED: 3>, <SolStatus.OPTIMAL: 1>)

# %%
y_solution = {key: model.getSolution(var) for key, var in y.items()}

# show the items that selected
selected_y = {key: value for key, value in y_solution.items() if value > 0.5}

df_y = pd.DataFrame([
    {"Item": key[0], "Guest": key[1], "Meal": key[2], "Time": key[3], "Value": value}
    for key, value in selected_y.items()
])
df_y.to_csv("3.10y_result.csv", index=False)

preference_scores = {}

for t in T:
    score = 0
    for p in P:
        for j in M:
            for i in I:
                score += y_solution[(i, p, j, t)] * pi[p][i]
    preference_scores[t] = score
    
df = pd.DataFrame(list(preference_scores.items()), columns=['Day', 'Preference Score'])

df.to_csv('3.10daily_preference_scores.csv', index=False)
